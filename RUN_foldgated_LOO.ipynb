# %%
import re
import csv
import ast
import matplotlib.pyplot as plt
import pandas as pd
import copy
import time

def todata(dict1, dict2, val_type = 'MEAN'):
    valid_keys = list(dict1.keys() & dict2.keys())
    data1 = [dict1[x] for x in valid_keys]
    data2 = [dict2[x] for x in valid_keys]
    
    if type(data1[0]) == dict:
        data1 = [x[val_type] for x in data1]
        
    if type(data2[0]) == dict:
        data2 = [x[val_type] for x in data2]
    
    return valid_keys, data1, data2

def csv2dict(csv_file_path):
    result_dict = {}
    with open(csv_file_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        
        for row in csv_reader:
            try:
                result_dict[row[0]] = ast.literal_eval(row[1])  # value is list
            except:
                result_dict[row[0]] = row[1]
                
    return result_dict

def scatter(dict1, dict2, x_axis = 'x-axis', y_axis = 'y-axis'):
    valid_keys, data1, data2 = todata(dict1, dict2)
    plt.scatter(data1, data2, marker='o', color='b', alpha = 0.1, label='Data Points', zorder=2)
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)
    # plt.savefig('scatter.png')
    plt.show()

# %%
module2name = csv2dict('../data/assets/module2name.csv')
module2rns = csv2dict('../data/assets/module2rns.csv')

rn2modules = csv2dict('../data/assets/rn2modules.csv')
rn2def = csv2dict('../data/assets/rn2def_versions.csv')
rn2rules = pd.read_pickle('../data/assets/rn2rules.20230224.pkl')
rn2eqn_SI = csv2dict('../data/assets/rn2eqn_SI.csv')
cpd2name = csv2dict('../data/assets/cpd2nameShort.csv')

# %%
H2O2_rns = ['R00017_v1', 'R03532_v1', 'R09507_v1', 'R09740_v1', 'R09741_v1', 'R11522', 'R12455', 'R12454']

# %%
all_xgroups = ['fold_independent', 'spontaneous', '2002', '1', '2487', '2006', '2003', '7518', '4126', '7542', '246', '218', '2007', '7525', '304', '12', '11', '109', '10', '210', '7515', '279', '7577', '3016', '281', '7528', '331', '301', '7572', '2011', '206', '325', '282', '7527', '805', '180', '7512', '7560', '7529', '3691', '7579', '62', '315', '7554', '70', '4002', '2485', '2004', '297', '205', '7580', '286', '208', '247', '7567', '7510', '3156', '2', '307', '212', '387', '7561', '5104', '7571', '5', '7516', '7517', '7574', '911', '611', '132', '283', '3651', '2005', '2498', '4081', '7573', '632', '103', '328', '64', '708', '302', '2484', '7520', '185', '221', '2492', '7543', '211', '810', '285', '2493', '7523', '4021', '298', '7541', '7552', '164', '3847', '149', '4020', '4045', '355', '4178', '108', '4018', '7587', '7546', '7507', '812', '101', '4019', '223', '3339', '702', '7601', '7602', '144', '3374', '278', '604', '7588', '602', '4952', '4953', '7524', '236', '131', '129', '159', '7581', '2486', '7531', '222', '213', '7504', '6094', '3692', '4004', '220', '330', '7558', '230', '314', '207', '65', '376', '276', '503', '7501', '244', '7522', '323', '7514', '107', '3294', '217', '187', '219', '239', '243', '3883', '7564', '266', '147', '321', '312', '296', '3687', '150', '3699', '5084', '868', '1001', '327', '3688', '375', '4995', '7589', '73', '133', '3371', '7568', '7509', '300', '277', '141', '7534', '3754', '2500', '1074', '102', '136', '316', '209', '139', '601', '4093', '177', '371', '873', '4279', '5038', '813', '5069', '7500', '3257', '172', '629', '232', '3052', '275', '6075', '7553', '3264', '231', '179', '189', '7539', '830', '377', '270', '313', '6051', '106', '3654', '7586', '258', '6058', '3117', '3292', '4114', '3086', '1077', '3599', '6113', '7550', '1137', '4262', '3005', '69', '7536', '7549', '214', '4', '3686', '148', '3896', '3076', '633', '4033', '4052', '3794', '2008', '1119', '4161', '319', '268', '5067', '9', '3447', '4029', '4049', '7584', '4011', '4237', '4111', '608', '7604', '7551', '525', '875', '880', '3858', '582', '4194', '374', '7513', '3740', '1143', '1055', '1114', '7595', '7562', '814', '197', '842', '650', '869', '5039', '7521', '623', '1144', '6096', '4022', '4044', '237', '5100', '4295', '7540', '309', '253', '303', '199', '3001', '4335', '3685', '324', '3009', '528', '4076', '876', '4017', '2496', '3697', '3892', '3997', '146', '262', '867', '914', '2012', '7', '3249', '158', '557', '66', '4294', '6166', '257', '3978', '620', '6174', '6', '4159', '4110', '235', '7556', '581', '3960', '154', '640', '5103', '3752', '3777', '3115', '4160', '196', '305', '3207', '881', '241', '284', '3321', '3323', '3322', '920', '378', '7544', '184', '4983', '4229', '4971', '4223', '590', '2010', '169', '806', '228', '192', '603', '306', '75', '3018', '865', '872', '3269', '7563', '3623', '4048', '4028', '7578', '3993', '3994', '3500', '3304', '4025', '4024', '4046', '4272', '3281', '3843', '3456', '3579', '4035', '4054', '4036']

# %%
'558' in all_xgroups
# Out:
# False

# %%
len(all_xgroups)
# Out:
# 398

# %%
import networkExpansionPy.folds as nf
import pandas as pd
from collections import Counter
from pathlib import PurePath, Path

# %%
for x in all_xgroups:
    xgroups = copy.copy(all_xgroups)
    xgroups.remove(x)

    start_time = time.time()

    # seed = sys.argv[1]
    # random.seed(seed)
    asset_path = nf.asset_path

    # for vanilla
    METABOLISM_PATH = PurePath(asset_path, "metabolic_networks","metabolism.v8.01May2023.pkl") # path to metabolism object pickle
    RN2RULES_PATH = PurePath(asset_path,"rn2fold","rn2rules.20230224.pkl") # path to rn2rules object pickle
    SEED_CPDS_PATH = PurePath(asset_path, "compounds", "seeds.Goldford2022.csv") # path to seed compounds csv

    # for FOLD-GATED
    ALGORITHM = "no_look_ahead_rules"
    WRITE = True # write result to disk
    WRITE_TMP = False # write after each iteration
    CUSTOM_WRITE_PATH = None # if writing result, custom path to write to
    STR_TO_APPEND_TO_FNAME = f'{x}' # if writing result, str to append to filename
    ORDERED_OUTCOME = False # ignore random seed and always choose folds based on sort order
    IGNORE_REACTION_VERSIONS = True # when maximizing for reactions, don't count versioned reactions

    ## Metabolism
    metabolism = pd.read_pickle(METABOLISM_PATH)


    ## FoldRules
    rn2rules = pd.read_pickle(RN2RULES_PATH)
    foldrules = nf.FoldRules.from_rn2rules(rn2rules)

    ## Modify seeds with AA and GATP_rns
    aa_cids = set(["C00037",
        "C00041",
        "C00065",
        "C00188",
        "C00183",
        "C00407",
        "C00123",
        "C00148",
        "C00049",
        "C00025"]) 

    GATP_rns = {'R00200_gATP_v1',
        'R00200_gATP_v2',
        'R00430_gGTP_v1',
        'R00430_gGTP_v2',
        'R01523_gATP_v1',
        'R04144_gATP_v1',
        'R04208_gATP',
        'R04463_gATP',
        'R04591_gATP_v1',
        'R06836_gATP',
        'R06974_gATP',
        'R06975_gATP_v1'}

    ## Seed
    seed = nf.Params(
        rns = set(metabolism.network["rn"]) - set(rn2rules) | GATP_rns,  # start with non-fold-gated reactions
        cpds = set((pd.read_csv(SEED_CPDS_PATH)["ID"])) | aa_cids,
        folds = set(xgroups)
    )

    ## remove H2O2 producing reactions
    condition = ((metabolism.network['rn'].isin(H2O2_rns)) & (metabolism.network['s'] > 0))
    metabolism.network = metabolism.network[~condition]

    ## Inititalize fold metabolism
    fm = nf.FoldMetabolism(metabolism, foldrules, seed)

    # run FOLD-GATED expansion
    result = fm.rule_order(algorithm=ALGORITHM, write=WRITE, write_tmp=WRITE_TMP, path=CUSTOM_WRITE_PATH, str_to_append_to_fname=STR_TO_APPEND_TO_FNAME, ordered_outcome=ORDERED_OUTCOME, ignore_reaction_versions=IGNORE_REACTION_VERSIONS)

    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 2 (6.2 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_17-59-26__fold_independent.pkl.gz
# --- 10.735487937927246 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 96
# max_foldsets:
# 	[frozenset({'spontaneous'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'spontaneous'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_17-59-37__spontaneous.pkl.gz
# --- 16.505591869354248 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 34
# max_foldsets:
# 	[frozenset({'2002'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'2002'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_17-59-53__2002.pkl.gz
# --- 16.267051935195923 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 106
# max_foldsets:
# 	[frozenset({'1'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'1'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-00-09__1.pkl.gz
# --- 16.42062997817993 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 92
# max_foldsets:
# 	[frozenset({'2487'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'2487'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-00-26__2487.pkl.gz
# --- 16.41579008102417 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 192
# max_foldsets:
# 	[frozenset({'2006'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'2006'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-00-42__2006.pkl.gz
# --- 16.389725923538208 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 448
# max_foldsets:
# 	[frozenset({'2003'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'2003'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-00-59__2003.pkl.gz
# --- 16.27831506729126 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 18
# max_foldsets:
# 	[frozenset({'7518'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'7518'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-01-15__7518.pkl.gz
# --- 16.34084701538086 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 5
# max_foldsets:
# 	[frozenset({'4126'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'4126'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-01-31__4126.pkl.gz
# --- 16.350997924804688 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 31
# max_foldsets:
# 	[frozenset({'7542'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'7542'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-01-47__7542.pkl.gz
# --- 16.42597198486328 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 161
# max_foldsets:
# 	[frozenset({'246'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'246'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-02-04__246.pkl.gz
# --- 16.368398904800415 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 4
# max_foldsets:
# 	[frozenset({'218'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'218'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-02-20__218.pkl.gz
# --- 16.06571388244629 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 64
# max_foldsets:
# 	[frozenset({'2007'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'2007'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-02-36__2007.pkl.gz
# --- 16.206513166427612 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 47
# max_foldsets:
# 	[frozenset({'7525'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'7525'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-02-53__7525.pkl.gz
# --- 16.418556928634644 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 386
# max_foldsets:
# 	[frozenset({'304'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'304'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-03-09__304.pkl.gz
# --- 16.349740982055664 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 191
# max_foldsets:
# 	[frozenset({'12'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'12'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-03-25__12.pkl.gz
# --- 16.366718292236328 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 179
# max_foldsets:
# 	[frozenset({'11'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'11'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-03-42__11.pkl.gz
# --- 16.36584210395813 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 193
# max_foldsets:
# 	[frozenset({'109'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'109'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-03-58__109.pkl.gz
# --- 16.357788801193237 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 217
# max_foldsets:
# 	[frozenset({'10'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'10'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-04-14__10.pkl.gz
# --- 16.403934001922607 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 53
# max_foldsets:
# 	[frozenset({'210'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'210'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-04-31__210.pkl.gz
# --- 16.426416873931885 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 58
# max_foldsets:
# 	[frozenset({'7515'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'7515'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-04-47__7515.pkl.gz
# --- 16.410493850708008 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 50
# max_foldsets:
# 	[frozenset({'279'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'279'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-05-04__279.pkl.gz
# --- 16.405534982681274 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 143
# max_foldsets:
# 	[frozenset({'7577'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'7577'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-05-20__7577.pkl.gz
# --- 16.377722024917603 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 138
# max_foldsets:
# 	[frozenset({'3016'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'3016'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-05-36__3016.pkl.gz
# --- 16.410471200942993 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 25
# max_foldsets:
# 	[frozenset({'281'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'281'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-05-53__281.pkl.gz
# --- 16.445188760757446 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 17
# max_foldsets:
# 	[frozenset({'7528'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'7528'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-06-09__7528.pkl.gz
# --- 16.309287786483765 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 37
# max_foldsets:
# 	[frozenset({'331'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.1 sec) frozenset({'331'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-06-26__331.pkl.gz
# --- 16.449249982833862 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 68
# max_foldsets:
# 	[frozenset({'301'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.2 sec) frozenset({'301'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_18-06-42__301.pkl.gz
# --- 16.43302869796753 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
# ...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-44-19__4024.pkl.gz
# --- 16.043489933013916 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 1
# max_foldsets:
# 	[frozenset({'4046'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'4046'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-44-35__4046.pkl.gz
# --- 16.023760080337524 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 7
# max_foldsets:
# 	[frozenset({'4272'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'4272'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-44-51__4272.pkl.gz
# --- 15.996776103973389 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 8
# max_foldsets:
# 	[frozenset({'3281'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'3281'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-45-07__3281.pkl.gz
# --- 15.991786003112793 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 7
# max_foldsets:
# 	[frozenset({'3843'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'3843'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-45-23__3843.pkl.gz
# --- 16.01115322113037 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 7
# max_foldsets:
# 	[frozenset({'3456'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'3456'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-45-39__3456.pkl.gz
# --- 15.989978075027466 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 6
# max_foldsets:
# 	[frozenset({'3579'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'3579'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-45-55__3579.pkl.gz
# --- 16.030007123947144 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 6
# max_foldsets:
# 	[frozenset({'4035'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'4035'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-46-11__4035.pkl.gz
# --- 16.00079107284546 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 6
# max_foldsets:
# 	[frozenset({'4054'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'4054'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-46-27__4054.pkl.gz
# --- 15.961824655532837 seconds ---
# calculating scope...
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ...done.
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# +++++++++++++++++
# max_v: 6
# max_foldsets:
# 	[frozenset({'4036'})]
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:535: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   X,Y = netExp_trace(R,P,x0,b)
# ============================================================
# rule iter: 2 (9.0 sec) frozenset({'4036'})
# ============================================================
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/networkExpansionPy/lib.py:537: SparseEfficiencyWarning: Comparing sparse matrices using == is inefficient, try using != instead.
#   x,y = netExp_step(R,P,x0,b)
# No foldsets remaining.
# ============================================================
# rule iter: 3 (1.2e+01 sec) frozenset()
# ============================================================
# Final results written to:
# /Users/longolab/Desktop/LongoLab/Fold_Gated/networkExpansion/fold_results/2024-06-12_19-46-43__4036.pkl.gz
# --- 15.914360046386719 seconds ---
