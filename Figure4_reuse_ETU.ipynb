# %% [markdown]
# **NOTE:** Some variable names differ from those used in the main text,
# reflecting terminology changes made during the course of the study:
# - 'fold' -> 'lineage'
# - 'NONE' -> 'base seed'
# - 'ALL' -> 'full network'
#
# Each enzyme-gated network expansion run records iterations of network expansion as follows:
# - cumiter: Tracks all individual expansion steps, including both lineage addition steps and the resulting standard network expansion steps
# - folditer: Groups each lineage addition and the subsequent network expansion into a single unit; corresponds to a metabolic stage

# %%
from utils import*

# %%
def getDirectRns(cpd_id):
    direct_rns = set()
    for rn, cpds in rn2cpds.items():
        if cpd_id in cpds:
            direct_rns.add(rn)
    return direct_rns

# %%
# from Leave-One-Out analysis

group1 = ['2005', '4952', '184', '325', '3016', '2003', '2002', '7523', '328', '875', '602', '2486', '212', '4011', '7574', '218', '2004', '304', '7584', '206', '4953', '1', '3997', '7577', '148', '7501', '7579', '2007', '253', '7544', '101', '297', '327', '330', '141', '109', '2492']
first10 = ['2005', '4952', '325', '2003', '2002', '602', '218', '206', '4953', '2007']

# %%
# preATP 1000 runs

df_folds_folditer = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/folds_folditer_preATP.csv', index_col=0)
df_cpds_folditer = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/cpds_folditer_preATP.csv', index_col=0)
df_rns_folditer = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/rns_folditer_preATP.csv', index_col=0)
df_rules_folditer = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/rules_folditer_preATP.csv', index_col=0)

df_folds_cumiter = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/folds_cumiter_preATP.csv', index_col=0)
df_cpds_cumiter = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/cpds_cumiter_preATP.csv', index_col=0)
df_rns_cumiter = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/rns_cumiter_preATP.csv', index_col=0)
df_rules_cumiter = pd.read_csv('../data/1000runs_csvs/1000runs_csvs_preATP/rules_cumiter_preATP.csv', index_col=0)

# %%
x2foMean = {}
x2foStd = {}
for x in df_folds_folditer.index:
    if x not in ['fold_independent', 'spontaneous']:
        x2foMean[x] = np.mean(df_folds_folditer.loc[x])
        x2foStd[x] = np.std(df_folds_folditer.loc[x])

print(len(x2foMean))
print(len(x2foStd))
# Out:
# 396
# 396

# %%
rns_scope = list(df_rns_folditer[df_rns_folditer.columns[0]].keys())
len(rns_scope)
# Out:
# 7678

# %% [markdown]
# # 1. Direct vs. indirect reactions
# - direct := reaction has the cpd in its eqn (reac or prod)
# - indirect := reaction does NOT have the cpd in its eqn, but is unreachable when cpd in ablated

# %% [markdown]
# ### get direct cofactor reactions from SI

# %%
# get 'direct' reactions from SI list of rns

direct_rns_SI_O2 = getDirectRns('C00007')
print(len(direct_rns_SI_O2))
direct_rns_SI_CoA = getDirectRns('C00010') | getDirectRns('Z00051')
print(len(direct_rns_SI_CoA))
direct_rns_SI_ATP = getDirectRns('C00002') | getDirectRns('C00008')
print(len(direct_rns_SI_ATP))
direct_rns_SI_SAM = getDirectRns('C00019') | getDirectRns('Z00041') # C00021 (SAH) is accessible before SAM; do not include here
print(len(direct_rns_SI_SAM))
direct_rns_SI_FAD = getDirectRns('C00016') | getDirectRns('Z00013') | getDirectRns('C01352')
print(len(direct_rns_SI_FAD))
direct_rns_SI_NAD = getDirectRns('C00003') | getDirectRns('Z00032') | getDirectRns('C00004')  # Z00032 = 'NAD/NADP'
print(len(direct_rns_SI_NAD))
direct_rns_SI_NADP = getDirectRns('C00005') | getDirectRns('Z00032') | getDirectRns('C00006')
print(len(direct_rns_SI_NADP))
direct_rns_SI_PLP = getDirectRns('C00018') | getDirectRns('Z00035')
print(len(direct_rns_SI_PLP))
direct_rns_SI_ThDP = getDirectRns('C00068') | getDirectRns('Z00047')
print(len(direct_rns_SI_ThDP))
direct_rns_SI_FMN = getDirectRns('C00061') | getDirectRns('Z00014') | getDirectRns('C01847')
print(len(direct_rns_SI_FMN))
direct_rns_SI_Cobalamin = getDirectRns('Z00009')
print(len(direct_rns_SI_Cobalamin))
direct_rns_SI_AcetylCoA = getDirectRns('C00024')
print(len(direct_rns_SI_AcetylCoA))
direct_rns_SI_IPP = getDirectRns('C00129')
print(len(direct_rns_SI_IPP))
# Out:
# 1638
# 659
# 843
# 581
# 732
# 1384
# 1389
# 386
# 103
# 250
# 50
# 218
# 50

# %% [markdown]
# ### get unreached reactions from ablation (direct or indirect)

# %%
with open('../data/rns_unreached_wo/rns_unreached_wo_O2.pkl', 'rb') as file:
    unreached_O2 = pickle.load(file)
print(len(unreached_O2))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_CoA_zCoA.pkl', 'rb') as file:
    unreached_CoA = pickle.load(file)
print(len(unreached_CoA))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_ATP_ADP.pkl', 'rb') as file:
    unreached_ATP = pickle.load(file)
print(len(unreached_ATP))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_SAM_zSAM.pkl', 'rb') as file:
    unreached_SAM = pickle.load(file)
print(len(unreached_SAM))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_FAD_FADH2_zFAD.pkl', 'rb') as file:
    unreached_FAD = pickle.load(file)
print(len(unreached_FAD))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_NAD_NADH_zNAD.pkl', 'rb') as file:
    unreached_NAD = pickle.load(file)
print(len(unreached_NAD))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_NADP_NADPH_zNADP.pkl', 'rb') as file:
    unreached_NADP = pickle.load(file)
print(len(unreached_NADP))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_PLP_zPLP.pkl', 'rb') as file:
    unreached_PLP = pickle.load(file)
print(len(unreached_PLP))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_ThDP_zThDP.pkl', 'rb') as file:
    unreached_ThDP = pickle.load(file)
print(len(unreached_ThDP))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_FMN_zFMN.pkl', 'rb') as file:
    unreached_FMN = pickle.load(file)
print(len(unreached_FMN))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_IPP.pkl', 'rb') as file:
    unreached_IPP = pickle.load(file)
print(len(unreached_IPP))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_zCobalamin.pkl', 'rb') as file:
    unreached_Cobalamin = pickle.load(file)
print(len(unreached_Cobalamin))  # from ablation

with open('../data/rns_unreached_wo/rns_unreached_wo_AcetylCoA.pkl', 'rb') as file:
    unreached_AcetylCoA = pickle.load(file)
print(len(unreached_AcetylCoA))  # from ablation
# Out:
# 1673
# 3788
# 6788
# 3134
# 2121
# 6591
# 4259
# 5380
# 1894
# 3590
# 2304
# 87
# 2911

# %%
# get 'indirect' reactions:
    # 1. get reactions unreachable without cofactor (cpd ablation) from actual vanilla run
    # 2. subtract 'direct' from that
# get 'direct' reactions:
    # 1. get reactions unreachable without cofactor (cpd ablation) from actual vanilla run
    # 2. get overlap with direct_reactions from SI
    # 3. check to make sure it's the same as len(direct_rns_SI_cofactor & set(rns_scope))

indirectO2 = unreached_O2 - direct_rns_SI_O2
directO2 = unreached_O2 & direct_rns_SI_O2
print('O2: ', len(indirectO2), len(directO2), len(direct_rns_SI_O2 & set(rns_scope)))

indirectATP = unreached_ATP - direct_rns_SI_ATP 
directATP = unreached_ATP & direct_rns_SI_ATP
print('ATP:',len(indirectATP), len(directATP), len(direct_rns_SI_ATP & set(rns_scope)))

indirectCoA = unreached_CoA - direct_rns_SI_CoA
directCoA = unreached_CoA & direct_rns_SI_CoA
print('CoA:', len(indirectCoA), len(directCoA), len(direct_rns_SI_CoA & set(rns_scope)))

indirectSAM = unreached_SAM - direct_rns_SI_SAM
directSAM = unreached_SAM & direct_rns_SI_SAM
print('SAM:', len(indirectSAM), len(directSAM), len(direct_rns_SI_SAM & set(rns_scope)))

indirectFAD = unreached_FAD - direct_rns_SI_FAD
directFAD = unreached_FAD & direct_rns_SI_FAD
print('FAD:', len(indirectFAD), len(directFAD), len(direct_rns_SI_FAD & set(rns_scope)))

indirectNAD = unreached_NAD - direct_rns_SI_NAD
directNAD = unreached_NAD & direct_rns_SI_NAD
print('NAD:', len(indirectNAD), len(directNAD), len(direct_rns_SI_NAD & set(rns_scope)))

indirectNADP = unreached_NADP - direct_rns_SI_NADP
directNADP = unreached_NADP & direct_rns_SI_NADP
print('NADP:', len(indirectNADP), len(directNADP), len(direct_rns_SI_NADP & set(rns_scope)))

indirectPLP = unreached_PLP - direct_rns_SI_PLP
directPLP = unreached_PLP & direct_rns_SI_PLP
print('PLP:', len(indirectPLP), len(directPLP), len(direct_rns_SI_PLP & set(rns_scope)))

indirectThDP = unreached_ThDP - direct_rns_SI_ThDP
directThDP = unreached_ThDP & direct_rns_SI_ThDP
print('ThDP:', len(indirectThDP), len(directThDP), len(direct_rns_SI_ThDP & set(rns_scope)))

indirectFMN = unreached_FMN - direct_rns_SI_FMN
directFMN = unreached_FMN & direct_rns_SI_FMN
print('FMN:', len(indirectFMN), len(directFMN), len(direct_rns_SI_FMN & set(rns_scope)))

indirectCobalamin = unreached_Cobalamin - direct_rns_SI_Cobalamin
directCobalamin = unreached_Cobalamin & direct_rns_SI_Cobalamin
print('Cobalamin:', len(indirectCobalamin), len(directCobalamin), len(direct_rns_SI_Cobalamin & set(rns_scope)))

indirectIPP = unreached_IPP - direct_rns_SI_IPP
directIPP = unreached_IPP & direct_rns_SI_IPP
print('IPP:', len(indirectIPP), len(directIPP), len(direct_rns_SI_IPP & set(rns_scope)))

indirectAcetylCoA = unreached_AcetylCoA - direct_rns_SI_AcetylCoA
directAcetylCoA = unreached_AcetylCoA & direct_rns_SI_AcetylCoA
print('AcetylCoA:', len(indirectAcetylCoA), len(directAcetylCoA), len(direct_rns_SI_AcetylCoA & set(rns_scope)))
# Out:
# O2:  826 847 847
# ATP: 6142 646 646
# CoA: 3325 463 463
# SAM: 2800 334 334
# FAD: 1631 490 490
# NAD: 5716 875 875
# NADP: 3400 859 859
# PLP: 5032 348 348
# ThDP: 1798 96 96
# FMN: 3411 179 179
# Cobalamin: 50 37 37
# IPP: 2255 49 49
# AcetylCoA: 2747 164 164

# %% [markdown]
# #### what if we ignore Z cpds?

# %%
# ignore Z compounds
print('      C+Z  C')
print('-------------')

direct_rns_SI_CoA_C = getDirectRns('C00010')
print('CoA: ',len(direct_rns_SI_CoA), len(direct_rns_SI_CoA_C))
direct_rns_SI_ATP_C = getDirectRns('C00002')
print('ATP: ',len(direct_rns_SI_ATP), len(direct_rns_SI_ATP_C))
direct_rns_SI_SAM_C = getDirectRns('C00019')
print('SAM: ',len(direct_rns_SI_SAM), len(direct_rns_SI_SAM_C))
direct_rns_SI_FAD_C = getDirectRns('C00016')
print('FAD: ',len(direct_rns_SI_FAD), len(direct_rns_SI_FAD_C))
direct_rns_SI_NAD_C = getDirectRns('C00003')
print('NAD: ',len(direct_rns_SI_NAD), len(direct_rns_SI_NAD_C))
direct_rns_SI_NADP_C = getDirectRns('C00005')
print('NADP:',len(direct_rns_SI_NADP), len(direct_rns_SI_NADP_C))
direct_rns_SI_PLP_C = getDirectRns('C00018')
print('PLP: ',len(direct_rns_SI_PLP), len(direct_rns_SI_PLP_C))
direct_rns_SI_ThDP_C = getDirectRns('C00068')
print('ThDP:',len(direct_rns_SI_ThDP), len(direct_rns_SI_ThDP_C))
direct_rns_SI_FMN_C = getDirectRns('C00061')
print('FMN: ',len(direct_rns_SI_FMN), len(direct_rns_SI_FMN_C))
# Out:
#       C+Z  C
# -------------
# CoA:  659 638
# ATP:  843 796
# SAM:  581 564
# FAD:  732 93
# NAD:  1384 1078
# NADP: 1389 1080
# PLP:  386 15
# ThDP: 103 28
# FMN:  250 72

# %%
directFMN_C = unreached_FMN & direct_rns_SI_FMN_C
print('FMN: ', len(directFMN), len(directFMN_C), len([rn for rn in directFMN_C if rn2rev[rn]]), len([rn for rn in directFMN_C if not rn2rev[rn]]))
# Out:
# FMN:  179 40 25 15

# %%
directO2_C = unreached_O2 & direct_rns_SI_O2
print('O2: ', len(directO2), len([rn for rn in directO2 if rn2rev[rn]]))
[rn for rn in directO2 if rn2rev[rn]]

# only 1 O2 reactions is 'reversible'!
# Out:
# O2:  847 1
# ['R09503_vX']

# %%
print('     C+Z C rev n_rev')
print('-------------------------')

print('O2:  ', '-', len(directO2), len([rn for rn in directO2 if rn2rev[rn]]), len([rn for rn in directO2 if not rn2rev[rn]]))
directCoA_C = unreached_CoA & direct_rns_SI_CoA_C
print('CoA: ', len(directCoA), len(directCoA_C), len([rn for rn in directCoA_C if rn2rev[rn]]), len([rn for rn in directCoA_C if not rn2rev[rn]]))
directATP_C = unreached_ATP & direct_rns_SI_ATP_C
print('ATP: ', len(directATP), len(directATP_C), len([rn for rn in directATP_C if rn2rev[rn]]), len([rn for rn in directATP_C if not rn2rev[rn]]))
directSAM_C = unreached_SAM & direct_rns_SI_SAM_C
print('SAM: ', len(directSAM), len(directSAM_C), len([rn for rn in directSAM_C if rn2rev[rn]]), len([rn for rn in directSAM_C if not rn2rev[rn]]))
directFAD_C = unreached_FAD & direct_rns_SI_FAD_C
print('FAD: ', len(directFAD), len(directFAD_C), len([rn for rn in directFAD_C if rn2rev[rn]]), len([rn for rn in directFAD_C if not rn2rev[rn]]))
directNAD_C = unreached_NAD & direct_rns_SI_NAD_C
print('NAD: ', len(directNAD), len(directNAD_C), len([rn for rn in directNAD_C if rn2rev[rn]]), len([rn for rn in directNAD_C if not rn2rev[rn]]))
directNADP_C = unreached_NADP & direct_rns_SI_NADP_C
print('NADP:', len(directNADP), len(directNADP_C), len([rn for rn in directNADP_C if rn2rev[rn]]), len([rn for rn in directNADP_C if not rn2rev[rn]]))
directPLP_C = unreached_PLP & direct_rns_SI_PLP_C
print('PLP: ', len(directPLP), len(directPLP_C), len([rn for rn in directPLP_C if rn2rev[rn]]), len([rn for rn in directPLP_C if not rn2rev[rn]]))
directThDP_C = unreached_ThDP & direct_rns_SI_ThDP_C
print('ThDP: ', len(directThDP), len(directThDP_C), len([rn for rn in directThDP_C if rn2rev[rn]]), len([rn for rn in directThDP_C if not rn2rev[rn]]))
directFMN_C = unreached_FMN & direct_rns_SI_FMN_C
print('FMN: ', len(directFMN), len(directFMN_C), len([rn for rn in directFMN_C if rn2rev[rn]]), len([rn for rn in directFMN_C if not rn2rev[rn]]))
# Out:
#      C+Z C rev n_rev
# -------------------------
# O2:   - 847 1 846
# CoA:  463 445 351 94
# ATP:  646 606 559 47
# SAM:  334 320 291 29
# FAD:  490 53 45 8
# NAD:  875 661 538 123
# NADP: 859 644 472 172
# PLP:  348 15 8 7
# ThDP:  96 28 20 8
# FMN:  179 40 25 15

# %% [markdown]
# ### calculate fraction of reactions that are direct cofactor-utilizing

# %%
# make x2rn with the same scope as our simulations

x2rn_scope = {}
for x, rns in x2rn.items():
    scope_rns = []
    for rn in rns:
        if rn in rns_scope:  # check if rn appears in our simulations
            scope_rns.append(rn)
    x2rn_scope[x] = scope_rns

# %%
def makeCofactorDicts(direct_rns, indirect_rns):
    # make categorical dict
    x2rn_cofactor = {}
    for x, rns in x2rn_scope.items():
        fracdict = {'direct':[], 'indirect':[], 'total':[]}
        for rn in rns:
            if rn in direct_rns:
                fracdict['direct'].append(rn)
            if rn in indirect_rns:
                fracdict['indirect'].append(rn)
            fracdict['total'].append(rn)
        x2rn_cofactor[x] = fracdict
    
    # make fraction dict
    x2rnFrac_cofactor = {}
    for x, d in x2rn_cofactor.items():
        dir_total = len(d['direct']) / len(d['total'])
        ind_total = len(d['indirect']) / len(d['total'])
        dir_ind_total = len((set(d['direct']) | set(d['indirect']))) / len(d['total'])
        x2rnFrac_cofactor[x] = [dir_total, ind_total, dir_ind_total]
    
    return x2rn_cofactor, x2rnFrac_cofactor

# %%
x2rn_O2, x2rnFrac_O2 = makeCofactorDicts(directO2, indirectO2)
x2rn_ATP, x2rnFrac_ATP = makeCofactorDicts(directATP, indirectATP)
x2rn_CoA, x2rnFrac_CoA = makeCofactorDicts(directCoA, indirectCoA)
x2rn_SAM, x2rnFrac_SAM = makeCofactorDicts(directSAM, indirectSAM)
x2rn_FAD, x2rnFrac_FAD = makeCofactorDicts(directFAD, indirectFAD)

x2rn_NAD, x2rnFrac_NAD = makeCofactorDicts(directNAD, indirectNAD)
x2rn_NADP, x2rnFrac_NADP = makeCofactorDicts(directNADP, indirectNADP)
x2rn_PLP, x2rnFrac_PLP = makeCofactorDicts(directPLP, indirectPLP)
x2rn_ThDP, x2rnFrac_ThDP = makeCofactorDicts(directThDP, indirectThDP)

x2rn_FMN, x2rnFrac_FMN = makeCofactorDicts(directFMN, indirectFMN)
x2rn_IPP, x2rnFrac_IPP = makeCofactorDicts(directIPP, indirectIPP)
x2rn_Cobalamin, x2rnFrac_Cobalamin = makeCofactorDicts(directCobalamin, indirectCobalamin)
x2rn_AcetylCoA, x2rnFrac_AcetylCoA = makeCofactorDicts(directAcetylCoA, indirectAcetylCoA)

# %% [markdown]
# ### separate fractions

# %%
x2rnFrac_O2_0 = {x:values[0] for x, values in x2rnFrac_O2.items()}
x2rnFrac_O2_1 = {x:values[1] for x, values in x2rnFrac_O2.items()}
x2rnFrac_O2_2 = {x:values[2] for x, values in x2rnFrac_O2.items()}

x2rnFrac_ATP_0 = {x:values[0] for x, values in x2rnFrac_ATP.items()}
x2rnFrac_ATP_1 = {x:values[1] for x, values in x2rnFrac_ATP.items()}
x2rnFrac_ATP_2 = {x:values[2] for x, values in x2rnFrac_ATP.items()}

x2rnFrac_CoA_0 = {x:values[0] for x, values in x2rnFrac_CoA.items()}
x2rnFrac_CoA_1 = {x:values[1] for x, values in x2rnFrac_CoA.items()}
x2rnFrac_CoA_2 = {x:values[2] for x, values in x2rnFrac_CoA.items()}

x2rnFrac_SAM_0 = {x:values[0] for x, values in x2rnFrac_SAM.items()}
x2rnFrac_SAM_1 = {x:values[1] for x, values in x2rnFrac_SAM.items()}
x2rnFrac_SAM_2 = {x:values[2] for x, values in x2rnFrac_SAM.items()}

x2rnFrac_FAD_0 = {x:values[0] for x, values in x2rnFrac_FAD.items()}
x2rnFrac_FAD_1 = {x:values[1] for x, values in x2rnFrac_FAD.items()}
x2rnFrac_FAD_2 = {x:values[2] for x, values in x2rnFrac_FAD.items()}

x2rnFrac_NAD_0 = {x:values[0] for x, values in x2rnFrac_NAD.items()}
x2rnFrac_NAD_1 = {x:values[1] for x, values in x2rnFrac_NAD.items()}
x2rnFrac_NAD_2 = {x:values[2] for x, values in x2rnFrac_NAD.items()}

x2rnFrac_NADP_0 = {x:values[0] for x, values in x2rnFrac_NADP.items()}
x2rnFrac_NADP_1 = {x:values[1] for x, values in x2rnFrac_NADP.items()}
x2rnFrac_NADP_2 = {x:values[2] for x, values in x2rnFrac_NADP.items()}

x2rnFrac_PLP_0 = {x:values[0] for x, values in x2rnFrac_PLP.items()}
x2rnFrac_PLP_1 = {x:values[1] for x, values in x2rnFrac_PLP.items()}
x2rnFrac_PLP_2 = {x:values[2] for x, values in x2rnFrac_PLP.items()}

x2rnFrac_ThDP_0 = {x:values[0] for x, values in x2rnFrac_ThDP.items()}
x2rnFrac_ThDP_1 = {x:values[1] for x, values in x2rnFrac_ThDP.items()}
x2rnFrac_ThDP_2 = {x:values[2] for x, values in x2rnFrac_ThDP.items()}

x2rnFrac_FMN_0 = {x:values[0] for x, values in x2rnFrac_FMN.items()}
x2rnFrac_FMN_1 = {x:values[1] for x, values in x2rnFrac_FMN.items()}
x2rnFrac_FMN_2 = {x:values[2] for x, values in x2rnFrac_FMN.items()}

x2rnFrac_IPP_0 = {x:values[0] for x, values in x2rnFrac_IPP.items()}
x2rnFrac_IPP_1 = {x:values[1] for x, values in x2rnFrac_IPP.items()}
x2rnFrac_IPP_2 = {x:values[2] for x, values in x2rnFrac_IPP.items()}

x2rnFrac_Cobalamin_0 = {x:values[0] for x, values in x2rnFrac_Cobalamin.items()}
x2rnFrac_Cobalamin_1 = {x:values[1] for x, values in x2rnFrac_Cobalamin.items()}
x2rnFrac_Cobalamin_2 = {x:values[2] for x, values in x2rnFrac_Cobalamin.items()}

x2rnFrac_AcetylCoA_0 = {x:values[0] for x, values in x2rnFrac_AcetylCoA.items()}
x2rnFrac_AcetylCoA_1 = {x:values[1] for x, values in x2rnFrac_AcetylCoA.items()}
x2rnFrac_AcetylCoA_2 = {x:values[2] for x, values in x2rnFrac_AcetylCoA.items()}

# %% [markdown]
# ### get 'direct' lineages that have cofactors in equation

# %%
direct_lineages_O2 = [x for x,v in x2rnFrac_O2.items() if v[0] > 0]
print(len(direct_lineages_O2))
direct_lineages_ATP = [x for x,v in x2rnFrac_ATP.items() if v[0] > 0]
print(len(direct_lineages_ATP))
direct_lineages_CoA = [x for x,v in x2rnFrac_CoA.items() if v[0] > 0]
print(len(direct_lineages_CoA))
direct_lineages_SAM = [x for x,v in x2rnFrac_SAM.items() if v[0] > 0]
print(len(direct_lineages_SAM))
direct_lineages_FAD = [x for x,v in x2rnFrac_FAD.items() if v[0] > 0]
print(len(direct_lineages_FAD))
direct_lineages_NAD = [x for x,v in x2rnFrac_NAD.items() if v[0] > 0]
print(len(direct_lineages_NAD))
direct_lineages_NADP = [x for x,v in x2rnFrac_NADP.items() if v[0] > 0]
print(len(direct_lineages_NADP))
direct_lineages_PLP = [x for x,v in x2rnFrac_PLP.items() if v[0] > 0]
print(len(direct_lineages_PLP))
direct_lineages_ThDP = [x for x,v in x2rnFrac_ThDP.items() if v[0] > 0]
print(len(direct_lineages_ThDP))
direct_lineages_IPP = [x for x,v in x2rnFrac_IPP.items() if v[0] > 0]
print(len(direct_lineages_IPP))
direct_lineages_FMN = [x for x,v in x2rnFrac_FMN.items() if v[0] > 0]
print(len(direct_lineages_FMN))
direct_lineages_Cobalamin = [x for x,v in x2rnFrac_Cobalamin.items() if v[0] > 0]
print(len(direct_lineages_Cobalamin))
direct_lineages_AcetylCoA = [x for x,v in x2rnFrac_AcetylCoA.items() if v[0] > 0]
print(len(direct_lineages_AcetylCoA))
# Out:
# 88
# 132
# 79
# 40
# 89
# 127
# 120
# 41
# 22
# 8
# 75
# 16
# 63

# %% [markdown]
# # 2. ETU (Emerge to Use) lineages

# %%
# # this takes a while
# # collect cumiter2rules for all 1000 runs

# cumiter2rules_all_runs = {}
# for run in df_rules_cumiter:
#     cumiter2rules = {}
#     for rule, i in df_rules_cumiter[run].items():
#         if i not in cumiter2rules:
#             cumiter2rules[i] = [eval(rule)]  # convert string into tuple with 'eval'
#         else:
#             cumiter2rules[i].append(eval(rule))
#     cumiter2rules_all_runs[run] = cumiter2rules

# with open('../data/assets/cumiter2rules_all_runs.pkl', 'wb') as file:
#     pickle.dump(cumiter2rules_all_runs, file)

# %%
cumiter2rules_all_runs = pd.read_pickle('../data/assets/cumiter2rules_all_runs.pkl')

# %% [markdown]
# ### helper function to differentiate cofactor 'using' and 'producing' reactions

# %%
# helper function to return reactions that 'use' or 'produce' given cofactor when discovered
# change the condition in 'else' to either:
    # (1) compare cumiters of cpds to decide direction of rev reactions
    # (2) return reac_iters and prod_iters to compare with fold-cumiter in main function

def getUsingProducingRns(run, cofactor, direct_cofactor_rns):
    cofactor_using = []
    both = {}
    cofactor_producing = []

    if cofactor.startswith('Z'):
        print('this function cannot be used with Z compounds, since they are not consumed!')
        return None
    
    for rn in direct_cofactor_rns:

        if rn2direction[rn] == 'forward':
            if cofactor in rn2prod[rn]: # forward AND cpd is in prod
                cofactor_producing.append(rn) 
            else:
                cofactor_using.append(rn)
        elif rn2direction[rn] == 'reverse':
            if cofactor in rn2reac[rn]: # reverse AND cpd is in reac
                cofactor_producing.append(rn) 
            else:
                cofactor_using.append(rn)
        else:  # reversible 
            reac_iters = [df_cpds_cumiter[run][c] for c in rn2reac[rn]]
            prod_iters = [df_cpds_cumiter[run][c] for c in rn2prod[rn]]
            
            # # (1) compare cumiter of cpds
            # if max(reac_iters) > max(prod_iters):  # reverse
            #     if cofactor in rn2prod[rn]:
            #         cofactor_using.append(rn)
            #     else:
            #         cofactor_producing.append(rn)
            # elif max(reac_iters) < max(prod_iters):  # forward
            #     if cofactor in rn2reac[rn]:
            #         cofactor_using.append(rn)
            #     else:
            #         cofactor_producing.append(rn)
            # else:  # same max cumiter
            #     both.append(rn)

            # (2) instead, return max cumiters of reac and prod to be compared to 'fold cumiter' later
            both[rn] = (max(reac_iters), max(prod_iters))
            
    return cofactor_using, both, cofactor_producing

# example
run = '87452'
cofactor = 'C00007'
direct_cofactor_rns = directO2
using, both, producing = getUsingProducingRns(run, cofactor, direct_cofactor_rns)
print(len(directO2), len(using), len(both), len(producing))
# Out:
# 847 826 1 20

# %%
# check all of them
cid2directRns = {'C00007': directO2, 'C00002': directATP, 'C00010': directCoA, 'C00019': directSAM, 'C00016': directFAD, 'C00003': directNAD, 'C00005': directNADP, 'C00018': directPLP, 'C00068': directThDP, 'C00061': directFMN, 'C00129': directIPP, 'C00024': directAcetylCoA}
run = '87452'
for cid, direct_cofactor_rns in cid2directRns.items():
    using, both, producing = getUsingProducingRns(run, cid, direct_cofactor_rns)
    print(cid, len(direct_cofactor_rns), len(using), len(both), len(producing))
# Out:
# C00007 847 826 1 20
# C00002 646 43 595 8
# C00010 463 18 368 77
# C00019 334 32 302 0
# C00016 490 298 188 4
# C00003 875 136 648 91
# C00005 859 258 582 19
# C00018 348 71 272 5
# C00068 96 20 69 7
# C00061 179 75 94 10
# C00129 49 34 14 1
# C00024 164 14 147 3

# %% [markdown]
# ### getETC_UC: function to collect lineages that 'emerge to use' a given cpd

# %%
# Do not differentiate use vs. produce
def getETU_UC_direct(direct_cofactor_rn_set, direct_cofactor_lineage_set=None, mode='strict'):
    
    recruited_lineages_allruns = []
    for run, cumiter2rules in cumiter2rules_all_runs.items():
        
        # collect a list of rnRules discovered at the same time as lineage addition
        x2first_rules = {} 
        for x, i in df_folds_cumiter[run].items():
            if direct_cofactor_lineage_set == None:  # no lineage_set given
                if x != 'fold_independent':
                    x2first_rules[x] = cumiter2rules[i]
            else:
                if x in direct_cofactor_lineage_set:  # only look at lineages we already know have cofactor-using reactions
                    x2first_rules[x] = cumiter2rules[i]
                
        if mode == 'loose':
            # LOOSE: ETU if ANY reaction has cofactor ('direct')
            recruited_lineages = set()
            for x, rules in x2first_rules.items():
                for rule in rules:
                    if rule[0] in direct_cofactor_rn_set:  # direct cofactor rns 
                        recruited_lineages.add(x)
        
        elif mode == 'strict':
            # STRICT: ETU if ALL reactions have cofactor ('direct')
            recruited_lineages = set()
            for x, rules in x2first_rules.items():
                count = 0
                # count num of cofactor reactions
                for rule in rules:
                    if rule[0] in direct_cofactor_rn_set:  # direct cofactor rns 
                        count += 1
                if count == len(rules):  # if all reactions use the cofactor
                    recruited_lineages.add(x)        

        else:
            print('unrecognized mode name')
            return

        recruited_lineages_allruns.append(recruited_lineages)

    # tally of all lineages
    l = []  
    for run in recruited_lineages_allruns:
        for x in run:
            l.append(x)
    
    # divide based on threshold
    emerged_to_use = set()
    unclassified = set()
    for x in set(l):
#         print(l.count(x)/len(df_rules_cumiter.columns))
        if l.count(x)/len(df_rules_cumiter.columns) >= 0.75:  # change threshold here
            emerged_to_use.add(x)
        else:
            unclassified.add(x)

    # return the set of lineages 'recruited for' the cofactor
    return emerged_to_use, unclassified

# %%
# Differentiate use vs. produce

def getETU_UC_using(cofactor, direct_cofactor_rn_set, direct_cofactor_lineage_set=None, mode='strict'):
    recruited_lineages_allruns = []
    # just use one run to get using/producing reactions (2a)
    run = '87452'
    using, both, producing = getUsingProducingRns(run, cofactor, direct_cofactor_rn_set)
    
    for run, cumiter2rules in cumiter2rules_all_runs.items():
        # uncomment if using (2b) option below
        # using, both, producing = getUsingProducingRns(run, cofactor, direct_cofactor_rn_set)
        
        # collect a list of rnRules discovered at the same time as lineage addition
        x2first_rules = {} 
        for x, i in df_folds_cumiter[run].items():
            if direct_cofactor_lineage_set == None:  # no lineage_set given
                if x != 'fold_independent':
                    x2first_rules[x] = cumiter2rules[i]
            else:
                if x in direct_cofactor_lineage_set:  # only look at lineages we already know have cofactor-using reactions
                    x2first_rules[x] = cumiter2rules[i]
                
        # go through the reactions and determine their direction => collect cases where the lineage 'used' the cofactor
        if mode == 'loose':
            # LOOSE: ETU if ANY reaction uses the cofactor
            recruited_lineages = set()
            for x, rules in x2first_rules.items():
                for rule in rules:
                    if rule[0] in using:  # use the cofactor 
                        recruited_lineages.add(x)
        
        elif mode == 'strict':
            # STRICT: ETU if ALL reactions use the cofactor
            recruited_lineages = set()
            for x, rules in x2first_rules.items():
                count = 0
                for rule in rules:
    
                    # differentiate usage vs. production (reactant vs. product)
                    if rule[0] in using:  # direct cofactor USING rns 
                        count += 1
                    if rule[0] in both:
                        # (2a) just add them to recruit
                        count += 1
                        
                        # # (2b) more stringent; check for cpds that were gated by the lineage
                        # max_reac = both[rule[0]][0]  # max cumiter cpd in reac
                        # max_prod = both[rule[0]][0]  # max cumiter cpd in prod
                        # if df_folds_cumiter[run][x] == max_prod and cofactor in rn2reac[rule[0]]:
                        #     recruited_lineages.add(x)
                        # elif df_folds_cumiter[run][x] == max_reac and cofactor in rn2prod[rule[0]]:
                        #     recruited_lineages.add(x)
                        # else:
                        #     'this should not print'
                        #     return
                if count == len(rules):
                    recruited_lineages.add(x)

        else:
            print('unrecognized mode name')
            return

        recruited_lineages_allruns.append(recruited_lineages)

    # tally of all lineages
    l = []  
    for run in recruited_lineages_allruns:
        for x in run:
            l.append(x)
    
    # divide based on threshold
    emerged_to_use = set()
    unclassified = set()
    
    for x in set(l):
        # print(x, l.count(x)/len(df_rules_cumiter.columns))
        if l.count(x)/len(df_rules_cumiter.columns) >= 0.75:  # change threshold here
            emerged_to_use.add(x)
        else:
            unclassified.add(x)

    # return the set of lineages 'recruited for' the cofactor
    return emerged_to_use, unclassified

# %%
ETU_O2_direct, UC_O2_direct = getETU_UC_direct(directO2, direct_lineages_O2, 'loose')
print(len(ETU_O2_direct), len(UC_O2_direct))
ETU_O2_direct, UC_O2_direct = getETU_UC_direct(directO2, direct_lineages_O2, 'strict')
print(len(ETU_O2_direct), len(UC_O2_direct))

ETU_O2_using_loose, UC_O2_using_loose = getETU_UC_using('C00007', directO2, direct_lineages_O2, 'loose')
print(len(ETU_O2_using_loose), len(UC_O2_using_loose))
ETU_O2_using, UC_O2_using = getETU_UC_using('C00007', directO2, direct_lineages_O2, 'strict')
print(len(ETU_O2_using), len(UC_O2_using))
# Out:
# 33 0
# 27 0
# 31 0
# 24 0

# %%
ETU_O2_direct - ETU_O2_using
# Out:
# {'192', '228', '66'}

# %%
# check the lost lineages
run = '87452'
cofactor = 'C00007'
direct_cofactor_rns = directO2
using, both, producing = getUsingProducingRns(run, cofactor, direct_cofactor_rns)
print(len(directO2), len(using), len(both), len(producing))
# Out:
# 847 826 1 20

# %%
for rn in x2rn_O2['192']['direct']:
    print(rn, rn in producing)
# Out:
# R09518 False
# R00148_v1 False
# R00275_v3 True
# R00275_v4 True
# R00275_v2 True
# R00275_v1 True

# %%
for rn in x2rn_O2['228']['direct']:
    print(rn, rn in producing)
# Out:
# R00275_v3 True
# R00275_v4 True
# R00275_v2 True
# R00275_v1 True

# %%
for rn in x2rn_O2['66']['direct']:
    print(rn, rn in producing)
# Out:
# R03562 False
# R05440 False
# R05148_v1 False
# R05666_v1 False
# R07188_v1 False
# R02550_v1 True
# R05274_v1 False
# R06782_v1 False
# R05739_v1 False
# R00823_v1 False
# R07409_v2 False
# R05427_v1 False
# R05425_v1 False
# R03559_v1 False
# R05739_v2 False
# R07710_v1 False
# R07709_v1 False
# R07409_v1 False
# R05622_v1 False
# R09513_v1 False
# R06783_v1 False
# R05426_v1 False
# R05444_v1 False
# R05621_v1 False
# R00825_v1 False

# %%
# direct recruitment defined by cumiter; this takes longer

# using
ETU_O2, UC_O2 = getETU_UC_using('C00007', directO2, direct_lineages_O2, 'strict')
print('O2:  ', len(ETU_O2), len(UC_O2))
# direct
# ETU_O2, UC_O2 = getETU_UC_direct(directO2, direct_lineages_O2)
# print('O2:  ', len(ETU_O2), len(UC_O2))


# direct
ETU_ATP, UC_ATP = getETU_UC_direct(directATP, direct_lineages_ATP)
print('ATP: ', len(ETU_ATP), len(UC_ATP))
ETU_CoA, UC_CoA = getETU_UC_direct(directCoA, direct_lineages_CoA)
print('CoA: ', len(ETU_CoA), len(UC_CoA))
ETU_SAM, UC_SAM = getETU_UC_direct(directSAM, direct_lineages_SAM)
print('SAM: ', len(ETU_SAM), len(UC_SAM))
ETU_FAD, UC_FAD = getETU_UC_direct(directFAD, direct_lineages_FAD)
print('FAD: ', len(ETU_FAD), len(UC_FAD))
ETU_NAD, UC_NAD = getETU_UC_direct(directNAD, direct_lineages_NAD)
print('NAD: ', len(ETU_NAD), len(UC_NAD))
ETU_NADP, UC_NADP = getETU_UC_direct(directNADP, direct_lineages_NADP)
print('NADP:', len(ETU_NADP), len(UC_NADP))
ETU_PLP, UC_PLP = getETU_UC_direct(directPLP, direct_lineages_PLP)
print('PLP: ', len(ETU_PLP), len(UC_PLP))
ETU_ThDP, UC_ThDP = getETU_UC_direct(directThDP, direct_lineages_ThDP)
print('ThDP:', len(ETU_ThDP), len(UC_ThDP))
ETU_IPP, UC_IPP = getETU_UC_direct(directIPP, direct_lineages_IPP)
print('IPP: ', len(ETU_IPP), len(UC_IPP))
ETU_FMN, UC_FMN = getETU_UC_direct(directFMN, direct_lineages_FMN)
print('FMN: ', len(ETU_FMN), len(UC_FMN))
ETU_Cobalamin, UC_Cobalamin = getETU_UC_direct(directCobalamin, direct_lineages_Cobalamin)
print('Cobalamin: ', len(ETU_Cobalamin), len(UC_Cobalamin))
ETU_AcetylCoA, UC_AcetylCoA = getETU_UC_direct(directAcetylCoA, direct_lineages_AcetylCoA)
print('AcetylCoA: ', len(ETU_AcetylCoA), len(UC_AcetylCoA))
# Out:
# O2:   24 0
# ATP:  34 3
# CoA:  15 2
# SAM:  8 0
# FAD:  10 0
# NAD:  12 1
# NADP: 14 2
# PLP:  8 0
# ThDP: 2 0
# IPP:  0 0
# FMN:  4 1
# Cobalamin:  6 0
# AcetylCoA:  5 0

# %% [markdown]
# ### colored scatterplot => pie chart of ETU/LTU/NU

# %%
cpd2foMean = {}
cpd2foStd = {}
for x in df_cpds_folditer.index:
    cpd2foMean[x] = np.mean(df_cpds_folditer.loc[x])
    cpd2foStd[x] = np.std(df_cpds_folditer.loc[x])

# %%
cpd2foMean['C00007']
# Out:
# 307.151

# %%
def cofactorScatter(cid, title, x2rnFrac_cofactor_0, etu):
    print(title, pearson(x2foMean, x2rnFrac_cofactor_0))
    dict1 = x2foMean
    dict2 = x2rnFrac_cofactor_0
    valid_keys, data1, data2 = todata(dict1, dict2)

    colors = ['r' if key in etu else 'b' for key in valid_keys]

    plt.scatter(data1, data2, marker='o', color=colors, alpha = 0.1, label='Data Points', zorder=2)
    plt.axvline(x=cpd2foMean[cid], color='k', ls='--', lw=1)
    plt.xlabel('mean folditer')
    plt.ylabel(f'{title} rn fraction')
    
    # plt.savefig('cofactorScatter.svg', dpi=300, bbox_inches='tight')
    plt.show()

# %%
cofactorScatter('C00007', 'O2', x2rnFrac_O2_0, ETU_O2)
cofactorScatter('C00019', 'SAM', x2rnFrac_SAM_0, ETU_SAM)
cofactorScatter('C00002', 'ATP', x2rnFrac_ATP_0, ETU_ATP)
cofactorScatter('C00010', 'CoA', x2rnFrac_CoA_0, ETU_CoA)
cofactorScatter('C00016', 'FAD', x2rnFrac_FAD_0, ETU_FAD)
# Out:
# O2 (0.26497714053965304, '8.685304e-08')
# SAM (0.0732854527648617, '1.454728e-01')
# ATP (-0.014093526063696467, '7.797960e-01')
# CoA (0.007932391516128613, '8.749642e-01')
# FAD (0.07302791314496608, '1.468967e-01')

# %%
def getCategories(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc):
    emerge_to_use = set()  
    learn_to_use = set()
    unclassified = set()
    
    never_use_direct = set() # direct/total == 0
    never_use = set()  # direct/total == 0; indirect/total == 0; 'orthogonal'
    indirect_use = set() # direct/total == 0; indirect/total > 0

    for x, frac in x2rnFrac_cofactor_0.items():  # direct/total
        if frac == 0:
             never_use_direct.add(x)
        else:
            if x in etu:
                emerge_to_use.add(x)
            elif x in unc:
                unclassified.add(x)
            else:
                learn_to_use.add(x)  # here we don't check the direction...
    
    for x, frac in x2rnFrac_cofactor_1.items():  # indirect/total
        if x in never_use_direct and frac == 0:
             never_use.add(x)
        else:
            indirect_use.add(x)
    
    indirect_use_only = indirect_use - (emerge_to_use|learn_to_use|unclassified)
    return never_use, indirect_use_only, emerge_to_use, unclassified, learn_to_use

# %%
def getCategories_using(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc, using):
    
    emerge_to_use = set()  
    learn_to_use = set()
    unclassified = set()
    
    never_use_direct = set() # direct/total == 0
    never_use = set()  # direct/total == 0; indirect/total == 0; 'orthogonal'
    indirect_use = set() # direct/total == 0; indirect/total > 0

    for x, frac in x2rnFrac_cofactor_0.items():  # direct/total
        if frac == 0:
             never_use_direct.add(x)
        else:
            if x in etu:
                emerge_to_use.add(x)
            elif x in unc:
                unclassified.add(x)
            else:
                # x has using rn
                if len(set(x2rn_scope[x]) & set(using)) != 0:
                    learn_to_use.add(x)
                # producing only
                else:
                    indirect_use.add(x)
                
    
    for x, frac in x2rnFrac_cofactor_1.items():  # indirect/total
        if x in never_use_direct and frac == 0:
             never_use.add(x)
        else:
            indirect_use.add(x)
    
    indirect_use_only = indirect_use - (emerge_to_use|learn_to_use|unclassified)
    return never_use, indirect_use_only, emerge_to_use, unclassified, learn_to_use

# %%
def drawPie(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc, title):
    never_use, indirect_use, emerge_to_use, unclassified, learn_to_use = getCategories(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc)
    
    labels = ['never_use', 'indirect_use', 'learn_to_use', 'unclassified', 'emerge_to_use']
    values = [len(never_use), len(indirect_use), len(learn_to_use), len(unclassified), len(emerge_to_use)]
    colors = ['gray', 'lightgray', 'lightblue', '#f94449', 'red']
#     hatches = ['', '', '', '.', '']

    fig, ax = plt.subplots(figsize=(4, 4))
    wedges, texts, autotexts = ax.pie(values, colors=colors, autopct=lambda p: '{:.0f}% ({:.0f})'.format(p, p * sum(values) / 100), startangle=90, labeldistance=1.05)
    plt.title(f'{title} n={sum(values)}')
    # plt.savefig(f'piechart_cofactor_{title}.svg', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def drawPie_using(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc, title, using):
    never_use, indirect_use, emerge_to_use, unclassified, learn_to_use = getCategories_using(x2rnFrac_cofactor_0, x2rnFrac_cofactor_1, etu, unc, using)
    
    labels = ['never_use', 'indirect_use', 'learn_to_use', 'unclassified', 'emerge_to_use']
    values = [len(never_use), len(indirect_use), len(learn_to_use), len(unclassified), len(emerge_to_use)]
    colors = ['gray', 'lightgray', 'lightblue', '#f94449', 'red']
#     hatches = ['', '', '', '.', '']

    fig, ax = plt.subplots(figsize=(4, 4))
    wedges, texts, autotexts = ax.pie(values, colors=colors, autopct=lambda p: '{:.0f}% ({:.0f})'.format(p, p * sum(values) / 100), startangle=90, labeldistance=1.05)
    plt.title(f'{title} n={sum(values)}')
    # plt.savefig(f'piechart_cofactor_{title}.svg', dpi=300, bbox_inches='tight')
    plt.show()

# %%
drawPie_using(x2rnFrac_O2_0, x2rnFrac_O2_1, ETU_O2, UC_O2, 'O2', using)
# drawPie(x2rnFrac_ATP_0, x2rnFrac_ATP_1, ETU_ATP, UC_ATP, 'ATP')
# drawPie(x2rnFrac_SAM_0, x2rnFrac_SAM_1, ETU_SAM, UC_SAM, 'SAM')
# drawPie(x2rnFrac_CoA_0, x2rnFrac_CoA_1, ETU_CoA, UC_CoA, 'CoA')
# drawPie(x2rnFrac_FAD_0, x2rnFrac_FAD_1, ETU_FAD, UC_FAD, 'FAD')

# %% [markdown]
# ### stackplots instead

# %%
# Define categories, values, and colors
categories = ['never_use', 'indirect_use', 'emerge_to_use', 'unclassified', 'learn_to_use']
colors = ['gray', 'skyblue', 'red', '#f94449', 'pink']

# %%
NU_O2, IU_O2, ETU_O2, UC_O2, LTU_O2 =getCategories_using(x2rnFrac_O2_0, x2rnFrac_O2_1, ETU_O2, UC_O2, using)
NU_ATP, IU_ATP, ETU_ATP, UC_ATP, LTU_ATP =getCategories(x2rnFrac_ATP_0, x2rnFrac_ATP_1, ETU_ATP, UC_ATP)
NU_SAM, IU_SAM, ETU_SAM, UC_SAM, LTU_SAM =getCategories(x2rnFrac_SAM_0, x2rnFrac_SAM_1, ETU_SAM, UC_SAM)
NU_CoA, IU_CoA, ETU_CoA, UC_CoA, LTU_CoA =getCategories(x2rnFrac_CoA_0, x2rnFrac_CoA_1, ETU_CoA, UC_CoA)
NU_FAD, IU_FAD, ETU_FAD, UC_FAD, LTU_FAD =getCategories(x2rnFrac_FAD_0, x2rnFrac_FAD_1, ETU_FAD, UC_FAD)

NU_NAD, IU_NAD, ETU_NAD, UC_NAD, LTU_NAD =getCategories(x2rnFrac_NAD_0, x2rnFrac_NAD_1, ETU_NAD, UC_NAD)
NU_NADP, IU_NADP, ETU_NADP, UC_NADP, LTU_NADP =getCategories(x2rnFrac_NADP_0, x2rnFrac_NADP_1, ETU_NADP, UC_NADP)
NU_PLP, IU_PLP, ETU_PLP, UC_PLP, LTU_PLP =getCategories(x2rnFrac_PLP_0, x2rnFrac_PLP_1, ETU_PLP, UC_PLP)
NU_ThDP, IU_ThDP, ETU_ThDP, UC_ThDP, LTU_ThDP =getCategories(x2rnFrac_ThDP_0, x2rnFrac_ThDP_1, ETU_ThDP, UC_ThDP)

NU_IPP, IU_IPP, ETU_IPP, UC_IPP, LTU_IPP =getCategories(x2rnFrac_IPP_0, x2rnFrac_IPP_1, ETU_IPP, UC_IPP)
NU_FMN, IU_FMN, ETU_FMN, UC_FMN, LTU_FMN =getCategories(x2rnFrac_FMN_0, x2rnFrac_FMN_1, ETU_FMN, UC_FMN)
NU_Cobalamin, IU_Cobalamin, ETU_Cobalamin, UC_Cobalamin, LTU_Cobalamin =getCategories(x2rnFrac_Cobalamin_0, x2rnFrac_Cobalamin_1, ETU_Cobalamin, UC_Cobalamin)
NU_AcetylCoA, IU_AcetylCoA, ETU_AcetylCoA, UC_AcetylCoA, LTU_AcetylCoA =getCategories(x2rnFrac_AcetylCoA_0, x2rnFrac_AcetylCoA_1, ETU_AcetylCoA, UC_AcetylCoA)

# %%
print('    ETU   LTU   UC ')
print('------------------------')

print('O2  ', len(ETU_O2), '  ', len(LTU_O2), '  ', len(UC_O2))
print('ATP ', len(ETU_ATP), '  ', len(LTU_ATP), '  ', len(UC_ATP))
print('CoA  ', len(ETU_CoA), '  ', len(LTU_CoA), '  ', len(UC_CoA))
print('SAM ', len(ETU_SAM), '  ', len(LTU_SAM), '  ', len(UC_SAM))
print('FAD ', len(ETU_FAD), '  ', len(LTU_FAD), '  ', len(UC_FAD))
print('NAD ', len(ETU_NAD), '  ', len(LTU_NAD), '  ', len(UC_NAD))
print('NADP', len(ETU_NADP), '  ', len(LTU_NADP), '  ', len(UC_NADP))
print('PLP ', len(ETU_PLP), '  ', len(LTU_PLP), '  ', len(UC_PLP))
print('ThDP ', len(ETU_ThDP), '  ', len(LTU_ThDP), '  ', len(UC_ThDP))
# Out:
#     ETU   LTU   UC
# ------------------------
# O2   24    62    0
# ATP  34    95    3
# CoA   15    62    2
# SAM  8    32    0
# FAD  10    79    0
# NAD  12    114    1
# NADP 14    104    2
# PLP  8    33    0
# ThDP  2    20    0

# %%
# a = [-len(IU_PLP), -len(IU_ATP), -len(IU_NAD), -len(IU_NADP), -len(IU_CoA), -len(IU_AcetylCoA), -len(IU_IPP), -len(IU_SAM), -len(IU_ThDP), -len(IU_FAD), -len(IU_FMN), -len(IU_Cobalamin), -len(IU_O2)] 
# b = [-len(NU_PLP), -len(NU_ATP), -len(NU_NAD), -len(NU_NADP), -len(NU_CoA), -len(NU_AcetylCoA), -len(NU_IPP), -len(NU_SAM), -len(NU_ThDP), -len(NU_FAD),  -len(NU_FMN), -len(NU_Cobalamin), -len(NU_O2)]  
# c = [len(LTU_PLP), len(LTU_ATP), len(LTU_NAD), len(LTU_NADP), len(LTU_CoA), len(LTU_AcetylCoA), len(LTU_IPP), len(LTU_SAM), len(LTU_ThDP), len(LTU_FAD), len(LTU_FMN),  len(LTU_Cobalamin), len(LTU_O2)]
# d = [len(UC_PLP), len(UC_ATP), len(UC_NAD), len(UC_NADP), len(UC_CoA), len(UC_AcetylCoA), len(UC_IPP), len(UC_SAM), len(UC_ThDP), len(UC_FAD), len(UC_FMN), len(UC_Cobalamin), len(UC_O2)]
# e = [len(ETU_PLP), len(ETU_ATP), len(ETU_NAD), len(ETU_NADP), len(ETU_CoA), len(ETU_AcetylCoA), len(ETU_IPP), len(ETU_SAM), len(ETU_ThDP), len(ETU_FAD), len(ETU_FMN),  len(ETU_Cobalamin), len(ETU_O2)]

a = [-len(IU_PLP), -len(IU_ATP), -len(IU_NAD), -len(IU_CoA), -len(IU_IPP), -len(IU_SAM), -len(IU_ThDP), -len(IU_FAD), -len(IU_O2)] 
b = [-len(NU_PLP), -len(NU_ATP), -len(NU_NAD), -len(NU_CoA), -len(NU_IPP), -len(NU_SAM), -len(NU_ThDP), -len(NU_FAD), -len(NU_O2)]  
c = [len(LTU_PLP), len(LTU_ATP), len(LTU_NAD), len(LTU_CoA), len(LTU_IPP), len(LTU_SAM), len(LTU_ThDP), len(LTU_FAD), len(LTU_O2)]
d = [len(UC_PLP), len(UC_ATP), len(UC_NAD), len(UC_CoA), len(UC_IPP), len(UC_SAM), len(UC_ThDP), len(UC_FAD), len(UC_O2)]
e = [len(ETU_PLP), len(ETU_ATP), len(ETU_NAD), len(ETU_CoA), len(ETU_IPP), len(ETU_SAM), len(ETU_ThDP), len(ETU_FAD), len(ETU_O2)]


data = np.array([a, b, c, d, e])
# data = np.array([a, c, d, e])
data_shape = np.shape(data)

# Take negative and positive data apart and cumulate
def get_cumulated_array(data, **kwargs):
    cum = data.clip(**kwargs)
    cum = np.cumsum(cum, axis=0)
    d = np.zeros(np.shape(data))
    d[1:] = cum[:-1]
    return d  

cumulated_data = get_cumulated_array(data, min=0)
cumulated_data_neg = get_cumulated_array(data, max=0)

# Re-merge negative and positive data.
row_mask = (data<0)
cumulated_data[row_mask] = cumulated_data_neg[row_mask]
data_stack = cumulated_data

cols = ["#bebebe", "gray", "skyblue", "pink", 'red']
# cols = ["skyblue", "pink", "orange", 'red']

fig = plt.figure()
ax = plt.subplot(111)

bar_width = 0.2  # Adjust this value to make the bars narrower

for i in np.arange(0, data_shape[0]):
    ax.bar(np.arange(data_shape[1]), data[i], bottom=data_stack[i], color=cols[i], width=bar_width)

# Custom x-axis labels
# x_labels = ['PLP', 'ATP', 'NAD', 'NADP', 'CoA', 'A-CoA', 'IPP', 'SAM', 'ThDP', 'FAD', 'FMN', 'Cobalamin', 'O2']  # Replace with your custom labels
x_labels = ['PLP', 'ATP', 'NAD', 'CoA', 'IPP', 'SAM', 'ThDP', 'FAD', 'O2']  # Replace with your custom labels
ax.set_xticks(np.arange(data_shape[1]))
ax.set_xticklabels(x_labels)

# plt.savefig('cofactor_stacked_bars.svg', dpi=300, bbox_inches='tight')
# plt.savefig('cofactor_stacked_bars_no_neveruse.svg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### look for all cpds for high-ETU/LTU cpds

# %%
# this takes a while if you use getETU_UC_using

# cpd2ETUlineages = {}
# cpd2LTUlineages = {}
# for cpd in result.scope.cpds:  # for all compounds discovered in our simulation
#     print(len(cpd2ETUlineages), cpd)  # log for progress
    
#     # get direct cpd-using reactions within scope
#     direct_cofactor_rn_set = getDirectRns(cpd) & set(result.scope.rns)  
    
#     # get ETU lineages
#     if cpd.startswith('C'):
#         ETU, UC = getETU_UC_using(cpd, direct_cofactor_rn_set)  # excludes cofactor-producing rns

#         # redefine direct_cofactor_rn_set to exclude cofactor-producing rns
#         run = '87452'
#         using, both, producing = getUsingProducingRns(run, cpd, direct_cofactor_rn_set)
#         direct_cofactor_rn_set = set(using) | set(both.keys())
#     else:  # Z cpds
#         ETU, UC = getETU_UC_direct(direct_cofactor_rn_set)
#     cpd2ETUlineages[cpd] = ETU

#     # get LTU lineages
#     directLineages = set()
#     for x, rns in x2rn_scope.items():  # check each lineage and their reactions
#         for rn in rns:
#             if rn in direct_cofactor_rn_set:  # using or both, not produce
#                 directLineages.add(x)
#                 break
#     cpd2LTUlineages[cpd] = directLineages - ETU  # includes UC

# dict2csv(cpd2ETUlineages, '../data/assets/cpd2ETUlineages_preATP_getETU_UC_using_strict.csv')
# dict2csv(cpd2LTUlineages, '../data/assets/cpd2LTUlineages_preATP_getETU_UC_using_strict.csv')

# %%
cpd2ETUlineages = csv2dict('../data/assets/cpd2ETUlineages_preATP_getETU_UC_using_strict.csv')
cpd2LTUlineages = csv2dict('../data/assets/cpd2LTUlineages_preATP_getETU_UC_using_strict.csv')

cpd2ETUlineagesNum = {k:len(v) for k,v in cpd2ETUlineages.items()}
cpd2LTUlineagesNum = {k:len(v) for k,v in cpd2LTUlineages.items()}

# %%
histogram(cpd2ETUlineagesNum, bins=100, x_axis='Number of lineages that emerge to use cpd', ylog=True)
histogram(cpd2LTUlineagesNum, bins=100, x_axis='#lineages that learn to use compound', ylog=True)

# %%
cpd2LTUlineagesNum['C00007']
# Out:
# 62

# %%
for k,v in cpd2ETUlineagesNum.items():
    if v > 10:
        print(k, cpd2name[k], v)
# Out:
# C00009 Orthophosphate 13
# C00005 NADPH 11
# Z00015 Iron 15
# C00080 H+ 41
# C00011 CO2 18
# C00002 ATP 32
# C00008 ADP 19
# C00001 H2O 93
# Z00025 Heme 12
# Z00029 Mg 13
# Z00054 Zinc 11
# C00007 Oxygen 24
# C00013 Diphosphate 13

# %%
# top LTU cpds
{(cpd2name.get(k, 'no name'), k): v for k, v in sorted(cpd2LTUlineagesNum.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {('Mg', 'Z00029'): 156,
#  ('H2O', 'C00001'): 145,
#  ('Mn', 'Z00030'): 143,
#  ('H+', 'C00080'): 123,
#  ('Zinc', 'Z00054'): 117,
#  ('ATP', 'C00002'): 96,
#  ('Iron', 'Z00015'): 91,
#  ('NADPH', 'C00005'): 87,
#  ('NADH', 'C00004'): 87,
#  ('NAD+', 'C00003'): 81,
#  ('NADP+', 'C00006'): 79,
#  ('FAD', 'Z00013'): 78,
#  ('CO2', 'C00011'): 77,
#  ('Orthophosphate', 'C00009'): 73,
#  ('Flavoprotein', 'Z00019'): 72,
#  ('Divalent Metal (M2)', 'Z00069'): 72,
#  ('Cobalt', 'Z00006'): 72,
#  ('Calcium', 'Z00055'): 70,
#  ('ADP', 'C00008'): 70,
#  ('4Fe4S', 'Z00002'): 68,
#  ('NAD/NADP', 'Z00032'): 67,
#  ('CoA', 'C00010'): 64,
#  ('Ammonia', 'C00014'): 63,
#  ('Diphosphate', 'C00013'): 63,
#  ('FMN', 'Z00014'): 62,
#  ('Oxygen', 'C00007'): 62,
#  ('Generic FeS', 'Z00063'): 61,
#  ('AMP', 'C00020'): 60,
#  ('Acetyl-CoA', 'C00024'): 60,
#  ('Reduced ferredoxin', 'C00138'): 49,
#  ('Nickel', 'Z00034'): 49,
#  ('Heme', 'Z00025'): 46,
#  ('L-Glutamate', 'C00025'): 44,
#  ('Oxidized ferredoxin', 'C00139'): 44,
#  ('Acceptor', 'C00028'): 38,
#  ('GTP', 'C00044'): 35,
#  ('Pyruvate', 'C00022'): 35,
#  ('Propanoyl-CoA', 'C00100'): 34,
#  ('Copper', 'Z00070'): 34,
#  ('2-Oxoglutarate', 'C00026'): 33,
#  ('2Fe2S', 'Z00001'): 32,
#  ('PLP', 'Z00035'): 31,
#  ('L-Glutamine', 'C00064'): 31,
#  ('L-Aspartate', 'C00049'): 30,
#  ('K (Potassium)', 'Z00026'): 29,
#  ('Tetrahydrofolate', 'C00101'): 29,
#  ('S-Adenosyl-L-methionine', 'C00019'): 29,
#  ('L-Arginine', 'C00062'): 28,
#  ('S-Adenosyl-L-homocysteine', 'C00021'): 27,
#  ('HCO3-', 'C00288'): 27,
#  ('Reduced acceptor', 'C00030'): 26,
#  ('Malonyl-CoA', 'C00083'): 26,
#  ('Ubiquinone', 'C00399'): 25,
#  ('CTP', 'C00063'): 24,
#  ('Quinone', 'C15602'): 24,
#  ('Ferricytochrome c', 'C00125'): 24,
#  ('L-Cysteine', 'C00097'): 24,
#  ('GDP', 'C00035'): 23,
#  ('Phosphopantetheine', 'Z00038'): 23,
#  ('L-Serine', 'C00065'): 23,
#  ('Acetate', 'C00033'): 23,
#  ('FAD', 'C00016'): 22,
#  ('D-Glucose', 'C00031'): 22,
#  ('Acyl-carrier protein', 'C00229'): 22,
#  ('Glycerone phosphate', 'C00111'): 22,
#  ('Formate', 'C00058'): 21,
#  ('Molybdenum', 'Z00064'): 21,
#  ('Benzoyl-CoA', 'C00512'): 21,
#  ('Succinyl-CoA', 'C00091'): 21,
#  ('Glycine', 'C00037'): 21,
#  ('Anthranilate', 'C00108'): 21,
#  ('Oxaloacetate', 'C00036'): 21,
#  ('UTP', 'C00075'): 20,
#  ('UDP', 'C00015'): 20,
#  ('Butanoyl-CoA', 'C00136'): 20,
#  ('Phosphoenolpyruvate', 'C00074'): 20,
#  ('Molybdopterin', 'Z00031'): 19,
#  ('L-Lysine', 'C00047'): 19,
#  ('IMP', 'C00130'): 19,
#  ('Succinate', 'C00042'): 19,
#  ('Palmitoyl-CoA', 'C00154'): 19,
#  ('Nicotinate D-ribonucleotide', 'C01185'): 19,
#  ('Sulfite', 'C00094'): 19,
#  ('L-Tyrosine', 'C00082'): 18,
#  ('Tungstopterin', 'Z00059'): 18,
#  ('Ferrocytochrome c', 'C00126'): 18,
#  ('FADH2', 'C01352'): 18,
#  ('2-Methylpropanoyl-CoA', 'C00630'): 17,
#  ('Hydrogen', 'C00282'): 17,
#  ('3Fe4S', 'Z00067'): 17,
#  ('Hydrogen sulfide', 'C00283'): 17,
#  ('Acetoacetate', 'C00164'): 17,
#  ('Acetaldehyde', 'C00084'): 17,
#  ('Fumarate', 'C00122'): 17,
#  ('CDP', 'C00112'): 17,
#  ('Acyl-[acyl-carrier protein]', 'C00173'): 17,
#  ('Benzoate', 'C00180'): 16,
#  ('L-Histidine', 'C00135'): 16,
#  ('Phosphatidylethanolamine', 'C00350'): 16,
#  ('D-Fructose 6-phosphate', 'C00085'): 16,
#  ('L-Proline', 'C00148'): 16,
#  ('1-Phosphatidyl-D-myo-inositol', 'C01194'): 16,
#  ('Aldehyde', 'C00071'): 16,
#  ('10-Formyltetrahydrofolate', 'C00234'): 16,
#  ('Thiamine diphosphate', 'Z00047'): 16,
#  ('L-Tryptophan', 'C00078'): 15,
#  ('Hydroquinone', 'C15603'): 15,
#  ('Coenzyme F420', 'C00876'): 15,
#  ('D-Ribulose 5-phosphate', 'C00199'): 15,
#  ('FMN', 'C00061'): 15,
#  ('CMP', 'C00055'): 15,
#  ('(S)-Malate', 'C00149'): 15,
#  ('GMP', 'C00144'): 15,
#  ('Ferredoxin', 'Z00016'): 15,
#  ('Nitrite', 'C00088'): 15,
#  ('D-Glyceraldehyde', 'C00577'): 15,
#  ('Methanol', 'C00132'): 15,
#  ('Pyruvoyl', 'Z00039'): 15,
#  ('beta-D-Fructose 6-phosphate', 'C05345'): 15,
#  ('L-Alanine', 'C00041'): 15,
#  ('Glycerone', 'C00184'): 15,
#  ('Thioredoxin', 'C00342'): 14,
#  ('ACP', 'Z00003'): 14,
#  ('L-Methionine', 'C00073'): 14,
#  ('Coenzyme A', 'Z00051'): 14,
#  ('(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]', 'C05757'): 14,
#  ('Phosphoprotein', 'C00562'): 14,
#  ('Reduced coenzyme F420', 'C01080'): 14,
#  ('(3R)-3-Hydroxytetradecanoyl-[acyl-carrier protein]', 'C04688'): 14,
#  ('1-Phosphatidyl-D-myo-inositol 4,5-bisphosphate', 'C04637'): 14,
#  ('Thioredoxin disulfide', 'C00343'): 14,
#  ('Octanoyl-[acp]', 'C05752'): 14,
#  ('Malonyl-[acyl-carrier protein]', 'C01209'): 14,
#  ('Generic Flavin', 'Z00021'): 14,
#  ('(3R)-3-Hydroxyoctanoyl-[acyl-carrier protein]', 'C04620'): 14,
#  ('2-Oxobutanoate', 'C00109'): 14,
#  ('(3R)-3-Hydroxyhexanoyl-[acyl-carrier protein]', 'C05747'): 14,
#  ('Stearoyl-CoA', 'C00412'): 14,
#  ('5,6,7,8-Tetrahydromethanopterin', 'C01217'): 14,
#  ('(3R)-3-Hydroxybutanoyl-[acyl-carrier protein]', 'C04618'): 14,
#  ('L-Isoleucine', 'C00407'): 14,
#  ('(3R)-3-Hydroxypalmitoyl-[acyl-carrier protein]', 'C04633'): 14,
#  ('1,2-Diacyl-sn-glycerol', 'C00641'): 14,
#  ('L-Ornithine', 'C00077'): 14,
#  ('(3R)-3-Hydroxydecanoyl-[acyl-carrier protein]', 'C04619'): 14,
#  ('Tungsten', 'Z00053'): 14,
#  ('L-Phenylalanine', 'C00079'): 13,
#  ('Cytochrome', 'Z00010'): 13,
#  ('Biotin', 'Z00005'): 13,
#  ('Hexanoyl-[acp]', 'C05749'): 13,
#  ('Decanoyl-[acp]', 'C05755'): 13,
#  ('Putrescine', 'C00134'): 13,
#  ('UDP-glucose', 'C00029'): 13,
#  ('D-Glucose 6-phosphate', 'C00092'): 13,
#  ('Dodecanoyl-[acyl-carrier protein]', 'C05223'): 13,
#  ('Nitric oxide', 'C00533'): 13,
#  ('Glycerol', 'C00116'): 13,
#  ('Adenine', 'C00147'): 13,
#  ('UMP', 'C00105'): 13,
#  ('Acetyl-[acyl-carrier protein]', 'C03939'): 13,
#  ('Acyl-CoA', 'C00040'): 13,
#  ('5-Methyltetrahydrofolate', 'C00440'): 13,
#  ('Butyryl-[acp]', 'C05745'): 13,
#  ('1-Phosphatidyl-1D-myo-inositol 4-phosphate', 'C01277'): 13,
#  ('D-Ribose 5-phosphate', 'C00117'): 13,
#  ('CO', 'C00237'): 13,
#  ('Salicylate', 'C00805'): 13,
#  ('Succinate semialdehyde', 'C00232'): 13,
#  ('Nicotinate', 'C00253'): 13,
#  ('D-Glyceraldehyde 3-phosphate', 'C00118'): 13,
#  ('Generic quinone', 'Z00022'): 13,
#  ('Thiosulfate', 'C00320'): 13,
#  ('D-Fructose', 'C00095'): 13,
#  ('Tetradecanoyl-[acp]', 'C05761'): 13,
#  ('(S)-Methylmalonyl-CoA', 'C00683'): 13,
#  ('Propenoyl-CoA', 'C00894'): 12,
#  ('Uracil', 'C00106'): 12,
#  ('Toluene', 'C01455'): 12,
#  ('3-Oxodecanoyl-[acp]', 'C05753'): 12,
#  ('1-Phosphatidyl-1D-myo-inositol 3-phosphate', 'C04549'): 12,
#  ('4-Hydroxybenzoate', 'C00156'): 12,
#  ('Acetoacetyl-[acp]', 'C05744'): 12,
#  ('trans-Cinnamate', 'C00423'): 12,
#  ('5-Phospho-alpha-D-ribose 1-diphosphate', 'C00119'): 12,
#  ('Glyoxylate', 'C00048'): 12,
#  ('3-Oxopropanoate', 'C00222'): 12,
#  ('Deoxyuridine', 'C00526'): 12,
#  ("Pantetheine 4'-phosphate", 'C01134'): 12,
#  ('Phosphatidylinositol-3,4,5-trisphosphate', 'C05981'): 12,
#  ('Phosphatidylcholine', 'C00157'): 12,
#  ('3-Oxohexanoyl-[acp]', 'C05746'): 12,
#  ('2-Oxoadipate', 'C00322'): 12,
#  ('Hypoxanthine', 'C00262'): 12,
#  ('alpha-D-Glucose', 'C00267'): 12,
#  ('Selenite', 'C05684'): 12,
#  ('beta-Alanine', 'C00099'): 12,
#  ('Cytidine', 'C00475'): 12,
#  ('sn-Glycerol 3-phosphate', 'C00093'): 12,
#  ('3-Oxododecanoyl-[acp]', 'C05756'): 12,
#  ('3-Oxohexadecanoyl-[acp]', 'C05762'): 12,
#  ('Chorismate', 'C00251'): 12,
#  ('3-Phospho-D-glycerate', 'C00197'): 12,
#  ('Adenosine', 'C00212'): 12,
#  ('Uridine', 'C00299'): 12,
#  ('Nicotinamide D-ribonucleotide', 'C00455'): 12,
#  ('3-Methyl-2-oxobutanoic acid', 'C00141'): 12,
#  ('5,10-Methylenetetrahydrofolate', 'C00143'): 12,
#  ('Urea', 'C00086'): 12,
#  ('Adenylyl sulfate', 'C00224'): 12,
#  ('Phenol', 'C00146'): 12,
#  ('3-Oxooctanoyl-[acp]', 'C05750'): 12,
#  ('3-Oxotetradecanoyl-[acp]', 'C05759'): 12,
#  ('ITP', 'C00081'): 11,
#  ('D-Glutamate', 'C00217'): 11,
#  ('Enzyme N6-(dihydrolipoyl)lysine', 'C15973'): 11,
#  ('Phenylacetyl-CoA', 'C00582'): 11,
#  ('Carbamate', 'C01563'): 11,
#  ('Ethylbenzene', 'C07111'): 11,
#  ('Xanthine', 'C00385'): 11,
#  ('L-Valine', 'C00183'): 11,
#  ('dCDP', 'C00705'): 11,
#  ('Glutathione', 'C00051'): 11,
#  ('But-2-enoyl-[acyl-carrier protein]', 'C04246'): 11,
#  ('dADP', 'C00206'): 11,
#  ('Glutaryl-CoA', 'C00527'): 11,
#  ('Carbamoyl phosphate', 'C00169'): 11,
#  ('THF (H4F)', 'Z00046'): 11,
#  ('dGTP', 'C00286'): 11,
#  ('trans-Dec-2-enoyl-[acp]', 'C05754'): 11,
#  ('Spermidine', 'C00315'): 11,
#  ('IDP', 'C00104'): 11,
#  ('myo-Inositol', 'C00137'): 11,
#  ('Thymidine', 'C00214'): 11,
#  ('Acetophenone', 'C07113'): 11,
#  ('L-2-Aminoadipate 6-semialdehyde', 'C04076'): 11,
#  ('3-Hydroxypropanoate', 'C01013'): 11,
#  ('dCMP', 'C00239'): 11,
#  ('Formaldehyde', 'C00067'): 11,
#  ("3',5'-Cyclic AMP", 'C00575'): 11,
#  ('Cadaverine', 'C01672'): 11,
#  ('D-Sorbitol', 'C00794'): 11,
#  ('Fe2+', 'C14818'): 11,
#  ('Ubiquinol', 'C00390'): 11,
#  ("Xanthosine 5'-phosphate", 'C00655'): 11,
#  ('Riboflavin', 'C00255'): 11,
#  ('Phenylpyruvate', 'C00166'): 11,
#  ('p-Coumaroyl-CoA', 'C00223'): 11,
#  ('D-Glycerate', 'C00258'): 11,
#  ("3',5'-Cyclic GMP", 'C00942'): 11,
#  ('Choline', 'C00114'): 11,
#  ('trans-Tetradec-2-enoyl-[acp]', 'C05760'): 10,
#  ('Thymine', 'C00178'): 10,
#  ('D-Glucose 1-phosphate', 'C00103'): 10,
#  ('(2S)-Ethylmalonyl-CoA', 'C18026'): 10,
#  ('Sucrose', 'C00089'): 10,
#  ('Dopamine', 'C03758'): 10,
#  ('trans-Oct-2-enoyl-[acp]', 'C05751'): 10,
#  ('Methane', 'C01438'): 10,
#  ('Acetone', 'C00207'): 10,
#  ('trans-Hex-2-enoyl-[acp]', 'C05748'): 10,
#  ("2'-(5-triphosphoribosyl)-3'-dephospho-CoA", 'Z00066'): 10,
#  ('Pyridoxal', 'C00250'): 10,
#  ('Pantetheine', 'Z00037'): 10,
#  ('trans-Hexadec-2-enoyl-[acp]', 'C05763'): 10,
#  ('trans-2,3-Dehydroacyl-[acyl-carrier protein]', 'C00693'): 10,
#  ('Menaquinone', 'C00828'): 10,
#  ('UDP-N-acetyl-alpha-D-glucosamine', 'C00043'): 10,
#  ('dUMP', 'C00365'): 10,
#  ('2,3-Dehydroacyl-CoA', 'C00605'): 10,
#  ('3-Methylbutanoyl-CoA', 'C02939'): 10,
#  ('Ethanol', 'C00469'): 10,
#  ('Flavodoxin', 'Z00018'): 10,
#  ('Cobalamin', 'Z00009'): 10,
#  ('Phenylpropanoate', 'C05629'): 10,
#  ('Hydrogen peroxide', 'C00027'): 10,
#  ('Caffeoyl-CoA', 'C00323'): 10,
#  ('5,10-Methenyltetrahydrofolate', 'C00445'): 10,
#  ('Styrene', 'C07083'): 10,
#  ('dGDP', 'C00361'): 10,
#  ('dATP', 'C00131'): 10,
#  ('dTMP', 'C00364'): 10,
#  ('3-Hydroxypropionyl-CoA', 'C05668'): 10,
#  ('Hexadecanoyl-[acp]', 'C05764'): 10,
#  ('D-Ornithine', 'C00515'): 10,
#  ('trans-Dodec-2-enoyl-[acp]', 'C05758'): 10,
#  ('Methylmalonate', 'C02170'): 10,
#  ('Nicotinamide-beta-riboside', 'C03150'): 10,
#  ('Maltose', 'C00208'): 10,
#  ('Retinal', 'C00376'): 10,
#  ('Acetoacetyl-CoA', 'C00332'): 9,
#  ('Gallate', 'C01424'): 9,
#  ('dCTP', 'C00458'): 9,
#  ('Ascorbate', 'C00072'): 9,
#  ('Agmatine', 'C00179'): 9,
#  ('Indole-3-acetate', 'C00954'): 9,
#  ('D-Alanine', 'C00133'): 9,
#  ('(S)-2-Methylbutanoyl-CoA', 'C15980'): 9,
#  ('Crotonoyl-CoA', 'C00877'): 9,
#  ("1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide", 'C04677'): 9,
#  ("5'-Phosphoribosyl-N-formylglycinamide", 'C04376'): 9,
#  ('Inosine', 'C00294'): 9,
#  ('Dihydromethanophenazine', 'C11904'): 9,
#  ('Deamino-NAD+', 'C00857'): 9,
#  ('meso-2,6-Diaminoheptanedioate', 'C00680'): 9,
#  ('Ferrocytochrome', 'C00924'): 9,
#  ('2-Oxo acid', 'C00161'): 9,
#  ('Ferulate', 'C01494'): 9,
#  ('4-Hydroxybenzoyl-[acp]', 'C21505'): 9,
#  ('3-Methylcrotonyl-CoA', 'C03069'): 9,
#  ('Benzyl alcohol', 'C00556'): 9,
#  ('alpha-D-Ribose 1-phosphate', 'C00620'): 9,
#  ('Cys-Gly', 'C01419'): 9,
#  ('L-Aspartate 4-semialdehyde', 'C00441'): 9,
#  ('Eicosanoyl-CoA', 'C02041'): 9,
#  ('Dimethylamine', 'C00543'): 9,
#  ('Oxalate', 'C00209'): 9,
#  ('dUTP', 'C00460'): 9,
#  ('1-Phosphatidyl-1D-myo-inositol 3,4-bisphosphate', 'C11554'): 9,
#  ('Thiamin diphosphate', 'C00068'): 9,
#  ('17-(4-Hydroxyphenyl)heptadecanoyl-[acp]', 'C21506'): 9,
#  ('D-Galactose', 'C00124'): 9,
#  ('3,4-Dihydroxybenzoate', 'C00230'): 9,
#  ('19-(4-Hydroxyphenyl)nonadecanoyl-[acp]', 'C21507'): 9,
#  ('N-Carbamoyl-L-aspartate', 'C00438'): 9,
#  ('L-Homoserine', 'C00263'): 9,
#  ('N-Acetyl-D-glucosamine', 'C00140'): 9,
#  ('4-Hydroxybenzoyl-CoA', 'C02949'): 9,
#  ('4-Hydroxybutyryl-CoA', 'C11062'): 9,
#  ('4-Hydroxybutanoic acid', 'C00989'): 9,
#  ('Nicotinate D-ribonucleoside', 'C05841'): 9,
#  ('alpha-Amino acid', 'C05167'): 9,
#  ('Cytosine', 'C00380'): 9,
#  ('L-Asparagine', 'C00152'): 9,
#  ('Feruloyl-CoA', 'C00406'): 9,
#  ('Methanesulfonic acid', 'C11145'): 9,
#  ('L-2-Aminoadipate', 'C00956'): 9,
#  ('2,3-Dihydroxybenzoate', 'C00196'): 9,
#  ('beta-D-Glucose', 'C00221'): 9,
#  ('4-Aminobutanoate', 'C00334'): 9,
#  ('Methanophenazine', 'C11903'): 9,
#  ('Coenzyme M', 'C03576'): 9,
#  ('3-(4-Hydroxyphenyl)pyruvate', 'C01179'): 9,
#  ('Methylamine', 'C00218'): 8,
#  ('Indole-3-acetaldehyde', 'C00637'): 8,
#  ('Itaconate', 'C00490'): 8,
#  ('Urate', 'C00366'): 8,
#  ('Methyl-Co(III) corrinoid protein', 'C06020'): 8,
#  ('L-Glutamate 5-semialdehyde', 'C01165'): 8,
#  ('Sodium', 'Z00033'): 8,
#  ('Siroheme', 'C00748'): 8,
#  ('Hexadecanoic acid', 'C00249'): 8,
#  ('Selenium', 'Z00042'): 8,
#  ('Thiamin monophosphate', 'C01081'): 8,
#  ('Guanine', 'C00242'): 8,
#  ('N-Methyl-L-glutamate', 'C01046'): 8,
#  ('Electron-transferring flavoprotein', 'C04253'): 8,
#  ('beta-D-Fructose 1,6-bisphosphate', 'C05378'): 8,
#  ('Carboxyphosphate', 'C20969'): 8,
#  ('D-Gluconic acid', 'C00257'): 8,
#  ('Glycolate', 'C00160'): 8,
#  ('Urea-1-carboxylate', 'C01010'): 8,
#  ('Phenethylamine', 'C05332'): 8,
#  ('Shikimate', 'C00493'): 8,
#  ("2-(Formamido)-N1-(5'-phosphoribosyl)acetamidine", 'C04640'): 8,
#  ('4-Methyl-2-oxopentanoate', 'C00233'): 8,
#  ('4-Coumarate', 'C00811'): 8,
#  ('beta-D-Glucose 6-phosphate', 'C01172'): 8,
#  ("5'-Methylthioadenosine", 'C00170'): 8,
#  ('Coenzyme M 7-mercaptoheptanoylthreonine-phosphate heterodisulfide',
#   'C04832'): 8,
#  ('2-Deoxy-D-ribose 1-phosphate', 'C00672'): 8,
#  ('(S)-Dihydroorotate', 'C00337'): 8,
#  ('(S)-1-Phenylethanol', 'C11348'): 8,
#  ('(S)-1-Pyrroline-5-carboxylate', 'C03912'): 8,
#  ('Lactosylceramide', 'C01290'): 8,
#  ('Narbonolide', 'C11997'): 8,
#  ('Citrate', 'C00158'): 8,
#  ('Coenzyme B', 'C04628'): 8,
#  ('Hydroquinone', 'C00530'): 8,
#  ('alpha-D-Glucose 6-phosphate', 'C00668'): 8,
#  ('Deoxyadenosine', 'C00559'): 8,
#  ('Propanal', 'C00479'): 8,
#  ('Propanoate', 'C00163'): 8,
#  ('Orthoquinone', 'Z00065'): 8,
#  ('5-Oxoproline', 'C01879'): 8,
#  ('Terephthalate', 'C06337'): 8,
#  ('6-Deoxyerythronolide B', 'C03240'): 8,
#  ('4-Hydroxyphenylacetate', 'C00642'): 8,
#  ('Enterochelin', 'C05821'): 8,
#  ('Isopentenyl diphosphate', 'C00129'): 8,
#  ('8,8a-Deoxyoleandolide', 'C11989'): 8,
#  ('1,7-Dimethylxanthine', 'C13747'): 8,
#  ('L-Homocysteine', 'C00155'): 8,
#  ('5-Phosphoribosylamine', 'C03090'): 8,
#  ('Caffeate', 'C01197'): 8,
#  ('Sinapyl alcohol', 'C02325'): 8,
#  ('N-Acylsphingosine', 'C00195'): 8,
#  ('Riboflavin', 'Z00040'): 8,
#  ('Co(I) corrinoid protein', 'C06021'): 8,
#  ('Xanthosine', 'C01762'): 8,
#  ('D-Serine', 'C00740'): 8,
#  ('Tyramine', 'C00483'): 8,
#  ('L-erythro-4-Hydroxyglutamate', 'C05947'): 8,
#  ('Coniferyl alcohol', 'C00590'): 8,
#  ('L-Histidinol', 'C00860'): 8,
#  ('Ferrocytochrome b5', 'C00999'): 8,
#  ('4-Coumaryl alcohol', 'C02646'): 8,
#  ('dTTP', 'C00459'): 8,
#  ('D-Erythrose 4-phosphate', 'C00279'): 8,
#  ('Hydrogen selenide', 'C01528'): 8,
#  ('Aminoimidazole ribotide', 'C03373'): 8,
#  ('Methylmalonyl-CoA', 'C02557'): 8,
#  ('2-trans-Dodecenoyl-CoA', 'C03221'): 7,
#  ("Guanosine 3',5'-bis(diphosphate)", 'C01228'): 7,
#  ('Methylglyoxal', 'C00546'): 7,
#  ('N-Acetyl-L-glutamate', 'C00624'): 7,
#  ('Tetrahydrosarcinapterin', 'C18802'): 7,
#  ('Reduced flavodoxin', 'C02745'): 7,
#  ('trans,trans-Farnesyl diphosphate', 'C00448'): 7,
#  ('[Reduced NADPH---hemoprotein reductase]', 'C03024'): 7,
#  ('Cyclohexane-1-carbonyl-CoA', 'C09823'): 7,
#  ('Carboxybiotin-carboxyl-carrier protein', 'C04419'): 7,
#  ('Sinapate', 'C00482'): 7,
#  ('L-Histidinol phosphate', 'C01100'): 7,
#  ('2-Succinylbenzoate', 'C02730'): 7,
#  ('5-Methyl-5,6,7,8-tetrahydromethanopterin', 'C04488'): 7,
#  ('Methanethiol', 'C00409'): 7,
#  ('5-Hydroxyconiferyl alcohol', 'C12205'): 7,
#  ("5'-Phosphoribosylglycinamide", 'C03838'): 7,
#  ('3-Dehydroshikimate', 'C02637'): 7,
#  ('Ascorbate', 'Z00004'): 7,
#  ('(S)-2-Aminobutanoate', 'C02356'): 7,
#  ('D-Glucuronate', 'C00191'): 7,
#  ('Prephenate', 'C00254'): 7,
#  ('D-Ribose 1,5-bisphosphate', 'C01151'): 7,
#  ('Octadecanoic acid', 'C01530'): 7,
#  ('D-Mannose', 'C00159'): 7,
#  ('Coniferyl aldehyde', 'C02666'): 7,
#  ("3'-Phosphoadenylyl sulfate", 'C00053'): 7,
#  ('6-Hydroxynicotinate', 'C01020'): 7,
#  ('Sedoheptulose 7-phosphate', 'C05382'): 7,
#  ('Acetone cyanohydrin', 'C02659'): 7,
#  ("Guanosine 3'-diphosphate 5'-triphosphate", 'C04494'): 7,
#  ('L-Arogenate', 'C00826'): 7,
#  ('Phosphonoacetaldehyde', 'C03167'): 7,
#  ('trans-Hexadec-2-enoyl-CoA', 'C05272'): 7,
#  ('Phosphatidate', 'C00416'): 7,
#  ('(9Z)-Octadecenoic acid', 'C00712'): 7,
#  ('(S)-3-Methyl-2-oxopentanoic acid', 'C00671'): 7,
#  ('3-Oxostearoyl-[acp]', 'C16219'): 7,
#  ("1-(5'-Phosphoribosyl)-5-amino-4-(N-succinocarboxamide)-imidazole",
#   'C04823'): 7,
#  ('(2E)-Octadecenoyl-[acp]', 'C16221'): 7,
#  ('D-Glucosamine 6-phosphate', 'C00352'): 7,
#  ('Reduced FMN', 'C01847'): 7,
#  ('(2E,5S,6E,8E,10E)-5-Hydroxydodeca-2,6,8,10-tetraenal', 'C22087'): 7,
#  ('N-Methylhydantoin', 'C02565'): 7,
#  ('Octadecanoyl-[acyl-carrier protein]', 'C04088'): 7,
#  ('D-Xylulose 5-phosphate', 'C00231'): 7,
#  ('beta-D-Fructose', 'C02336'): 7,
#  ('UDP-alpha-D-galactose', 'C00052'): 7,
#  ('Holo-[carboxylase]', 'C06250'): 7,
#  ('N-Acetyl-alpha-D-glucosamine 1-phosphate', 'C04501'): 7,
#  ('trans-Hex-2-enoyl-CoA', 'C05271'): 7,
#  ('Dihydromonacolin L-[acyl-carrier protein]', 'C21108'): 7,
#  ('5-O-(1-Carboxyvinyl)-3-phosphoshikimate', 'C01269'): 7,
#  ('5-Carboxy-2-pentenoyl-CoA', 'C14144'): 7,
#  ('alpha,alpha-Trehalose', 'C01083'): 7,
#  ('Dephospho-CoA', 'C00882'): 7,
#  ('Taurine', 'C00245'): 7,
#  ('Reduced [2Fe-2S] ferredoxin', 'C22150'): 7,
#  ('Guanosine', 'C00387'): 7,
#  ('10-Deoxymethynolide', 'C11993'): 7,
#  ('Vanillate', 'C06672'): 7,
#  ('Pimeloyl-CoA', 'C01063'): 7,
#  ('Anthraniloyl-CoA', 'C02247'): 7,
#  ('2-Phospho-D-glycerate', 'C00631'): 7,
#  ('Cellobiose', 'C00185'): 7,
#  ('Cholesterol', 'C00187'): 7,
#  ('alpha-D-Galactose 1-phosphate', 'C00446'): 7,
#  ('N-Acetylornithine', 'C00437'): 7,
#  ('Glycolaldehyde', 'C00266'): 7,
#  ('trans-Dec-2-enoyl-CoA', 'C05275'): 7,
#  ('(3R)-3-Hydroxyoctadecanoyl-[acyl-carrier protein]', 'C16220'): 7,
#  ('Reduced electron-transferring flavoprotein', 'C04570'): 7,
#  ('Oxalosuccinate', 'C05379'): 7,
#  ('Deoxycytidine', 'C00881'): 7,
#  ('Octanoyl-CoA', 'C01944'): 7,
#  ('Deoxyguanosine', 'C00330'): 7,
#  ('Cholest-4-en-3-one', 'C00599'): 7,
#  ('Cob(II)yrinate a,c diamide', 'C06504'): 7,
#  ('Ethylene', 'C06547'): 7,
#  ('gamma-L-Glutamyl-L-cysteine', 'C00669'): 7,
#  ('Primary alcohol', 'C00226'): 7,
#  ('Protomycinolide IV', 'C15685'): 7,
#  ('Linoleate', 'C01595'): 7,
#  ('D-Lysine', 'C00739'): 7,
#  ("Adenosine 3',5'-bisphosphate", 'C00054'): 7,
#  ('Uroporphyrinogen III', 'C01051'): 7,
#  ('Phenylacetic acid', 'C07086'): 7,
#  ('5-Methyl-H4SPT', 'C18799'): 7,
#  ('trans-Oct-2-enoyl-CoA', 'C05276'): 7,
#  ('trans-Tetradec-2-enoyl-CoA', 'C05273'): 7,
#  ('Acetyl phosphate', 'C00227'): 7,
#  ('Oxidized flavodoxin', 'C02869'): 7,
#  ('Shikimate 3-phosphate', 'C03175'): 7,
#  ('Pantothenate', 'C00864'): 7,
#  ('Tylactone', 'C12000'): 7,
#  ('D-Mannose 6-phosphate', 'C00275'): 7,
#  ('Caffeine', 'C07481'): 6,
#  ('Topaquinone', 'Z00061'): 6,
#  ('Lactose', 'C00243'): 6,
#  ('Glutathione', 'Z00023'): 6,
#  ("alpha,alpha'-Trehalose 6-phosphate", 'C00689'): 6,
#  ('D-Alanyl-D-alanine', 'C00993'): 6,
#  ('L-1-Pyrroline-3-hydroxy-5-carboxylate', 'C04281'): 6,
#  ('Menaquinol', 'C05819'): 6,
#  ('Ferricytochrome', 'C00923'): 6,
#  ('2-Deoxy-D-ribose 5-phosphate', 'C00673'): 6,
#  ('Kanamycin B', 'C00825'): 6,
#  ('1-Pyrroline-2-carboxylate', 'C03564'): 6,
#  ('Pantetheine', 'C00831'): 6,
#  ('D-Xylulose', 'C00310'): 6,
#  ('Nicotinamide', 'C00153'): 6,
#  ('(S)-3-Hydroxy-3-methylglutaryl-CoA', 'C00356'): 6,
#  ('N-Acetylneuraminate', 'C00270'): 6,
#  ('3-Hydroxybenzoate', 'C00587'): 6,
#  ('L-Threonine', 'C00188'): 6,
#  ('PQQ', 'Z00036'): 6,
#  ('D-Tagatose 6-phosphate', 'C01097'): 6,
#  ('(R)-2-Methylmalate', 'C02612'): 6,
#  ('3-Hydroxyphenylacetate', 'C05593'): 6,
#  ('trans-2-Enoyl-OPC8-CoA', 'C16328'): 6,
#  ("7,8-Dihydroneopterin 3'-triphosphate", 'C04895'): 6,
#  ('Hydrazine', 'C05361'): 6,
#  ('Lauroyl-CoA', 'C01832'): 6,
#  ('4-Hydroxybenzaldehyde', 'C00633'): 6,
#  ('4-Phospho-L-aspartate', 'C03082'): 6,
#  ('Sinapoyl aldehyde', 'C05610'): 6,
#  ('(Z)-But-2-ene-1,2,3-tricarboxylate', 'C04225'): 6,
#  ('6-Phospho-D-gluconate', 'C00345'): 6,
#  ('trans-2-Enoyl-OPC4-CoA', 'C16336'): 6,
#  ('Serotonin', 'C00780'): 6,
#  ('dGMP', 'C00362'): 6,
#  ('2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate', 'C04691'): 6,
#  ('Alkene', 'C01372'): 6,
#  ('Uroporphyrin III', 'C02469'): 6,
#  ("1-(5'-Phosphoribosyl)-5-formamido-4-imidazolecarboxamide", 'C04734'): 6,
#  ('Ethanolamine phosphate', 'C00346'): 6,
#  ('dUDP', 'C01346'): 6,
#  ('Nitrate', 'C00244'): 6,
#  ('(S)-Lactate', 'C00186'): 6,
#  ('Theobromine', 'C07480'): 6,
#  ('7-Methylxanthine', 'C16353'): 6,
#  ('Phosphatidylserine', 'C02737'): 6,
#  ('2,3,4,5-Tetrahydrodipicolinate', 'C03972'): 6,
#  ('(R)-2-Hydroxyglutarate', 'C01087'): 6,
#  ('L-Arabinose', 'C00259'): 6,
#  ('Adenylylselenate', 'C05686'): 6,
#  ('2,5-Dihydroxybenzoate', 'C00628'): 6,
#  ('Mandelonitrile', 'C00561'): 6,
#  ('Orsellinate-[acp]', 'C21343'): 6,
#  ('Oxidized [2Fe-2S] ferredoxin', 'C22151'): 6,
#  ('Oxalyl-CoA', 'C00313'): 6,
#  ('Fumiquinazoline A', 'C22147'): 6,
#  ('Sulfoacetaldehyde', 'C00593'): 6,
#  ('L-4-Hydroxyphenylglycine', 'C12323'): 6,
#  ('GDP-mannose', 'C00096'): 6,
#  ('Isochorismate', 'C00885'): 6,
#  ('D-Fructose 1,6-bisphosphate', 'C00354'): 6,
#  ('Nitrous oxide', 'C00887'): 6,
#  ('dAMP', 'C00360'): 6,
#  ('Decanoyl-CoA', 'C05274'): 6,
#  ('D-Amino acid', 'C00405'): 6,
#  ('1-Phosphatidyl-1D-myo-inositol 3,5-bisphosphate', 'C11556'): 6,
#  ('1,3-Diaminopropane', 'C00986'): 6,
#  ('N(omega)-Hydroxyarginine', 'C05933'): 6,
#  ('Isomaltose', 'C00252'): 6,
#  ('Methanofuran', 'C00862'): 6,
#  ('Phenylacetonitrile', 'C16074'): 6,
#  ('cis-Aconitate', 'C00417'): 6,
#  ('3-Sulfopyruvate', 'C05528'): 6,
#  ('D-Galacturonate', 'C00333'): 6,
#  ('trans-2-Enoyl-OPC6-CoA', 'C16332'): 6,
#  ('Hexanoyl-CoA', 'C05270'): 6,
#  ('(S)-Lactaldehyde', 'C00424'): 6,
#  ('(R)-2-Hydroxybutane-1,2,4-tricarboxylate', 'C01251'): 6,
#  ('OPC8-CoA', 'C16327'): 6,
#  ('Sarcosine', 'C00213'): 6,
#  ('1D-myo-Inositol 3-phosphate', 'C04006'): 6,
#  ('Carboxylate', 'C00060'): 6,
#  ('Molybdopterin', 'C05924'): 6,
#  ('CDP-4-dehydro-3,6-dideoxy-D-glucose', 'C04297'): 6,
#  ('Catechol', 'C00090'): 6,
#  ('N-Acetyl-L-glutamate 5-semialdehyde', 'C01250'): 6,
#  ('(R)-Pantoate', 'C00522'): 6,
#  ('1-Acyl-sn-glycerol 3-phosphate', 'C00681'): 6,
#  ('Secondary alcohol', 'C01612'): 6,
#  ('3-Dehydroquinate', 'C00944'): 6,
#  ('4-Cresol', 'C01468'): 6,
#  ('1-Methylnicotinamide', 'C02918'): 6,
#  ('2-Hydroxyethylphosphonate', 'C06451'): 6,
#  ('N-Acetyl-L-aspartate', 'C01042'): 6,
#  ('Tetradecanoyl-CoA', 'C02593'): 6,
#  ('Trimethylamine', 'C00565'): 6,
#  ('5-Hydroxyindoleacetaldehyde', 'C05634'): 6,
#  ('Ketone', 'C01450'): 6,
#  ('Histidyltryptophyldiketopiperazine', 'C22162'): 6,
#  ('Precorrin 1', 'C15527'): 6,
#  ('L-Fucose', 'C01019'): 6,
#  ('N-Acetyl-D-galactosamine', 'C01132'): 6,
#  ('1D-myo-Inositol 1,3,4-trisphosphate', 'C01243'): 6,
#  ('Formylmethanofuran', 'C01001'): 6,
#  ('Abscisic aldehyde', 'C13455'): 6,
#  ('O-Acetyl-L-serine', 'C00979'): 6,
#  ('UDP-glucuronate', 'C00167'): 6,
#  ('Enzyme N6-(lipoyl)lysine', 'C15972'): 6,
#  ('3-(Methylthio)propanoyl-CoA', 'C20870'): 6,
#  ('Geranyl diphosphate', 'C00341'): 6,
#  ('(S)-Methylmalonate semialdehyde', 'C06002'): 6,
#  ('Retinol', 'C00473'): 6,
#  ('N-Acetyl-D-glucosamine 6-phosphate', 'C00357'): 6,
#  ('N-Formimino-L-glutamate', 'C00439'): 5,
#  ('(2R,5S)-2,5-Diaminohexanoate', 'C05161'): 5,
#  ('e-', 'C05359'): 5,
#  ('2-Octaprenylphenol', 'C05810'): 5,
#  ('(R)-5,6-Dihydrothymine', 'C21028'): 5,
#  ('Stachyose', 'C01613'): 5,
#  ('2-Aminoethylphosphonate', 'C03557'): 5,
#  ('dTDP-3-amino-2,3,6-trideoxy-4-keto-D-glucose', 'C12318'): 5,
#  ('trans-Aconitate', 'C02341'): 5,
#  ('UDP-L-Ara4O', 'C16155'): 5,
#  ("D-4'-Phosphopantothenate", 'C03492'): 5,
#  ('Squalene', 'C00751'): 5,
#  ('Tenuazonic acid', 'C08511'): 5,
#  ('Butanoic acid', 'C00246'): 5,
#  ('3-Hydroxypropanal', 'C00969'): 5,
#  ('Thiocyanate', 'C01755'): 5,
#  ('Kanosamine 6-phosphate', 'C12213'): 5,
#  ('Hydantoin-5-propionate', 'C05565'): 5,
#  ('3-Phospho-D-glyceroyl phosphate', 'C00236'): 5,
#  ('alpha-Isopropylmalate', 'C02504'): 5,
#  ('Histamine', 'C00388'): 5,
#  ('UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-meso-2,6-diaminopimelate',
#   'C04877'): 5,
#  ('o-Methoxyphenol', 'C01502'): 5,
#  ('Dimethyl sulfide', 'C00580'): 5,
#  ('D-Ribulose', 'C00309'): 5,
#  ('(R)-Lactate', 'C00256'): 5,
#  ('Cobalt-precorrin 4', 'C11540'): 5,
#  ('3-Oxo-3-phenylpropanoate', 'C07114'): 5,
#  ('3-(Methylthio)propanoate', 'C08276'): 5,
#  ('Hydroxyproline', 'C01157'): 5,
#  ('6-Methylsalicylyl-CoA', 'C21312'): 5,
#  ("(R)-4'-Phosphopantothenoyl-L-cysteine", 'C04352'): 5,
#  ('Erythrulose 1-phosphate', 'C03394'): 5,
#  ('Propane-1,2-diol', 'C00583'): 5,
#  ('Reduced azurin', 'C05358'): 5,
#  ('2-Methylcitrate', 'C02225'): 5,
#  ('(3S)-3,6-Diaminohexanoate', 'C01142'): 5,
#  ('Nitrogen', 'C00697'): 5,
#  ('Carnosine', 'C00386'): 5,
#  ('Isoliquiritigenin', 'C08650'): 5,
#  ('(S)-2-Methylbutanoyl-[acp]', 'C21129'): 5,
#  ('Protein disulfide', 'C02582'): 5,
#  ('Sulfur-carrier protein', 'C15810'): 5,
#  ('(9Z,12Z,15Z)-Octadecatrienoyl-CoA', 'C16162'): 5,
#  ('N-(5-Phospho-D-ribosyl)anthranilate', 'C04302'): 5,
#  ('(R)-Lipoate', 'C16241'): 5,
#  ('Androstenedione', 'C00280'): 5,
#  ('L-Galactonate', 'C15930'): 5,
#  ('Magnesium protoporphyrin', 'C03516'): 5,
#  ('5-Aminopentanoate', 'C00431'): 5,
#  ('Coproporphyrinogen III', 'C03263'): 5,
#  ('Cyclo(L-Trp-L-Phe)', 'C22142'): 5,
#  ('Protochlorophyllide', 'C02880'): 5,
#  ('L-2,4-Diaminobutanoate', 'C03283'): 5,
#  ('UDPMurNAc(oyl-L-Ala-D-gamma-Glu-L-Lys-D-Ala-D-Ala)', 'C04702'): 5,
#  ('1-Deoxy-D-xylulose 5-phosphate', 'C11437'): 5,
#  ('alpha-D-Galactosyl-(1->3)-1D-myo-inositol', 'C01235'): 5,
#  ('(2R,4S)-2,4-Diaminopentanoate', 'C03943'): 5,
#  ('UDP-L-Ara4N', 'C16153'): 5,
#  ('(S)-3-Hydroxybutanoyl-CoA', 'C01144'): 5,
#  ('(R)-Methylmalonyl-CoA', 'C01213'): 5,
#  ('(4R)-4-Hydroxy-2-oxoglutarate', 'C05946'): 5,
#  ('Hydroxypyruvate', 'C00168'): 5,
#  ('LL-2,6-Diaminoheptanedioate', 'C00666'): 5,
#  ('D-Glutamine', 'C00819'): 5,
#  ('4-Hydroxy-3-polyprenylbenzoate', 'C05848'): 5,
#  ('3,4-Dihydroxyphenylethyleneglycol', 'C05576'): 5,
#  ('Digalactosylceramide', 'C06126'): 5,
#  ('Glutathione disulfide', 'C00127'): 5,
#  ('Sinapoyl-CoA', 'C00411'): 5,
#  ('GA1', 'C06136'): 5,
#  ('Cinnamoyl-CoA', 'C00540'): 5,
#  ('(3S,5S)-3,5-Diaminohexanoate', 'C01186'): 5,
#  ('N,N-Dimethylglycine', 'C01026'): 5,
#  ('5-Guanidino-2-oxopentanoate', 'C03771'): 5,
#  ('5,10-Methylenetetrahydromethanopterin', 'C04377'): 5,
#  ('Tryptamine', 'C00398'): 5,
#  ('Butanal', 'C01412'): 5,
#  ('1-(5-Phospho-D-ribosyl)-ATP', 'C02739'): 5,
#  ('Chlorophyllide', 'C02139'): 5,
#  ('Dimethylallyl diphosphate', 'C00235'): 5,
#  ('Xylitol', 'C00379'): 5,
#  ('Indolepyruvate', 'C00331'): 5,
#  ('1-Methylxanthine', 'C16358'): 5,
#  ('Heme', 'C00032'): 5,
#  ('D-Ribulose 1,5-bisphosphate', 'C01182'): 5,
#  ('UDP-N-acetyl-D-galactosamine', 'C00203'): 5,
#  ('Cyclohex-1-ene-1-carbonyl-CoA', 'C09811'): 5,
#  ('Sulfur', 'C00087'): 5,
#  ('3,4-Dihydroxy-L-phenylalanine', 'C00355'): 5,
#  ('Sirohydrochlorin', 'C05778'): 5,
#  ('UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-6-carboxy-L-lysyl-D-alanyl-D-alanine',
#   'C04882'): 5,
#  ('N-Acetyl-alpha-D-galactosamine 1-phosphate', 'C18060'): 5,
#  ('dTDP-3,4-dioxo-2,6-dideoxy-D-glucose', 'C06620'): 5,
#  ('3-Hydroxyanthranilate', 'C00632'): 5,
#  ('Melibiose', 'C05402'): 5,
#  ('alpha-Oxo-benzeneacetic acid', 'C02137'): 5,
#  ('D-Gal alpha 1->6D-Gal alpha 1->6D-Glucose', 'C05404'): 5,
#  ('Cinnamyl alcohol', 'C02394'): 5,
#  ('2,4,6/3,5-Pentahydroxycyclohexanone', 'C00691'): 5,
#  ('(2R)-3-Sulfolactate', 'C11537'): 5,
#  ('Isocitrate', 'C00311'): 5,
#  ('Oxidized azurin', 'C05357'): 5,
#  ('Creatine', 'C00300'): 5,
#  ('Mercaptopyruvate', 'C00957'): 5,
#  ('Phytoceramide', 'C12145'): 5,
#  ('Dihydrocaffeoyl-CoA', 'C21175'): 5,
#  ('Itaconyl-CoA', 'C00531'): 5,
#  ('ADP-glucose', 'C00498'): 5,
#  ('Reduced riboflavin', 'C01007'): 5,
#  ('sn-Glycerol 1-phosphate', 'C00623'): 5,
#  ('Lipoylprotein', 'C02051'): 5,
#  ('o-Cresol', 'C01542'): 5,
#  ('Oleoyl-CoA', 'C00510'): 5,
#  ('(9Z,12Z,15Z)-Octadecatrienoic acid', 'C06427'): 5,
#  ('SAM', 'Z00041'): 5,
#  ('Maleylpyruvate', 'C02167'): 5,
#  ('(2S)-Methylsuccinyl-CoA', 'C18324'): 5,
#  ('2-Methyl-3-oxopropanoate', 'C00349'): 5,
#  ('L-Citrulline', 'C00327'): 5,
#  ('Chitobiose', 'C01674'): 5,
#  ('Hydrogenobyrinate a,c diamide', 'C06503'): 5,
#  ('Galactosylceramide', 'C02686'): 5,
#  ('3,4-Dihydroxymandelaldehyde', 'C05577'): 5,
#  ('Sorbitol 6-phosphate', 'C01096'): 5,
#  ('D-Erythrulose 4-phosphate', 'C03604'): 5,
#  ('N-Acetyl-D-mannosamine', 'C00645'): 5,
#  ('Sedoheptulose 1,7-bisphosphate', 'C00447'): 5,
#  ('Dihydropteroate', 'C00921'): 5,
#  ('Sulfate', 'C00059'): 5,
#  ('5,6-Dihydrouracil', 'C00429'): 5,
#  ('dTDP-4-oxo-6-deoxy-D-glucose', 'C11907'): 5,
#  ('Cobalt-factor III', 'C17401'): 5,
#  ('2-Polyprenylphenol', 'C05807'): 5,
#  ('4-Guanidinobutanoate', 'C01035'): 5,
#  ('2-Hydroxy-7-methoxy-5-methyl-1-naphthoate', 'C20841'): 5,
#  ('(S)-4-Hydroxymandelonitrile', 'C03742'): 5,
#  ('Linoleoyl-CoA', 'C02050'): 5,
#  ('Biotin', 'C00120'): 5,
#  ('5-Hydroxyconiferaldehyde', 'C12204'): 5,
#  ('Raffinose', 'C00492'): 5,
#  ('Nocardicin G', 'C17355'): 5,
#  ('Inositol 1-phosphate', 'C01177'): 5,
#  ('beta-Alanyl-N(pi)-methyl-L-histidine', 'C01262'): 5,
#  ('delta-(L-2-Aminoadipyl)-L-cysteinyl-D-valine', 'C05556'): 5,
#  ('HSO3-', 'C11481'): 5,
#  ('L-Malyl-CoA', 'C04348'): 5,
#  ('D-Arabinose', 'C00216'): 5,
#  ('(6Z,9Z,12Z)-Octadecatrienoic acid', 'C06426'): 4,
#  ('(S)-Ureidoglycine', 'C02091'): 4,
#  ('(L-Arginyl)adenylate', 'C22264'): 4,
#  ('D-Phenylalanine', 'C02265'): 4,
#  ('O-Phospho-D-serine', 'C02532'): 4,
#  ('Perillyl aldehyde', 'C02576'): 4,
#  ('5alpha-Androstane-3,17-dione', 'C00674'): 4,
#  ('Melibiitol', 'C05399'): 4,
#  ('5-Hydroxyferuloyl-CoA', 'C12203'): 4,
#  ('25-Hydroxycholest-4-en-3-one', 'C22325'): 4,
#  ('Aminoacetone', 'C01888'): 4,
#  ('8-Amino-7-oxononanoate', 'C01092'): 4,
#  ('5-Carboxyamino-1-(5-phospho-D-ribosyl)imidazole', 'C15667'): 4,
#  ('CDP-4-dehydro-6-deoxy-D-glucose', 'C01219'): 4,
#  ('L-Selenomethionine', 'C05335'): 4,
#  ('(3R)-3-Hydroxyacyl-CoA', 'C01086'): 4,
#  ('dTDP', 'C00363'): 4,
#  ("2-(7'-Methylthio)heptylmalic acid", 'C17230'): 4,
#  ('N-Methylputrescine', 'C02723'): 4,
#  ('4-Hydroxyphenylglyoxylate', 'C03590'): 4,
#  ('Benzylsuccinyl-CoA', 'C09817'): 4,
#  ('3-Oxotetradecanoyl-CoA', 'C05261'): 4,
#  ('3-Oxo-5,6-dehydrosuberyl-CoA', 'C19945'): 4,
#  ('Methylphosphonate', 'C20396'): 4,
#  ('Iminoaspartate', 'C05840'): 4,
#  ('Benzaldehyde', 'C00261'): 4,
#  ('Acrylic acid', 'C00511'): 4,
#  ('5-PP-InsP5', 'C11526'): 4,
#  ('Digalactosyl-diacylglycerol', 'C06037'): 4,
#  ('O-Succinyl-L-homoserine', 'C01118'): 4,
#  ('Monovalent Metal (M1)', 'Z00060'): 4,
#  ('L-Cystathionine', 'C02291'): 4,
#  ('2-Acetolactate', 'C00900'): 4,
#  ('Nitrile', 'C00726'): 4,
#  ('5-(5-Phospho-D-ribosylaminoformimino)-1-(5-phosphoribosyl)-imidazole-4-carboxamide',
#   'C04896'): 4,
#  ('Sphinganine 1-phosphate', 'C01120'): 4,
#  ('2-Hydroxybenzoyl-CoA', 'C20394'): 4,
#  ('(R)-3-Hydroxybutanoyl-CoA', 'C03561'): 4,
#  ('Alcohol', 'C00069'): 4,
#  ('UDP-N-acetylmuramate', 'C01050'): 4,
#  ('D-Glucono-1,5-lactone 6-phosphate', 'C01236'): 4,
#  ('Cobalt-precorrin 3', 'C11539'): 4,
#  ('D-Tagaturonate', 'C00558'): 4,
#  ('alpha-D-Galactosyl-(1->4)-beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-ceramide',
#   'C04737'): 4,
#  ('OPC4-CoA', 'C16335'): 4,
#  ('Glycyl radical', 'Z00052'): 4,
#  ('Prunasin', 'C00844'): 4,
#  ('dTDP-4-oxo-2,6-dideoxy-D-glucose', 'C11922'): 4,
#  ('N-Methylanthraniloyl-CoA', 'C12092'): 4,
#  ('N6-(1,2-Dicarboxyethyl)-AMP', 'C03794'): 4,
#  ('3,4-Dihydroxystyrene', 'C06224'): 4,
#  ('(Indol-3-yl)acetamide', 'C02693'): 4,
#  ('D-Glucono-1,5-lactone', 'C00198'): 4,
#  ('(S)-2-Acetolactate', 'C06010'): 4,
#  ('dTDP-3-amino-3,6-dideoxy-D-glucose', 'C11925'): 4,
#  ('Mycothiol', 'C06717'): 4,
#  ('Geranoyl-CoA', 'C01920'): 4,
#  ('Triacylglycerol', 'C00422'): 4,
#  ('3-Oxoadipate', 'C00846'): 4,
#  ('(R)-(Homo)2-citrate', 'C16583'): 4,
#  ('2-Hydroxyglutarate', 'C02630'): 4,
#  ('Paromamine', 'C01743'): 4,
#  ('Ethanolamine', 'C00189'): 4,
#  ('N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole', 'C04778'): 4,
#  ('Aniline', 'C00292'): 4,
#  ('Kanamycin A', 'C01822'): 4,
#  ("2-(2'-Methylthio)ethylmalic acid", 'C17210'): 4,
#  ('3-Ureidopropionate', 'C02642'): 4,
#  ('L-2-Amino-3-oxobutanoic acid', 'C03508'): 4,
#  ('L-Erythrulose', 'C02045'): 4,
#  ('(9S,13S,15Z)-12-Oxo-10,11-dihydrophyto-15-enoate', 'C04780'): 4,
#  ('D-Fructuronate', 'C00905'): 4,
#  ('Androsta-1,4-diene-3,17-dione', 'C20144'): 4,
#  ('2-O-(alpha-D-Mannosyl)-D-glycerate', 'C11544'): 4,
#  ('Folinic acid', 'C03479'): 4,
#  ('Cystathionine', 'C00542'): 4,
#  ('2-Methylacetoacetyl-CoA', 'C03344'): 4,
#  ('Benzonitrile', 'C09814'): 4,
#  ('3-Phosphonopyruvate', 'C02798'): 4,
#  ('3-(Methylthio)acryloyl-CoA', 'C20955'): 4,
#  ('3-Phosphonooxypyruvate', 'C03232'): 4,
#  ('2,3-Diketo-5-methylthiopentyl-1-phosphate', 'C15650'): 4,
#  ("5'-Deoxyadenosine", 'C05198'): 4,
#  ('1-Phosphatidyl-1D-myo-inositol 5-phosphate', 'C11557'): 4,
#  ('L-Rhamnose', 'C00507'): 4,
#  ('3-Octaprenyl-4-hydroxybenzoate', 'C05809'): 4,
#  ('(R)-3-Ureidoisobutyrate', 'C21029'): 4,
#  ('3-Oxo-OPC8-CoA', 'C16330'): 4,
#  ('Fumiquinazoline F', 'C22145'): 4,
#  ('L-Ribulose', 'C00508'): 4,
#  ("5-Amino-6-(5'-phospho-D-ribitylamino)uracil", 'C04454'): 4,
#  ('Spermine', 'C00750'): 4,
#  ('2-Methylquinolin-4-ol', 'C21873'): 4,
#  ('4-Amino-2-methyl-5-(phosphooxymethyl)pyrimidine', 'C04556'): 4,
#  ('Epimelibiose', 'C05400'): 4,
#  ('2-Carboxy-2,5-dihydro-5-oxofuran-2-acetate', 'C01278'): 4,
#  ('OPC6-CoA', 'C16331'): 4,
#  ('Naringenin', 'C00509'): 4,
#  ('Linamarin', 'C01594'): 4,
#  ('3-Dehydro-D-glucose 6-phosphate', 'C20668'): 4,
#  ('L-Gulonate', 'C00800'): 4,
#  ('1,2,3-Trihydroxybenzene', 'C01108'): 4,
#  ('Ethylene glycol', 'C01380'): 4,
#  ('Icosanoic acid', 'C06425'): 4,
#  ('3-beta-D-Galactosyl-sn-glycerol', 'C05401'): 4,
#  ('Precorrin 2', 'C02463'): 4,
#  ('4-Amino-4-deoxychorismate', 'C11355'): 4,
#  ('(L-Alanyl)adenylate', 'C22363'): 4,
#  ('Carboxynorspermidine', 'C18174'): 4,
#  ('Protoporphyrinogen IX', 'C01079'): 4,
#  ('5-Amino-6-(1-D-ribitylamino)uracil', 'C04732'): 4,
#  ('3-Oxoacyl-CoA', 'C00264'): 4,
#  ('Bilirubin', 'C00486'): 4,
#  ('Selenocysteine', 'Z00044'): 4,
#  ('3-Oxooctanoyl-CoA', 'C05267'): 4,
#  ('Dhurrin', 'C05143'): 4,
#  ('2,4-Bis(acetamido)-2,4,6-trideoxy-beta-L-altropyranose', 'C19972'): 4,
#  ('4-Imidazolone-5-propanoate', 'C03680'): 4,
#  ('(3R)-3-Hydroxyacyl-[acyl-carrier protein]', 'C01271'): 4,
#  ('3-Hydroxyhexadeca-4,6,8,10,12,14-hexaenoyl-[acp]', 'C21357'): 4,
#  ('N-Acetylaspartylglutamylglutamate', 'C20776'): 4,
#  ('D-Fructose 1-phosphate', 'C01094'): 4,
#  ('D-Mannonate', 'C00514'): 4,
#  ('4-Aminobenzoate', 'C00568'): 4,
#  ('Adipate semialdehyde', 'C06102'): 4,
#  ('6-Hydroxymethyl-7,8-dihydropterin diphosphate', 'C04807'): 4,
#  ('Choline phosphate', 'C00588'): 4,
#  ('3-Oxo-OPC6-CoA', 'C16334'): 4,
#  ('3-Oxopalmitoyl-CoA', 'C05259'): 4,
#  ('S-Adenosylmethioninamine', 'C01137'): 4,
#  ('N-Acetyl-L-glutamate 5-phosphate', 'C04133'): 4,
#  ('Dethiobiotin', 'C01909'): 4,
#  ('3-Oxodecanoyl-CoA', 'C05265'): 4,
#  ('D-Arabinono-1,4-lactone', 'C00652'): 4,
#  ('D-Arginine', 'C00792'): 4,
#  ('Testosterone', 'C00535'): 4,
#  ('5-Carboxymethyl-2-hydroxymuconate', 'C04186'): 4,
#  ('4-Hydroxycinnamyl aldehyde', 'C05608'): 4,
#  ('4-Phospho-D-erythronate', 'C03393'): 4,
#  ('6-Phospho-beta-D-glucosyl-(1,4)-D-glucose', 'C04534'): 4,
#  ('Starch', 'C00369'): 4,
#  ('Precursor Z', 'C18239'): 4,
#  ('D-myo-Inositol 1,4,5-trisphosphate', 'C01245'): 4,
#  ('2-Methylbut-2-enoyl-CoA', 'C03345'): 4,
#  ("Fumiquinazoline F-indoline-2',3'-diol", 'C22146'): 4,
#  ('3-Fumarylpyruvate', 'C02514'): 4,
#  ('Propanoyl phosphate', 'C02876'): 4,
#  ('D-Erythrulose', 'C02022'): 4,
#  ('Acetylene', 'C01548'): 4,
#  ('S-Methyl-5-thio-D-ribulose 1-phosphate', 'C04582'): 4,
#  ('Hydroxyacetone', 'C05235'): 4,
#  ('5-Hydroxykynurenamine', 'C05638'): 4,
#  ("2-(4'-Methylthio)butylmalic acid", 'C17218'): 4,
#  ('N-Succinyl-LL-2,6-diaminoheptanedioate', 'C04421'): 4,
#  ('Pyridoxal phosphate', 'C00018'): 4,
#  ('(S)-Ureidoglycolate', 'C00603'): 4,
#  ('N-Acetyl-L-2-amino-6-oxopimelate', 'C05539'): 4,
#  ('Protein', 'C00017'): 4,
#  ('Tetrathionate', 'C02084'): 4,
#  ('3-Oxoisoapionate', 'C22220'): 4,
#  ('Dihydroceramide', 'C12126'): 4,
#  ('(R)-(Homo)3-citrate', 'C16598'): 4,
#  ('Dihydrofolate', 'C00415'): 4,
#  ('S-Methyl-5-thio-D-ribose 1-phosphate', 'C04188'): 4,
#  ('5-Methyl-3-oxo-4-hexenoyl-CoA', 'C16471'): 4,
#  ('7-Dehydrocholesterol', 'C01164'): 4,
#  ('Maltodextrin', 'C01935'): 4,
#  ('Cobalt-precorrin 5A', 'C16242'): 4,
#  ('3-O-Methylgallate', 'C05616'): 4,
#  ('N6-(L-1,3-Dicarboxypropyl)-L-lysine', 'C00449'): 4,
#  ('Thiocarboxy-[sulfur-carrier protein]', 'C15814'): 4,
#  ('Mannitol', 'C00392'): 4,
#  ('(S)-Reticuline', 'C02105'): 4,
#  ('Phytic acid', 'C01204'): 4,
#  ('4-Carboxy-4-hydroxy-2-oxoadipate', 'C04115'): 4,
#  ('N-(L-Arginino)succinate', 'C03406'): 4,
#  ('L-Formylkynurenine', 'C02700'): 4,
#  ('Sodium cation', 'C01330'): 4,
#  ('N-Methylanthranilate', 'C03005'): 4,
#  ('L-Selenocystathionine', 'C05699'): 4,
#  ('alpha-D-Glucosamine 1-phosphate', 'C06156'): 4,
#  ("2-(6'-Methylthio)hexylmalic acid", 'C17226'): 4,
#  ('gamma-Linolenoyl-CoA', 'C03035'): 4,
#  ('Cellodextrin', 'C01898'): 4,
#  ('6-Pyruvoyltetrahydropterin', 'C03684'): 4,
#  ('Tetrahydrobiopterin', 'C00272'): 4,
#  ('L-4-Hydroxyphenylglycyl-L-arginine', 'C20910'): 4,
#  ('2-Succinylbenzoyl-CoA', 'C03160'): 4,
#  ('O-Phospho-L-serine', 'C01005'): 4,
#  ('L-2,3-Diaminopropanoate', 'C03401'): 4,
#  ('ADP-ribose', 'C00301'): 4,
#  ('Cinnamaldehyde', 'C00903'): 4,
#  ('Sphingomyelin', 'C00550'): 4,
#  ('(2S,3R)-3-Hydroxybutane-1,2,3-tricarboxylate', 'C04593'): 4,
#  ('Dihydrolipoylprotein', 'C02972'): 4,
#  ('Carboxyspermidine', 'C18172'): 4,
#  ('O-Phospho-L-homoserine', 'C01102'): 4,
#  ('D-Aspartate', 'C00402'): 4,
#  ('3-Oxododecanoyl-CoA', 'C05263'): 4,
#  ("2-(3'-Methylthio)propylmalic acid", 'C17214'): 4,
#  ('UDP-2-acetamido-4-amino-2,4,6-trideoxy-alpha-D-glucose', 'C04630'): 4,
#  ('N-Acetyl-D-mannosamine 6-phosphate', 'C04257'): 4,
#  ('2-[(2-Aminoethylcarbamoyl)methyl]-2-hydroxybutanedioate', 'C22073'): 4,
#  ('Cyanide ion', 'C00177'): 4,
#  ('1D-myo-Inositol 1,3,4,5-tetrakisphosphate', 'C01272'): 4,
#  ('Methanofuran', 'C21621'): 4,
#  ('7,8-Diaminononanoate', 'C01037'): 4,
#  ('Aminopropylcadaverine', 'C16565'): 4,
#  ('N-Acetyl-D-glucosaminyldiphosphoundecaprenol', 'C01289'): 4,
#  ('Pyridoxine', 'C00314'): 4,
#  ('D-arabino-Hex-3-ulose 6-phosphate', 'C06019'): 4,
#  ('3-Methylglutaconyl-CoA', 'C03231'): 4,
#  ('2-Formylglutarate', 'C16159'): 4,
#  ('Selenohomocysteine', 'C05698'): 4,
#  ('(S)-2-Aceto-2-hydroxybutanoate', 'C06006'): 4,
#  ('4-Amino-5-hydroxymethyl-2-methylpyrimidine', 'C01279'): 4,
#  ('E-Phenylitaconyl-CoA', 'C09818'): 4,
#  ('L-Amino acid', 'C00151'): 4,
#  ('Phenylacetaldehyde', 'C00601'): 4,
#  ('D-Mannose 1-phosphate', 'C00636'): 4,
#  ('L-Tyrosinal', 'C22021'): 4,
#  ('4-Hydroxy-3-methoxy-benzaldehyde', 'C00755'): 4,
#  ('L-4-Hydroxyglutamate semialdehyde', 'C05938'): 4,
#  ('Protoporphyrin', 'C02191'): 4,
#  ('UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-L-lysine', 'C05892'): 4,
#  ('Geranylgeranyl diphosphate', 'C00353'): 4,
#  ('Magnesium cation', 'C00305'): 4,
#  ('Trypanothione', 'C02090'): 4,
#  ('4-Hydroxystyrene', 'C05627'): 4,
#  ('L-Pipecolate', 'C00408'): 4,
#  ('Naringenin chalcone', 'C06561'): 4,
#  ('(+)-Pinoresinol', 'C05366'): 4,
#  ...}

# %%
# for 93% of cpd, they have ZERO lineages that ETU that cpd

print(list(cpd2ETUlineagesNum.values()).count(0))
print(list(cpd2ETUlineagesNum.values()).count(0)/len(cpd2ETUlineagesNum))
# Out:
# 4026
# 0.9375873311597578

# %%
# top ETU cpds
{(cpd2name.get(k, 'no name'), k): v for k, v in sorted(cpd2ETUlineagesNum.items(), key=lambda item: item[1], reverse=True)}
# Out:
# {('H2O', 'C00001'): 93,
#  ('H+', 'C00080'): 41,
#  ('ATP', 'C00002'): 32,
#  ('Oxygen', 'C00007'): 24,
#  ('ADP', 'C00008'): 19,
#  ('CO2', 'C00011'): 18,
#  ('Iron', 'Z00015'): 15,
#  ('Orthophosphate', 'C00009'): 13,
#  ('Mg', 'Z00029'): 13,
#  ('Diphosphate', 'C00013'): 13,
#  ('Heme', 'Z00025'): 12,
#  ('NADPH', 'C00005'): 11,
#  ('Zinc', 'Z00054'): 11,
#  ('Nickel', 'Z00034'): 9,
#  ('PLP', 'Z00035'): 8,
#  ('4Fe4S', 'Z00002'): 8,
#  ('Generic FeS', 'Z00063'): 8,
#  ('NADH', 'C00004'): 8,
#  ('CoA', 'C00010'): 8,
#  ('NAD+', 'C00003'): 8,
#  ('FAD', 'Z00013'): 7,
#  ('Ammonia', 'C00014'): 7,
#  ('Hydrogen', 'C00282'): 7,
#  ('NADP+', 'C00006'): 7,
#  ('Oxidized ferredoxin', 'C00139'): 7,
#  ('Reduced ferredoxin', 'C00138'): 7,
#  ('AMP', 'C00020'): 6,
#  ('L-Glutamate', 'C00025'): 6,
#  ('Cobalamin', 'Z00009'): 6,
#  ('S-Adenosyl-L-methionine', 'C00019'): 6,
#  ('Reduced acceptor', 'C00030'): 5,
#  ('Coenzyme F420', 'C00876'): 5,
#  ('Formate', 'C00058'): 5,
#  ('Flavoprotein', 'Z00019'): 5,
#  ('L-Serine', 'C00065'): 5,
#  ('Thioredoxin', 'C00342'): 4,
#  ('Acceptor', 'C00028'): 4,
#  ('L-Methionine', 'C00073'): 4,
#  ('Calcium', 'Z00055'): 4,
#  ('Sucrose', 'C00089'): 4,
#  ('Reduced coenzyme F420', 'C01080'): 4,
#  ('Thioredoxin disulfide', 'C00343'): 4,
#  ('Mn', 'Z00030'): 4,
#  ('Pyruvoyl', 'Z00039'): 4,
#  ('HCO3-', 'C00288'): 4,
#  ('L-Alanine', 'C00041'): 4,
#  ('GTP', 'C00044'): 3,
#  ('Cytochrome', 'Z00010'): 3,
#  ('Phosphoprotein', 'C00562'): 3,
#  ('2-Oxoglutarate', 'C00026'): 3,
#  ('5-Phospho-alpha-D-ribose 1-diphosphate', 'C00119'): 3,
#  ('Ascorbate', 'Z00004'): 3,
#  ('Methane', 'C01438'): 3,
#  ('Dihydromethanophenazine', 'C11904'): 3,
#  ('Glutathione', 'C00051'): 3,
#  ('Adenine', 'C00147'): 3,
#  ('FMN', 'Z00014'): 3,
#  ('N-Acetylmuramate', 'C02713'): 3,
#  ('Acetyl-CoA', 'C00024'): 3,
#  ('S-Adenosyl-L-homocysteine', 'C00021'): 3,
#  ('2-Phospho-D-glycerate', 'C00631'): 3,
#  ('Pyruvate', 'C00022'): 3,
#  ('D-Ribose 5-phosphate', 'C00117'): 3,
#  ('L-Arginine', 'C00062'): 3,
#  ('Copper', 'Z00070'): 3,
#  ('N-Acetylmuramoyl-Ala', 'C02999'): 3,
#  ('D-Glycerate', 'C00258'): 3,
#  ('Methanophenazine', 'C11903'): 3,
#  ('NAD/NADP', 'Z00032'): 3,
#  ('Superoxide', 'C00704'): 2,
#  ('Glycyl radical', 'Z00052'): 2,
#  ('(R)-Lactate', 'C00256'): 2,
#  ('Ethanolamine', 'C00189'): 2,
#  ("5'-Deoxyadenosine", 'C05198'): 2,
#  ('Acetone', 'C00207'): 2,
#  ('Coenzyme M 7-mercaptoheptanoylthreonine-phosphate heterodisulfide',
#   'C04832'): 2,
#  ("Cyclic di-3',5'-adenylate", 'C20565'): 2,
#  ('Coenzyme B', 'C04628'): 2,
#  ('THF (H4F)', 'Z00046'): 2,
#  ('Tetrahydrofolate', 'C00101'): 2,
#  ('(S)-Lactate', 'C00186'): 2,
#  ('Acetoacetate', 'C00164'): 2,
#  ('Dimethylallyl diphosphate', 'C00235'): 2,
#  ('L-Proline', 'C00148'): 2,
#  ('O-Phospho-L-serine', 'C01005'): 2,
#  ('L-Homocysteine', 'C00155'): 2,
#  ('UDP', 'C00015'): 2,
#  ('L-Cysteine', 'C00097'): 2,
#  ('Malonyl-CoA', 'C00083'): 2,
#  ('THB', 'Z00045'): 2,
#  ('2-(Methylthio)ethanesulfonate', 'C03920'): 2,
#  ('3-Phospho-D-glycerate', 'C00197'): 2,
#  ('SAM', 'Z00041'): 2,
#  ('CO', 'C00237'): 2,
#  ('alpha-D-Ribose 1-methylphosphonate 5-phosphate', 'C20423'): 2,
#  ('Ferrocytochrome b5', 'C00999'): 2,
#  ('alpha-D-Ribose 1,2-cyclic phosphate 5-phosphate', 'C20440'): 2,
#  ('D-Fructose', 'C00095'): 2,
#  ('Coenzyme M', 'C03576'): 2,
#  ('D-Mannose 6-phosphate', 'C00275'): 2,
#  ('Lactose', 'C00243'): 1,
#  ('UDP-N-acetyl-3-(1-carboxyvinyl)-D-glucosamine', 'C04631'): 1,
#  ('S-(Hydroxymethyl)glutathione', 'C14180'): 1,
#  ('L-Tryptophan', 'C00078'): 1,
#  ("2'-(5-Triphosphoribosyl)-3'-dephospho-CoA", 'C19771'): 1,
#  ('2-trans-Dodecenoyl-CoA', 'C03221'): 1,
#  ('D-Alanyl-D-alanine', 'C00993'): 1,
#  ('Uracil', 'C00106'): 1,
#  ('(3R)-3-Hydroxyacyl-CoA', 'C01086'): 1,
#  ('N-Acetyl-beta-D-glucosaminyl-(1->4)-D-glucosamine', 'C21747'): 1,
#  ('N-Acetyl-L-glutamate', 'C00624'): 1,
#  ('Acyl phosphate', 'C02133'): 1,
#  ('Hydroquinone', 'C15603'): 1,
#  ('ACP', 'Z00003'): 1,
#  ('Tetrahydrosarcinapterin', 'C18802'): 1,
#  ('Ascorbate', 'C00072'): 1,
#  ('Methylphosphonate', 'C20396'): 1,
#  ('Agmatine', 'C00179'): 1,
#  ('Monovalent Metal (M1)', 'Z00060'): 1,
#  ("Pseudouridine 5'-phosphate", 'C01168'): 1,
#  ('Kanamycin B', 'C00825'): 1,
#  ('Methyl-Co(III) corrinoid protein', 'C06020'): 1,
#  ('Nitrile', 'C00726'): 1,
#  ('Biotin', 'Z00005'): 1,
#  ('D-Ribulose 5-phosphate', 'C00199'): 1,
#  ('Kanosamine 6-phosphate', 'C12213'): 1,
#  ('UDP-N-acetylmuramate', 'C01050'): 1,
#  ('D-Alanine', 'C00133'): 1,
#  ('4-Hydroxybenzoate', 'C00156'): 1,
#  ('F430', 'Z00012'): 1,
#  ('Selenium', 'Z00042'): 1,
#  ('(S)-3-Hydroxy-3-methylglutaryl-CoA', 'C00356'): 1,
#  ('(S)-2-Acetolactate', 'C06010'): 1,
#  ('Enzyme N6-(dihydrolipoyl)lysine', 'C15973'): 1,
#  ('Dimethyl sulfide', 'C00580'): 1,
#  ('Methanethiol', 'C00409'): 1,
#  ('CTP', 'C00063'): 1,
#  ('Molybdenum', 'Z00064'): 1,
#  ('3-Oxo-3-phenylpropanoate', 'C07114'): 1,
#  ('Phenylacetyl-CoA', 'C00582'): 1,
#  ('Tungstopterin', 'Z00059'): 1,
#  ('N-Acetylneuraminate', 'C00270'): 1,
#  ('Monocarboxylic acid amide', 'C03620'): 1,
#  ('(2E)-Octadecenoyl-CoA', 'C16218'): 1,
#  ('Cyanate', 'C01417'): 1,
#  ('2-O-(alpha-D-Mannosyl)-D-glycerate', 'C11544'): 1,
#  ('PQQ', 'Z00036'): 1,
#  ('S-Ribosyl-L-homocysteine', 'C03539'): 1,
#  ('di-trans,poly-cis-Undecaprenyl phosphate', 'C17556'): 1,
#  ('FMN', 'C00061'): 1,
#  ('Nitric oxide', 'C00533'): 1,
#  ('Glycolate', 'C00160'): 1,
#  ('L-Lysine', 'C00047'): 1,
#  ('Succinyl-CoA', 'C00091'): 1,
#  ('N-Acetylaspartylglutamate', 'C12270'): 1,
#  ('Magnesium protoporphyrin', 'C03516'): 1,
#  ('D-Mannose', 'C00159'): 1,
#  ('4a-Hydroxytetrahydrobiopterin', 'C15522'): 1,
#  ('CMP', 'C00055'): 1,
#  ('Thiamine', 'C00378'): 1,
#  ('Rhodopsin', 'C00778'): 1,
#  ('Ferricytochrome cL', 'C18233'): 1,
#  ('UDP-N-acetyl-D-mannosamine', 'C01170'): 1,
#  ('5,10-Methenyltetrahydromethanopterin', 'C04330'): 1,
#  ('Generic Flavin', 'Z00021'): 1,
#  ('3-Dehydro-D-glucose 6-phosphate', 'C20668'): 1,
#  ("N6'-Acetylkanamycin-B", 'C03154'): 1,
#  ('Acetate', 'C00033'): 1,
#  ('Precorrin 2', 'C02463'): 1,
#  ('4-Amino-4-deoxychorismate', 'C11355'): 1,
#  ('Phosphatidylinositol-3,4,5-trisphosphate', 'C05981'): 1,
#  ('Phosphatidylethanolamine', 'C00350'): 1,
#  ('4-Imidazolone-5-propanoate', 'C03680'): 1,
#  ('Ubiquinone', 'C00399'): 1,
#  ('Phosphatidate', 'C00416'): 1,
#  ('ROOH', 'C15498'): 1,
#  ('dUMP', 'C00365'): 1,
#  ('Citrate', 'C00158'): 1,
#  ('Hypoxanthine', 'C00262'): 1,
#  ('Cys-Gly', 'C01419'): 1,
#  ('4-Phospho-D-erythronate', 'C03393'): 1,
#  ('UMP', 'C00105'): 1,
#  ('Hydrogen sulfide', 'C00283'): 1,
#  ('Phosphatidylserine', 'C02737'): 1,
#  ('2,3,4,5-Tetrahydrodipicolinate', 'C03972'): 1,
#  ('D-Ribulose 1,5-bisphosphate', 'C01182'): 1,
#  ("Cytidine 5'-({hydroxy[(S)-2-hydroxypropyl]phosphonoyl}phosphate)",
#   'C22217'): 1,
#  ('7,8-Didemethyl-8-hydroxy-5-deazariboflavin', 'C19154'): 1,
#  ('Molybdoenzyme molybdenum cofactor', 'C18237'): 1,
#  ('Sirohydrochlorin', 'C05778'): 1,
#  ('Orthoquinone', 'Z00065'): 1,
#  ('5,10-Methenyltetrahydrofolate', 'C00445'): 1,
#  ('UDP-alpha-D-galactose', 'C00052'): 1,
#  ('Protein', 'C00017'): 1,
#  ('5-Oxoproline', 'C01879'): 1,
#  ('GMP', 'C00144'): 1,
#  ('5-O-(1-Carboxyvinyl)-3-phosphoshikimate', 'C01269'): 1,
#  ('Ferrocytochrome c', 'C00126'): 1,
#  ('Thiamin diphosphate', 'C00068'): 1,
#  ('prenFMN', 'Z00057'): 1,
#  ('(2R)-3-Sulfolactate', 'C11537'): 1,
#  ('N(omega)-(ADP-D-ribosyl)-L-arginine', 'C01201'): 1,
#  ('FAD', 'C00016'): 1,
#  ('Dephospho-CoA', 'C00882'): 1,
#  ('D-Galactose', 'C00124'): 1,
#  ('(R)-Acetoin', 'C00810'): 1,
#  ('N-(L-Arginino)succinate', 'C03406'): 1,
#  ('dTMP', 'C00364'): 1,
#  ('sn-Glycerol 3-phosphate', 'C00093'): 1,
#  ('Acetophenone', 'C07113'): 1,
#  ('2-Oxo-3-hydroxy-4-phosphobutanoate', 'C06054'): 1,
#  ("3',5'-Cyclic diGMP", 'C16463'): 1,
#  ('Ferricytochrome c', 'C00125'): 1,
#  ('D-Glucose', 'C00031'): 1,
#  ('Dihydro-heme d1', 'C22338'): 1,
#  ('N-Succinyl-2-L-amino-6-oxoheptanedioate', 'C04462'): 1,
#  ('L-4-Hydroxyphenylglycine', 'C12323'): 1,
#  ('Acyl-CoA', 'C00040'): 1,
#  ('Cellodextrin', 'C01898'): 1,
#  ('Tetrahydrobiopterin', 'C00272'): 1,
#  ('5-Methyltetrahydrofolate', 'C00440'): 1,
#  ('L-4-Hydroxyphenylglycyl-L-arginine', 'C20910'): 1,
#  ('Nicotinate D-ribonucleotide', 'C01185'): 1,
#  ('ADP-ribose', 'C00301'): 1,
#  ('Nitrous oxide', 'C00887'): 1,
#  ('Thio-molybdenum cofactor', 'C21486'): 1,
#  ('Glycine', 'C00037'): 1,
#  ('Phosphorhodopsin', 'C02456'): 1,
#  ('Adenosine', 'C00212'): 1,
#  ('N-Acetyl-D-glucosaminyldiphosphoundecaprenol', 'C01289'): 1,
#  ('Formaldehyde', 'C00067'): 1,
#  ('(S)-2-Hydroxypropylphosphonate', 'C06452'): 1,
#  ('Adenylated molybdopterin', 'C19848'): 1,
#  ('3-cis-Dodecenoyl-CoA', 'C02944'): 1,
#  ('Phosphoenolpyruvate', 'C00074'): 1,
#  ('L-Citrulline', 'C00327'): 1,
#  ('3-Hydroxyoctadecanoyl-CoA', 'C16217'): 1,
#  ('Chitobiose', 'C01674'): 1,
#  ('Nicotinamide D-ribonucleotide', 'C00455'): 1,
#  ('D-Mannose 1-phosphate', 'C00636'): 1,
#  ('(R)-Mevalonate', 'C00418'): 1,
#  ('Protoporphyrin', 'C02191'): 1,
#  ('2Fe2S', 'Z00001'): 1,
#  ('Formamide', 'C00488'): 1,
#  ('Magnesium cation', 'C00305'): 1,
#  ('N-Acetyl-beta-D-mannosaminyl-1,4-N-acetyl-D-glucosaminyldiphosphoundecaprenol',
#   'C04881'): 1,
#  ('(S)-4,5-Dihydroxypentane-2,3-dione', 'C11838'): 1,
#  ('Urocanate', 'C00785'): 1,
#  ('Fe2+', 'C14818'): 1,
#  ('Ferrocytochrome cL', 'C18234'): 1,
#  ('5,10-Methylenetetrahydrofolate', 'C00143'): 1,
#  ('Urea', 'C00086'): 1,
#  ('Sulfite', 'C00094'): 1,
#  ('Generic quinone', 'Z00022'): 1,
#  ('(2R)-O-Phospho-3-sulfolactate', 'C11536'): 1,
#  ('Nocardicin G', 'C17355'): 1,
#  ('Heme d1', 'C22339'): 1,
#  ('2,5-Dihydroxypyridine', 'C01059'): 1,
#  ('O-Acetyl-L-serine', 'C00979'): 1,
#  ('Dihydrobiopterin', 'C00268'): 1,
#  ('L-Aspartate', 'C00049'): 1,
#  ('Thiamine diphosphate', 'Z00047'): 1,
#  ('Oxaloacetate', 'C00036'): 1,
#  ('alpha-D-Ribose 1-methylphosphonate 5-triphosphate', 'C20422'): 1,
#  ("3',5'-Cyclic GMP", 'C00942'): 1,
#  ('Fe3+', 'C14819'): 1,
#  ('Methylmalonyl-CoA', 'C02557'): 1,
#  ('(S)-Methylmalonyl-CoA', 'C00683'): 1,
#  ('Avermectin B2b aglycone', 'C11955'): 0,
#  ('Erythromycin C', 'C06616'): 0,
#  ('L-Normetanephrine', 'C05589'): 0,
#  ('Lanosterol', 'C01724'): 0,
#  ('Terpentetriene', 'C19814'): 0,
#  ('Homogentisate', 'C00544'): 0,
#  ('Paspaline', 'C20530'): 0,
#  ('Apulose 4-phosphate', 'C22318'): 0,
#  ('1-O-Galloyl-beta-D-glucose', 'C01158'): 0,
#  ("Adenosine 5'-pentaphosphate", 'C20198'): 0,
#  ("N,N'-Diacetylhydrazine", 'C16622'): 0,
#  ('Cholesterol-5alpha,6alpha-epoxide', 'C15992'): 0,
#  ('(2S)-3-(4-Hydroxyphenyl)-2-isocyanopropanoate', 'C21889'): 0,
#  ('Caffeine', 'C07481'): 0,
#  ('(6Z,9Z,12Z)-Octadecatrienoic acid', 'C06426'): 0,
#  ('(R)-2-Ethylmalate', 'C02488'): 0,
#  ('6-(alpha-D-Glucosaminyl)-1-phosphatidyl-1D-myo-inositol', 'C04248'): 0,
#  ('2-Amino-4,5-dihydroxy-6-oxo-7-(phosphooxy)heptanoate', 'C20644'): 0,
#  ('9-Oxononanoic acid', 'C16322'): 0,
#  ('Hippurate', 'C01586'): 0,
#  ('H4MPT', 'Z00024'): 0,
#  ('Topaquinone', 'Z00061'): 0,
#  ('24-epi-Campesterol', 'C21106'): 0,
#  ('Neomycin B', 'C01737'): 0,
#  ('4-Vinylguaiacol', 'C17883'): 0,
#  ('2-Deoxy-5-keto-D-gluconic acid', 'C06892'): 0,
#  ('Indole', 'C00463'): 0,
#  ("2',3'-Cyclic UMP", 'C02355'): 0,
#  ('Cannabidiol', 'C07578'): 0,
#  ('(S)-Ureidoglycine', 'C02091'): 0,
#  ('Propynoate', 'C00804'): 0,
#  ('(R)-Canadine', 'C11818'): 0,
#  ('5,6-Dihydrothymine', 'C00906'): 0,
#  ('Creatinine', 'C00791'): 0,
#  ('Geranic acid', 'C16461'): 0,
#  ('Phenyllactate', 'C05607'): 0,
#  ('5-Androstene-3,17-dione', 'C20252'): 0,
#  ('Myrcene', 'C06074'): 0,
#  ('4-Methylene-2-oxoglutarate', 'C06035'): 0,
#  ('N-Formimino-L-glutamate', 'C00439'): 0,
#  ("9'-cis-Neoxanthin", 'C13431'): 0,
#  ('D-Galactarate', 'C00879'): 0,
#  ('Methylamine', 'C00218'): 0,
#  ('1-Deoxy-11beta-hydroxypentalenate', 'C20403'): 0,
#  ('(Z)-11-Tetradecenoyl-CoA', 'C06737'): 0,
#  ('2-Methylpropanoyl-CoA', 'C00630'): 0,
#  ('Episterol', 'C15777'): 0,
#  ('N5-Hydroxy-L-ornithine', 'C20850'): 0,
#  ('Humulene', 'C09684'): 0,
#  ('(2R,5S)-2,5-Diaminohexanoate', 'C05161'): 0,
#  ('1-alpha-D-[(1->4)-alpha-D-Glucosyl](n-1)-alpha-D-glucopyranoside',
#   'C06400'): 0,
#  ('L-Methionine S-oxide', 'C02989'): 0,
#  ('Benzoate', 'C00180'): 0,
#  ('1-Deoxy-D-xylulose', 'C06257'): 0,
#  ('Glutathione', 'Z00023'): 0,
#  ('(13E)-Labda-7,13-dien-15-ol', 'C20158'): 0,
#  ('e-', 'C05359'): 0,
#  ('(L-Arginyl)adenylate', 'C22264'): 0,
#  ('Octanoic acid', 'C06423'): 0,
#  ('2-Octaprenylphenol', 'C05810'): 0,
#  ('D-Phenylalanine', 'C02265'): 0,
#  ('Acetoacetyl-CoA', 'C00332'): 0,
#  ('N1,N8-Bis(sinapoyl)spermidine', 'C21170'): 0,
#  ('Sphinganine', 'C00836'): 0,
#  ('(R)-5,6-Dihydrothymine', 'C21028'): 0,
#  ('3-Methylthiopropanamine', 'C03354'): 0,
#  ('beta-Copaene', 'C20274'): 0,
#  ('[Sulfur-carrier protein]-Gly-NH-CH2-C(O)-S-L-cysteine', 'C20729'): 0,
#  ("9-cis-10'-Apo-beta-carotenal", 'C20692'): 0,
#  ('Epoxide', 'C00722'): 0,
#  ('(-)-Spiroviolene', 'C21661'): 0,
#  ('Dec-9-enoyl-[acyl-carrier protein]', 'C22343'): 0,
#  ('Stachyose', 'C01613'): 0,
#  ('O-Phospho-D-serine', 'C02532'): 0,
#  ('5-Methyl-3-oxohexanoyl-[acyl-carrier-protein]', 'C22368'): 0,
#  ('3-[(Z)-2-Isocyanoethenyl]-1H-indole', 'C21893'): 0,
#  ('Biotin amide', 'C01893'): 0,
#  ('4,5-Dioxopentanoate', 'C02800'): 0,
#  ('Gallate', 'C01424'): 0,
#  ('Perillyl aldehyde', 'C02576'): 0,
#  ('5alpha-Androstane-3,17-dione', 'C00674'): 0,
#  ('2,5-Dioxopentanoate', 'C00433'): 0,
#  ('26-Hydroxyecdysone', 'C16499'): 0,
#  ('Galactitol 1-phosphate', 'C06311'): 0,
#  ("alpha,alpha'-Trehalose 6-phosphate", 'C00689'): 0,
#  ('Maleamate', 'C01596'): 0,
#  ('D-Galactono-1,5-lactone', 'C02669'): 0,
#  ('Melibiitol', 'C05399'): 0,
#  ('13(1)-Oxo-magnesium-protoporphyrin IX 13-monomethyl ester', 'C11830'): 0,
#  ('5-Hydroxyferuloyl-CoA', 'C12203'): 0,
#  ('D-Glucuronolactone', 'C02670'): 0,
#  ('(R)-2-(Phosphonomethyl)malate', 'C21613'): 0,
#  ('11-cis-Dehydroretinal', 'C05919'): 0,
#  ('25-Hydroxycholest-4-en-3-one', 'C22325'): 0,
#  ('Aminoacetone', 'C01888'): 0,
#  ('1-Methylpyrrolinium', 'C06178'): 0,
#  ('Cobalt-sirohydrochlorin', 'C11538'): 0,
#  ('2-cis,6-trans-Farnesyl diphosphate', 'C16826'): 0,
#  ('beta-Sesquiphellandrene', 'C16776'): 0,
#  ('(14E)-Hexadec-14-enoyl-CoA', 'C20996'): 0,
#  ('p-Coumaroylputrescine', 'C18326'): 0,
#  ('N-Acetyl-beta-D-mannosaminuronosyl-(1->4)-N-acetyl-alpha-D-glucosaminyl-diphospho-ditrans,octacis-undecaprenol',
#   'C20497'): 0,
#  ('dTDP-4-oxo-2,6-dideoxy-D-allose', 'C11928'): 0,
#  ('N-Formyl-L-aspartate', 'C01044'): 0,
#  ('Indole-3-acetaldehyde', 'C00637'): 0,
#  ('8-Amino-7-oxononanoate', 'C01092'): 0,
#  ('Cyanidin 5-O-glucoside', 'C16298'): 0,
#  ('1D-myo-Inositol 1,3,4,6-tetrakisphosphate', 'C04477'): 0,
#  ('3-Methoxy-4-hydroxymandelate', 'C05584'): 0,
#  ('beta-D-Galactosyl-(1->4)-L-rhamnose', 'C19758'): 0,
#  ('Sesamin', 'C10882'): 0,
#  ('trans-beta-D-Glucosyl-2-hydroxycinnamate', 'C05158'): 0,
#  ('GDP', 'C00035'): 0,
#  ('ent-Copalyl diphosphate', 'C06089'): 0,
#  ('2-Dehydro-3-deoxy-L-rhamnonate', 'C03979'): 0,
#  ('1-Methyluric acid', 'C16359'): 0,
#  ('3-Hydroxy-4-methylanthranilate', 'C03986'): 0,
#  ('D-Xylose', 'C00181'): 0,
#  ('3-Hydroxybutanoyl-CoA', 'C05116'): 0,
#  ('2-Aminoethylphosphonate', 'C03557'): 0,
#  ("Quercetin 3,4',7-trissulfate", 'C03898'): 0,
#  ('3-Dehydro-2-deoxyecdysone', 'C16497'): 0,
#  ('dTDP-4-oxo-alpha-D-xylose', 'C21351'): 0,
#  ('Propenoyl-CoA', 'C00894'): 0,
#  ('Benzoylacetyl-CoA', 'C07118'): 0,
#  ('Peptide', 'C00012'): 0,
#  ('3-Methoxy-4-hydroxyphenylethyleneglycol', 'C05594'): 0,
#  ('5-Formiminotetrahydrofolate', 'C00664'): 0,
#  ('1,3,7-Trimethyl-5-hydroxyisourate', 'C21144'): 0,
#  ('2-Methylmaleate', 'C02226'): 0,
#  ('5-Carboxyamino-1-(5-phospho-D-ribosyl)imidazole', 'C15667'): 0,
#  ('3-Dehydro-scyllo-inosose', 'C21643'): 0,
#  ('Heme I', 'C22328'): 0,
#  ('GDP-L-fucose', 'C00325'): 0,
#  ('Methaneselenol', 'C05703'): 0,
#  ('Biliverdin-IX-delta', 'C21723'): 0,
#  ("2'-Phospho-cyclic ADP-ribose", 'C20742'): 0,
#  ('dTDP-3-amino-2,3,6-trideoxy-4-keto-D-glucose', 'C12318'): 0,
#  ('Branched chain fatty acid', 'C05996'): 0,
#  ('Cannabidiolic acid', 'C10784'): 0,
#  ('6-Deoxy-6-sulfo-D-fructose 1-phosphate', 'C20831'): 0,
#  ('CDP-4-dehydro-6-deoxy-D-glucose', 'C01219'): 0,
#  ('(R)-10-Hydroxystearate', 'C03195'): 0,
#  ('alpha-D-Mannosyl-(1->3)-N-acetyl-alpha-D-glucosaminyl-diphospho-ditrans,octacis-undecaprenol',
#   'C21780'): 0,
#  ('(2E,4E)-2,4-Dienoyl-CoA', 'C04512'): 0,
#  ('5-Methoxyindoleacetate', 'C05660'): 0,
#  ('4-Hydroxyphthalate', 'C06680'): 0,
#  ('7,8-Dihydroxykynurenate', 'C01111'): 0,
#  ('Androsterone glucuronide', 'C11135'): 0,
#  ('L-Selenomethionine', 'C05335'): 0,
#  ('21,22-Diprenylpaxilline', 'C20561'): 0,
#  ('Mannobiose', 'C20861'): 0,
#  ("Guanosine 3',5'-bis(diphosphate)", 'C01228'): 0,
#  ('19-(4-Hydroxyphenyl)nonadecanoate', 'C21448'): 0,
#  ('L-1-Pyrroline-3-hydroxy-5-carboxylate', 'C04281'): 0,
#  ('N-Acetyl-D-galactosaminyl-N-acetyl-D-galactosaminyl-1,3-D-galactosyl-1,4-D-galactosyl-1,4-D-glucosylceramide',
#   'C04925'): 0,
#  ('Glutamate', 'C00302'): 0,
#  ('L-Phenylalanine', 'C00079'): 0,
#  ('Galangin', 'C10044'): 0,
#  ('3-D-Glucosyl-1,2-diacylglycerol', 'C04046'): 0,
#  ('ITP', 'C00081'): 0,
#  ('2-Hydroxy-6-oxonona-2,4-diene-1,9-dioate', 'C04479'): 0,
#  ('Methylglyoxal', 'C00546'): 0,
#  ('Deoxyinosine', 'C05512'): 0,
#  ("Oleandomycin 2'-O-phosphate", 'C03796'): 0,
#  ('HO-', 'C01328'): 0,
#  ('Sabinene hydrate', 'C02462'): 0,
#  ('Nebramine', 'C21259'): 0,
#  ('CoA-glutathione', 'C00920'): 0,
#  ('(+)-endo-beta-Bergamotene', 'C19737'): 0,
#  ('dTDP', 'C00363'): 0,
#  ("2-(7'-Methylthio)heptylmalic acid", 'C17230'): 0,
#  ('Guanylyl molybdenum cofactor', 'C19871'): 0,
#  ('alpha,beta-Dihydroxyethyl-TPP', 'C13378'): 0,
#  ('trans-Aconitate', 'C02341'): 0,
#  ('Guanidinoproclavaminic acid', 'C06657'): 0,
#  ('N4-Acetylaminobutanal', 'C05936'): 0,
#  ('UDP-4-keto-rhamnose', 'C17328'): 0,
#  ('Malonate', 'C00383'): 0,
#  ('Geranylgeraniol', 'C09094'): 0,
#  ('3-Oxalomalate', 'C01990'): 0,
#  ('dCTP', 'C00458'): 0,
#  ('(+)-epi-alpha-Bisabolol', 'C20479'): 0,
#  ('Anilide', 'C01402'): 0,
#  ('2-Oxo-4-hydroxy-5-aminovalerate', 'C05941'): 0,
#  ('1,8-Cineole', 'C09844'): 0,
#  ('5-Amino-5-(4-hydroxybenzyl)-6-(D-ribitylimino)-5,6-dihydrouracil',
#   'C21971'): 0,
#  ('Aminobacteriohopanetriol', 'C21123'): 0,
#  ('dTDP-5-dimethyl-L-lyxose', 'C12481'): 0,
#  ('(3S)-3-Hydroxycyclocitral', 'C19731'): 0,
#  ('beta-D-Galactosyl-(1->4)-N-acetyl-beta-D-glucosaminyl-(1->3)-beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-ceramide',
#   'C04922'): 0,
#  ('N-Methylputrescine', 'C02723'): 0,
#  ('Phosphoramidate', 'C02306'): 0,
#  ('trans-Tetradec-2-enoyl-[acp]', 'C05760'): 0,
#  ('4-Hydroxyphenylglyoxylate', 'C03590'): 0,
#  ('Nerylneryl diphosphate', 'C21784'): 0,
#  ('L-Arabinono-1,4-lactone', 'C01114'): 0,
#  ('12-Oxo-9(Z)-dodecenoic acid', 'C16311'): 0,
#  ('Urobilin', 'C05794'): 0,
#  ('5-Hydroxybenzimidazole', 'C21764'): 0,
#  ('(24R,24(1)R)-Fucosterol epoxide', 'C03910'): 0,
#  ('Thymine', 'C00178'): 0,
#  ('Benzylsuccinyl-CoA', 'C09817'): 0,
#  ('Imidazol-5-yl-pyruvate', 'C03277'): 0,
#  ('Demethyl-4-deoxygadusol', 'C21281'): 0,
#  ('7-epi-alpha-Eudesmol', 'C21689'): 0,
#  ('D-Threonine', 'C00820'): 0,
#  ("N8,N'8-Citryl-bis(spermidine)", 'C22004'): 0,
#  ('Mycinamicin IV', 'C18846'): 0,
#  ('3-Hexenol', 'C08492'): 0,
#  ('4-Fumarylacetoacetate', 'C01061'): 0,
#  ('Daidzin', 'C10216'): 0,
#  ('3-Demethylubiquinol', 'C21860'): 0,
#  ('Propanoyl-CoA', 'C00100'): 0,
#  ('N6-Acetyl-N6-hydroxy-L-lysine', 'C03955'): 0,
#  ('15,16-Epoxydolabrene', 'C22009'): 0,
#  ('Menaquinol', 'C05819'): 0,
#  ('3-Oxotetradecanoyl-CoA', 'C05261'): 0,
#  ('L-Kynurenine', 'C00328'): 0,
#  ('5-Hydroxyindoleacetate', 'C05635'): 0,
#  ('3-Dehydroecdysone', 'C02513'): 0,
#  ('Styrene oxide', 'C02083'): 0,
#  ("3,4,3',4'-Tetrahydrospirilloxanthin", 'C15888'): 0,
#  ('3-Oxo-5,6-dehydrosuberyl-CoA', 'C19945'): 0,
#  ('Benzene-1,2,4-triol', 'C02814'): 0,
#  ('Hopanoid', 'C06084'): 0,
#  ('L-threo-7,8-Dihydrobiopterin', 'C20263'): 0,
#  ('D-Galactaro-1,4-lactone', 'C20896'): 0,
#  ('11-cis-Retinal', 'C02110'): 0,
#  ('dTDP-4-oxo-2,6-dideoxy-L-mannose', 'C11927'): 0,
#  ('4-Oxoproline', 'C01877'): 0,
#  ('ent-13-epi-Manoyl oxide', 'C21714'): 0,
#  ('4-(2-Amino-3-hydroxyphenyl)-2,4-dioxobutanoate', 'C05645'): 0,
#  ('(3S,4S)-3-Hydroxytetradecane-1,3,4-tricarboxylate', 'C04529'): 0,
#  ('Phosphonoformate', 'C06456'): 0,
#  ('C30 Botryococcene', 'C20432'): 0,
#  ('2-Hydroxy-6-oxoocta-2,4,7-trienoate', 'C07087'): 0,
#  ('Dehydro coenzyme F420-0', 'C22277'): 0,
#  ('L-Tyrosine', 'C00082'): 0,
#  ('cyclo-Dopa 5-O-glucoside', 'C17751'): 0,
#  ('Toluene', 'C01455'): 0,
#  ('Violaxanthin', 'C08614'): 0,
#  ('beta-Amyrin', 'C08616'): 0,
#  ('Melamine', 'C08737'): 0,
#  ('Ferricytochrome', 'C00923'): 0,
#  ('(9Z,12Z)-Hexadeca-9,12,15-trienoyl-CoA', 'C21528'): 0,
#  ('Pseudouridine', 'C02067'): 0,
#  ('5-Deoxy-D-glucuronate', 'C16737'): 0,
#  ('Coenzyme A', 'Z00051'): 0,
#  ('Iminoaspartate', 'C05840'): 0,
#  ('2-O-(alpha-D-Glucopyranosyl)glycerol', 'C11546'): 0,
#  ('Maleic acid', 'C01384'): 0,
#  ('N(pi)-Methyl-L-histidine', 'C01152'): 0,
#  ('(+)-Piperitol', 'C21954'): 0,
#  ('2-[(L-Alanin-3-ylcarbamoyl)methyl]-3-(2-aminoethylcarbamoyl)-2-hydroxypropanoate',
#   'C22074'): 0,
#  ('Sorbose 1-phosphate', 'C02888'): 0,
#  ('Imidazolone', 'C06195'): 0,
#  ('L-Fucose 1-phosphate', 'C02985'): 0,
#  ('3-Aminopentanedioate', 'C05574'): 0,
#  ('3,5-Dihydroxy-phenylglycine', 'C12026'): 0,
#  ('Vanillylamine', 'C16666'): 0,
#  ('2-Phosphoglycolate', 'C00988'): 0,
#  ('Roseoflavin', 'C21647'): 0,
#  ('trans-Crocetin (beta-D-glucosyl) (beta-D-gentibiosyl) ester', 'C17513'): 0,
#  ('Imidazole lactate', 'C05568'): 0,
#  ('3-Hydroxypimeloyl-[acp] methyl ester', 'C20377'): 0,
#  ('Apiforol', 'C12124'): 0,
#  ('(+)-alpha-Pinene', 'C06306'): 0,
#  ('2-Amino-2-deoxyisochorismate', 'C18054'): 0,
#  ('20,21-Diprenylterpendole J', 'C20594'): 0,
#  ('alpha-D-GalNAc-(1->3)-alpha-D-GalNAc-diphospho-ditrans,octacis-undecaprenol',
#   'C20621'): 0,
#  ('Picolinic acid', 'C10164'): 0,
#  ('Psychosine sulfate', 'C02744'): 0,
#  ('UDP-2-acetamido-2,6-dideoxy-alpha-D-galactose', 'C22261'): 0,
#  ('Labda-7,13(16),14-triene', 'C21728'): 0,
#  ('2-Amino-3-oxo-4-phosphonooxybutyrate', 'C07335'): 0,
#  ('(4R,5S)-4,5,6-Trihydroxy-2,3-dioxohexanoate', 'C04575'): 0,
#  ('1,4-Dihydroxy-2-naphthoyl-CoA', 'C15547'): 0,
#  ("Quercetin 3,3',7-trissulfate", 'C03897'): 0,
#  ('Deacetoxycephalosporin C', 'C06565'): 0,
#  ('UDP-L-Ara4O', 'C16155'): 0,
#  ('D-Glucose 1-phosphate', 'C00103'): 0,
#  ('2-Oxohept-3-enedioate', 'C03063'): 0,
#  ('Benzaldehyde', 'C00261'): 0,
#  ('Acrylic acid', 'C00511'): 0,
#  ('Itaconate', 'C00490'): 0,
#  ("D-4'-Phosphopantothenate", 'C03492'): 0,
#  ('3-Deoxy-D-glycero-D-galacto-non-2-ulopyranosonate 9-phosphate',
#   'C21383'): 0,
#  ('Malonylapiin', 'C05622'): 0,
#  ("2'''-N-Acetyl-6'''-deamino-6'''-hydroxyparomomycin II", 'C21261'): 0,
#  ('beta-Cryptoxanthin', 'C08591'): 0,
#  ('(R)-3-(4-Hydroxyphenyl)lactate', 'C03964'): 0,
#  ('D-Glutamate', 'C00217'): 0,
#  ('Eriodictyol', 'C05631'): 0,
#  ('dTDP-D-forosamine', 'C18034'): 0,
#  ('(2S)-2-Phospholactate', 'C19156'): 0,
#  ('C20817', 'C20817'): 0,
#  ('Precorrin 3A', 'C05772'): 0,
#  ('beta-Pinacene', 'C22052'): 0,
#  ('[Sulfur-carrier protein]-Gly-Gly-L-Cys', 'C21437'): 0,
#  ('2-Deoxy-D-ribose 5-phosphate', 'C00673'): 0,
#  ('Glutathionylaminopropylcadaverine', 'C16566'): 0,
#  ('2-Oxocyclohexane-1-carbonyl-CoA', 'C09813'): 0,
#  ('Enzyme N6-(S-propyldihydrolipoyl)lysine', 'C21018'): 0,
#  ('10-epi-Cubebol', 'C21700'): 0,
#  ('Sedoheptulose 1-phosphate', 'C06222'): 0,
#  ('(1E,3E)-4-Hydroxybuta-1,3-diene-1,2,4-tricarboxylate', 'C04324'): 0,
#  ('13-(2-Methylcrotonoyl)oxylupanine', 'C04170'): 0,
#  ('(2S)-Ethylmalonyl-CoA', 'C18026'): 0,
#  ('2-Caffeoylisocitrate', 'C02927'): 0,
#  ('5-PP-InsP5', 'C11526'): 0,
#  ('Etherolenic acid', 'C16319'): 0,
#  ('Apigenin 7-O-[beta-D-apiosyl-(1->2)-beta-D-glucoside]', 'C04858'): 0,
#  ('UDP-3-ketoglucose', 'C12210'): 0,
#  ('Digalactosyl-diacylglycerol', 'C06037'): 0,
#  ('L-xylo-Hexulonolactone', 'C03289'): 0,
#  ('5-Hydroxymethyluracil', 'C03088'): 0,
#  ('Urate', 'C00366'): 0,
#  ('Baccharis oxide', 'C20189'): 0,
#  ('5-L-Glutamyl-D-glutamyl-peptide', 'C16690'): 0,
#  ('Methostenol', 'C05111'): 0,
#  ('2-Hydroxy-1,4-benzoquinone', 'C07103'): 0,
#  ('all-trans-Polyprenyl diphosphate', 'C05847'): 0,
#  ('2,3-Bis-(O-geranylgeranyl)-sn-glycerol 1-phosphate', 'C04638'): 0,
#  ('D-Psicose', 'C06468'): 0,
#  ('Cyanoglycoside', 'C05713'): 0,
#  ('O-Succinyl-L-homoserine', 'C01118'): 0,
#  ('(+)-6-Hydroxypinoresinol', 'C22302'): 0,
#  ("3''-Oxogentamicin A2", 'C21265'): 0,
#  ('Quinolinate', 'C03722'): 0,
#  ('Squalene', 'C00751'): 0,
#  ('N5-Methyl-L-glutamine', 'C03153'): 0,
#  ('14,15-Epoxyemindole SB', 'C20529'): 0,
#  ("Lactose 6'-phosphate", 'C05396'): 0,
#  ('4-Aminocatechol', 'C18351'): 0,
#  ('3-Hydroxy-2-methylpropanoate', 'C01188'): 0,
#  ('(4R,5R)-4,5-Dihydroxycyclohexa-1(6),2-diene-1-carboxylate', 'C20710'): 0,
#  ('Abrine', 'C02983'): 0,
#  ('Metarhodopsin', 'C05916'): 0,
#  ('2,3-Dihydroxytoluene', 'C02923'): 0,
#  ('Monoglucosyl-enterobactin', 'C22180'): 0,
#  ('Triterpenoid', 'C06085'): 0,
#  ('Dextran', 'C00372'): 0,
#  ("7,4'-Dihydroxyflavone", 'C12123'): 0,
#  ('(6S)-6beta-Hydroxy-1,4,5,6-tetrahydronicotinamide-adenine dinucleotide phosphate',
#   'C04899'): 0,
#  ('1-Amino-1-deoxy-scyllo-inositol 4-phosphate', 'C01283'): 0,
#  ('3-Acylpyruvate', 'C02119'): 0,
#  ('dTDP-4-(methylamino)-2,3,4,6-tetradeoxy-D-glucose', 'C21395'): 0,
#  ('L-Cystathionine', 'C02291'): 0,
#  ('Apigenin', 'C01477'): 0,
#  ('Methyloxaloacetate', 'C06030'): 0,
#  ('dTDP-4-amino-2,4-dideoxy-beta-L-xylose', 'C21354'): 0,
#  ('Rhodovibrin', 'C15878'): 0,
#  ('3-Hydroxybenzaldehyde', 'C03067'): 0,
#  ('Palmitoleoyl-CoA', 'C21072'): 0,
#  ('Aurachin B', 'C21140'): 0,
#  ('3-Hydroxy-cis,cis-muconate', 'C03676'): 0,
#  ('1-Pyrroline-2-carboxylate', 'C03564'): 0,
#  ('Tenuazonic acid', 'C08511'): 0,
#  ('2-Acetolactate', 'C00900'): 0,
#  ('(4S,5S)-4,5-Dihydroxy-2,6-dioxohexanoate', 'C04471'): 0,
#  ('beta-D-Gal-(1->4)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol',
#   'C20618'): 0,
#  ('1,3,7-Trimethyluric acid', 'C16361'): 0,
#  ('5-Methylthio-D-ribose', 'C03089'): 0,
#  ('GDP-4-acetamido-4,6-dideoxy-alpha-D-mannose', 'C20672'): 0,
#  ('5-(5-Phospho-D-ribosylaminoformimino)-1-(5-phosphoribosyl)-imidazole-4-carboxamide',
#   'C04896'): 0,
#  ('Nopaline', 'C01682'): 0,
#  ('2,6-Di-O-alpha-D-mannosyl-1-phosphatidyl-1D-myo-inositol', 'C21607'): 0,
#  ('Amide', 'C00241'): 0,
#  ('(E)-2-(Methoxycarbonylmethyl)butenedioate', 'C11515'): 0,
#  ('gamma-Terpinene', 'C09900'): 0,
#  ('2-alpha-D-Glucosyl-D-glucose', 'C15548'): 0,
#  ('Biocytin', 'C05552'): 0,
#  ('2-(Glutathione-S-yl)-hydroquinone', 'C21563'): 0,
#  ('o-Benzoquinone', 'C02351'): 0,
#  ('2,3-Dihydrogossypetin', 'C03052'): 0,
#  ('Phylloquinone', 'C02059'): 0,
#  ('Mannobiose', 'C01728'): 0,
#  ('Nicotinic acid adenine dinucleotide phosphate', 'C13051'): 0,
#  ('Butanoic acid', 'C00246'): 0,
#  ('Neopentalenolactone D', 'C20402'): 0,
#  ('2-Polyprenyl-6-hydroxyphenol', 'C17551'): 0,
#  ('Formylphosphonate', 'C17943'): 0,
#  ('Sphinganine 1-phosphate', 'C01120'): 0,
#  ('(R)-Lactaldehyde', 'C00937'): 0,
#  ('Ceramide phosphoethanolamine', 'C06062'): 0,
#  ('Demethylsuberosin', 'C18083'): 0,
#  ('3-Amino-2-oxopropyl phosphate', 'C11638'): 0,
#  ('Geranyl-hydroxybenzoate', 'C18131'): 0,
#  ('Dihydrolipoyl-AMP', 'C22161'): 0,
#  ('Polyphosphate', 'C00404'): 0,
#  ('Penicillin N', 'C06564'): 0,
#  ('(+)-Corvol ether B', 'C21681'): 0,
#  ('Diplopterol', 'C06309'): 0,
#  ("Adenosylcobalamin 5'-phosphate", 'C21153'): 0,
#  ('3-Oxodecanoyl-[acp]', 'C05753'): 0,
#  ('Glycerophosphodiester', 'C03120'): 0,
#  ('N1,N5,N10-Tricoumaroyl spermidine', 'C18069'): 0,
#  ('(3Z)-Phytochromobilin', 'C05913'): 0,
#  ('(5R)-Carbapen-2-em-3-carboxylate', 'C06669'): 0,
#  ("5'-Acylphosphoadenosine", 'C03361'): 0,
#  ('Tetrahymanol', 'C06083'): 0,
#  ('1-Phosphatidyl-1D-myo-inositol 3-phosphate', 'C04549'): 0,
#  ('FMN-N5-oxide', 'C22238'): 0,
#  ('Reduced flavodoxin', 'C02745'): 0,
#  ('Pheophytin a', 'C05797'): 0,
#  ('5-O-beta-D-Mycaminosyltylactone', 'C12001'): 0,
#  ('N-Acyl-L-homoserine lactone', 'C18049'): 0,
#  ('(9Z,11E)-(13S)-13-Hydroperoxyoctadeca-9,11-dienoic acid', 'C04717'): 0,
#  ('Phenazine', 'C21476'): 0,
#  ('Chlorophyll b', 'C05307'): 0,
#  ('3-Carboxy-cis,cis-muconate', 'C01163'): 0,
#  ('D-4-Hydroxyphenylglycine', 'C03493'): 0,
#  ('4-(beta-Acetylaminoethyl)imidazole', 'C05135'): 0,
#  ('2-O-Caffeoylglucarate', 'C03062'): 0,
#  ("4'-Oxolividamine", 'C21257'): 0,
#  ('Cholesterol-5beta,6beta-epoxide', 'C05418'): 0,
#  ("UDP-N-acetyl-alpha-D-glucosamine 3'-phosphate", 'C20245'): 0,
#  ('N,N,N-Trimethylornithine lipid', 'C21675'): 0,
#  ('3-Hydroxypropanal', 'C00969'): 0,
#  ('6-Lactoyl-5,6,7,8-tetrahydropterin', 'C04244'): 0,
#  ('Rumenic acid', 'C04056'): 0,
#  ('(Stearoyl)adenylate', 'C22132'): 0,
#  ('Cephalosporin C', 'C00916'): 0,
#  ('6-Iminocyclohexa-2,4-dienone', 'C17500'): 0,
#  ('alpha-Zeacarotene', 'C14146'): 0,
#  ('Sapienoyl-CoA', 'C21943'): 0,
#  ('Chavicol', 'C16930'): 0,
#  ('Farnesyl triphosphate', 'C03115'): 0,
#  ('Vitamin D3', 'C05443'): 0,
#  ('Macrocin', 'C00744'): 0,
#  ('(+)-6-exo-Hydroxycamphor', 'C20322'): 0,
#  ('(3R)-3-Hydroxydodecanoyl-[acyl-carrier protein]', 'C05757'): 0,
#  ('Kanamycin C', 'C01823'): 0,
#  ('Stemar-13-ene', 'C18223'): 0,
#  ('3,6-Anhydro-alpha-L-galactopyranose', 'C20902'): 0,
#  ('3,5,7,9,11,13,15,17,19-Nonaoxo-docosanoyl-[acp]', 'C12356'): 0,
#  ('UDP-2-acetamido-4-(D-alanylamino)-2,4,6-trideoxy-alpha-D-mannopyranose',
#   'C22248'): 0,
#  ('trans,trans-Farnesyl diphosphate', 'C00448'): 0,
#  ('Ammeline', 'C08733'): 0,
#  ('[Reduced NADPH---hemoprotein reductase]', 'C03024'): 0,
#  ('D-Glucuronate 1-phosphate', 'C05385'): 0,
#  ('2,7-Dihydroxy-5-methyl-1-naphthoate', 'C20857'): 0,
#  ('NG,NG-Dimethyl-L-arginine', 'C03626'): 0,
#  ("5'-O-Phosphonoadenylyl-(3'->5')-adenosine", 'C22092'): 0,
#  ('1-Hydroxyalkyl-sn-glycerol', 'C03658'): 0,
#  ('(R)-3-Amino-2-methylpropanoate', 'C01205'): 0,
#  ('Indole-3-acetate', 'C00954'): 0,
#  ('1-Oxa-2-oxo-3-hydroxycycloheptane', 'C12314'): 0,
#  ('Phosphopantetheine', 'Z00038'): 0,
#  ('1,3,8-Naphthalenertriol', 'C01173'): 0,
#  ('2-Hydroxybenzoyl-CoA', 'C20394'): 0,
#  ('(R)-3-Hydroxybutanoyl-CoA', 'C03561'): 0,
#  ('2-Dehydro-3-deoxy-6-phospho-D-gluconate', 'C04442'): 0,
#  ('Luteoforol', 'C05907'): 0,
#  ('Hexanoyl-[acp]', 'C05749'): 0,
#  ('Cyclohexane-1-carbonyl-CoA', 'C09823'): 0,
#  ('6-(Hydroxymethyl)-7,8-dihydropterin', 'C01300'): 0,
#  ('Alcohol', 'C00069'): 0,
#  ('(E)-2-epi-beta-Caryophyllene', 'C20478'): 0,
#  ('2,5-Diamino-6-(5-phospho-D-ribitylamino)pyrimidin-4(3H)-one', 'C18910'): 0,
#  ('3-Ethylmalate', 'C01989'): 0,
#  ('Pantetheine', 'C00831'): 0,
#  ('Lycorine', 'C08532'): 0,
#  ('gamma-L-Glutamyl-S-(hercyn-2-yl)-L-cysteine S-oxide', 'C20995'): 0,
#  ('trans-2,3-Dehydroacyl-CoA', 'C00658'): 0,
#  ('1,4-Dihydroxy-6-naphthoate', 'C17018'): 0,
#  ('Hydroxymethylphosphonate', 'C06455'): 0,
#  ('L-Glutamyl 5-phosphate', 'C03287'): 0,
#  ('9(S)-HPODE', 'C14827'): 0,
#  ('Thiocyanate', 'C01755'): 0,
#  ("3''-O-Acetyl-ADP-D-ribose", 'C22131'): 0,
#  ('Copper', 'C00070'): 0,
#  ('2-Aminomalonate semialdehyde', 'C11822'): 0,
#  ('GA2', 'C06135'): 0,
#  ('2-Dehydro-D-glucono-1,5-lactone', 'C06440'): 0,
#  ('Carboxybiotin-carboxyl-carrier protein', 'C04419'): 0,
#  ('Pelargonidin 3-glucoside 5-caffeoylglucoside', 'C16371'): 0,
#  ('Fructoselysine 6-phosphate', 'C16489'): 0,
#  ('Sinapate', 'C00482'): 0,
#  ('Acylcholine', 'C01777'): 0,
#  ('(+)-Catechin', 'C06562'): 0,
#  ('Diacetylheptaprenylglycerol', 'C22342'): 0,
#  ('(E,E)-Geranyllinalool', 'C20681'): 0,
#  ('D-Ribulose 1-phosphate', 'C22337'): 0,
#  ('Hydrogenobyrinate', 'C06399'): 0,
#  ('N1-Hydroxy-roquefortine C', 'C22169'): 0,
#  ('Gentamicin A', 'C01917'): 0,
#  ('S-Formylmycothiol', 'C06718'): 0,
#  ('beta-D-Glucosaminyl-(1->4)-N-acetyl-D-glucosamine', 'C22320'): 0,
#  ('Palmatine', 'C05315'): 0,
#  ('Isonocardicin C', 'C17352'): 0,
#  ('3-[(1E,4R)-4-Hydroxycyclohex-2-en-1-ylidene]-2-oxopropanoate', 'C21085'): 0,
#  ('Hydantoin-5-propionate', 'C05565'): 0,
#  ('3-Amino-2,3-dideoxy-scyllo-inosose', 'C17581'): 0,
#  ('Methylisoeugenol', 'C10478'): 0,
#  ('Citramalate', 'C00815'): 0,
#  ('beta-Alaninamide', 'C19779'): 0,
#  ('Decanoyl-[acp]', 'C05755'): 0,
#  ('5-Amino-2-oxopentanoic acid', 'C01110'): 0,
#  ('gamma-Carotene', 'C05435'): 0,
#  ('3Fe4S', 'Z00067'): 0,
#  ('beta-Selinene', 'C09723'): 0,
#  ('Antheraxanthin', 'C08579'): 0,
#  ('(2-Amino-1-hydroxyethyl)phosphonate', 'C05678'): 0,
#  ('(S,S)-Butane-2,3-diol', 'C03046'): 0,
#  ('4,4-Dimethyl-5alpha-cholesta-8,14,24-trien-3beta-ol', 'C11455'): 0,
#  ('D-Glucono-1,5-lactone 6-phosphate', 'C01236'): 0,
#  ('(3S)-3-Hydroxyadipyl-CoA', 'C14145'): 0,
#  ('2-(Hydroxymethyl)-4-oxobutanoate', 'C04106'): 0,
#  ('(+)-Sabinene', 'C20230'): 0,
#  ('Cobalt-precorrin 3', 'C11539'): 0,
#  ('Putrescine', 'C00134'): 0,
#  ('Fumiquinazoline D', 'C22149'): 0,
#  ('3-Hydroxy-OPC8-CoA', 'C16329'): 0,
#  ('beta-1,2-Mannobiose', 'C21336'): 0,
#  ('dTDP-L-rhamnose', 'C03319'): 0,
#  ('D-Xylulose', 'C00310'): 0,
#  ('trans-Geranyl-CoA', 'C16465'): 0,
#  ('Taxa-4(5),11(12)-diene', 'C11894'): 0,
#  ('UDP-alpha-D-galactofuranose', 'C03733'): 0,
#  ('RCH2NH2', 'C00375'): 0,
#  ('2-Oxo-4-phenylbutyric acid', 'C20327'): 0,
#  ('4-Hydroxyphenylacetaldehyde', 'C03765'): 0,
#  ('Activated methyl group', 'C10905'): 0,
#  ('(2S,3S)-2,3-Dihydro-2,3-dihydroxybenzoate', 'C04171'): 0,
#  ('all-trans-Phytofluene', 'C05414'): 0,
#  ('(2R)-1,2-Epoxypropane', 'C11506'): 0,
#  ('D-Tagaturonate', 'C00558'): 0,
#  ('(E)-gamma-Bisabolene', 'C19748'): 0,
#  ('1,2-Diacyl-3-beta-D-galactosyl-sn-glycerol', 'C03692'): 0,
#  ('gamma-Humulene', 'C16829'): 0,
#  ('5-Deoxyleucopelargonidin', 'C16415'): 0,
#  ('L-Fuconate', 'C01720'): 0,
#  ('4,5-Dihydroxyphthalate', 'C03233'): 0,
#  ('di-trans,poly-cis-Undecaprenyl diphosphate', 'C04574'): 0,
#  ('L-Histidinol phosphate', 'C01100'): 0,
#  ('(-)-endo-Fenchol', 'C02344'): 0,
#  ('4-Methyl-3-oxoadipate', 'C18312'): 0,
#  ('3-Hydroxy-2-methylpyridine-4,5-dicarboxylate', 'C04604'): 0,
#  ('Achilleol B', 'C20187'): 0,
#  ('2-Succinylbenzoate', 'C02730'): 0,
#  ('3-Phospho-D-glyceroyl phosphate', 'C00236'): 0,
#  ('alpha-Isopropylmalate', 'C02504'): 0,
#  ('Toluene-cis-dihydrodiol', 'C04592'): 0,
#  ('L-Glutamate 5-semialdehyde', 'C01165'): 0,
#  ('Sodium', 'Z00033'): 0,
#  ('Manoyl oxide', 'C21725'): 0,
#  ('beta-Cubebene', 'C09648'): 0,
#  ('Geranial', 'C01499'): 0,
#  ('Nicotinamide', 'C00153'): 0,
#  ('2,6-Dihydroxynicotinate', 'C15523'): 0,
#  ('Histamine', 'C00388'): 0,
#  ('Glycine cleavage system H', 'C22157'): 0,
#  ('alpha-D-Galactosyl-(1->4)-beta-D-galactosyl-(1->4)-beta-D-glucosyl-(1<->1)-ceramide',
#   'C04737'): 0,
#  ('Terpendole B', 'C20528'): 0,
#  ('Perillyl-CoA', 'C11929'): 0,
#  ('Dopaquinone', 'C00822'): 0,
#  ('D-Threonate', 'C21649'): 0,
#  ('Monodehydroascorbate', 'C01041'): 0,
#  ("4-(Cytidine 5'-diphospho)-2-C-methyl-D-erythritol", 'C11435'): 0,
#  ('Acetylcholine', 'C01996'): 0,
#  ('Baruol', 'C20200'): 0,
#  ('Terpendole K', 'C20552'): 0,
#  ('UDP-N-acetylmuramoyl-L-alanyl-gamma-D-glutamyl-meso-2,6-diaminopimelate',
#   'C04877'): 0,
#  ('Norcraugsodine', 'C21634'): 0,
#  ('Siroheme', 'C00748'): 0,
#  ('(S)-2-Methylbutanoyl-CoA', 'C15980'): 0,
#  ('OPC4-CoA', 'C16335'): 0,
#  ('Fumiquinazoline C', 'C22148'): 0,
#  ('3,4-Dihydroxyphenylacetaldehyde', 'C04043'): 0,
#  ('Hexadecanoic acid', 'C00249'): 0,
#  ('o-Methoxyphenol', 'C01502'): 0,
#  ('Nezukol', 'C21709'): 0,
#  ('2-Oxopropyl-CoM', 'C11497'): 0,
#  ('3,4-Dihydroxyphenylacetate', 'C01161'): 0,
#  ('D-glycero-alpha-D-manno-Heptose 1-phosphate', 'C19880'): 0,
#  ('D-Erythronate', 'C21593'): 0,
#  ('Vermelone', 'C01624'): 0,
#  ('Methyl (indol-3-yl)acetate', 'C20635'): 0,
#  ('N-Acetylmuramic acid 6-phosphate', 'C16698'): 0,
#  ('Presilphiperfolan-8beta-ol', 'C19756'): 0,
#  ('ent-8alpha-Hydroxylabd-13-en-15-yl diphosphate', 'C21656'): 0,
#  ('Prunasin', 'C00844'): 0,
#  ('2-Iminopropanoate', 'C20904'): 0,
#  ('Theophylline', 'C07130'): 0,
#  ('(E,E)-4,8,12-Trimethyltrideca-1,3,7,11-tetraene', 'C20700'): 0,
#  ('Neomethymycin', 'C11995'): 0,
#  ('Camphene', 'C06076'): 0,
#  ('3-(Uracil-1-yl)-L-alanine', 'C03584'): 0,
#  ('dTDP-4-oxo-2,6-dideoxy-D-glucose', 'C11922'): 0,
#  ('N-Methylanthraniloyl-CoA', 'C12092'): 0,
#  ('N6-(1,2-Dicarboxyethyl)-AMP', 'C03794'): 0,
#  ('Xylitol 5-phosphate', 'C02895'): 0,
#  ('(R)-Mevalonate 3,5-bisphosphate', 'C20848'): 0,
#  ('3,4-Dihydroxystyrene', 'C06224'): 0,
#  ('Isopentenyl adenosine', 'C16427'): 0,
#  ('(Indol-3-yl)acetamide', 'C02693'): 0,
#  ('Salvianin', 'C12647'): 0,
#  ('Isoformononetin', 'C12125'): 0,
#  ('hn', 'C00205'): 0,
#  ('Deoxy-5-methylcytidylate', 'C03495'): 0,
#  ("5'-Oxoinosine", 'C01993'): 0,
#  ('D-Glucono-1,5-lactone', 'C00198'): 0,
#  ('3,4-Dihydrospheroidene', 'C15895'): 0,
#  ('5-Dehydro-D-fructose', 'C00273'): 0,
#  ('Miltiradiene', 'C20711'): 0,
#  ('5-Methoxytryptamine', 'C05659'): 0,
#  ('Hydropyrenol', 'C22109'): 0,
#  ('2-Dehydro-3-deoxy-D-glucarate', 'C03921'): 0,
#  ('Biotinyl-CoA', 'C01894'): 0,
#  ('Oxaloglutarate', 'C05533'): 0,
#  ('ent-Atiserene', 'C21711'): 0,
#  ('5-Methyl-5,6,7,8-tetrahydromethanopterin', 'C04488'): 0,
#  ('gamma-L-Glutamyl-[acp]', 'C18006'): 0,
#  ('Barbiturate', 'C00813'): 0,
#  ('2-Hydroxyethylenedicarboxylate', 'C03981'): 0,
#  ('1,3,6,8-Naphthalenetetrol', 'C04033'): 0,
#  ('UDP-L-arabinose', 'C00935'): 0,
#  ('dTDP-3-amino-3,6-dideoxy-D-glucose', 'C11925'): 0,
#  ('L-Xylulose', 'C00312'): 0,
#  ('7,8-Dihydro-beta-carotene', 'C16291'): 0,
#  ('2,4-Diacetamido-2,4,6-trideoxy-beta-L-gulose', 'C22254'): 0,
#  ('Neohesperidin', 'C09806'): 0,
#  ('dTDP-3-amino-3,6-dideoxy-alpha-D-galactopyranose', 'C19947'): 0,
#  ('Nicotine', 'C00745'): 0,
#  ('tritrans,heptacis-Undecaprenyl diphosphate', 'C19852'): 0,
#  ("4'-Oxonebramine", 'C21258'): 0,
#  ('3-Methylindolepyruvate', 'C05644'): 0,
#  ('Thiamin monophosphate', 'C01081'): 0,
#  ('5alpha-Cholestan-3-one', 'C03238'): 0,
#  ('Garbanzol', 'C09751'): 0,
#  ('3-Hydroxy-5-methylhex-4-enoyl-CoA', 'C16469'): 0,
#  ("4,4'-Diapophytofluene", 'C19840'): 0,
#  ('D-Apionate', 'C22219'): 0,
#  ('Licodione', 'C01592'): 0,
#  ('Prephytoene diphosphate', 'C03427'): 0,
#  ('5-Amino-4-imidazolecarboxyamide', 'C04051'): 0,
#  ('D-Altronate', 'C00817'): 0,
#  ('Crotonoyl-CoA', 'C00877'): 0,
#  ('Mycothiol', 'C06717'): 0,
#  ('all-trans-Heptaprenyl diphosphate', 'C04216'): 0,
#  ('2-Acyl-sn-glycerol 3-phosphate', 'C03974'): 0,
#  ('5-Hydroxykynurenine', 'C05651'): 0,
#  ('2-cis,6-cis-Farnesyl diphosphate', 'C19760'): 0,
#  ('Deamino-alpha-keto-demethylphosphinothricin', 'C17948'): 0,
#  ('(10aS)-10,10a-Dihydrophenazine-1-carboxylate', 'C21412'): 0,
#  ('3-O-alpha-Mycarosylerythronolide B', 'C06630'): 0,
#  ('Fecosterol', 'C04525'): 0,
#  ('dTDP-3-amino-4-oxo-2,3,6-trideoxy-L-allose', 'C21137'): 0,
#  ('(2S)-2-Amino-4-{[(1R)-1-carboxy-2-(1H-imidazol-4-yl)ethyl]amino}butanoate',
#   'C22025'): 0,
#  ('L-Ascorbate 6-phosphate', 'C16186'): 0,
#  ('3-Ketolactose', 'C05403'): 0,
#  ('2-Hydroxy-5-methyl-1-naphthoate', 'C20856'): 0,
#  ("2',3'-Cyclic CMP", 'C02354'): 0,
#  ('D-Ribulose', 'C00309'): 0,
#  ('Xanthoxin', 'C13453'): 0,
#  ("2,3',4,6-Tetrahydroxybenzophenone", 'C06355'): 0,
#  ('Abscisic acid glucose ester', 'C15970'): 0,
#  ('L-Lyxonate', 'C05412'): 0,
#  ('Alkyl cinnamate', 'C06357'): 0,
#  ('Coenzyme F420-1', 'C19152'): 0,
#  ('(4S)-4-Methyl-3-oxohexanoyl-[acyl-carrier-protein]', 'C22370'): 0,
#  ('3-Deoxy-D-glycero-D-galacto-non-2-ulopyranosonate', 'C20934'): 0,
#  ('7(1)-Hydroxychlorophyllide a', 'C16540'): 0,
#  ('L-Galactose', 'C01825'): 0,
#  ('Heptaprenylglycerol', 'C22341'): 0,
#  ('(7R)-7-(5-Carboxy-5-oxopentanoyl)aminocephalosporinate', 'C04712'): 0,
#  ('D-2,3-Diketo 4-deoxy-epi-inositol', 'C06891'): 0,
#  ('Nalpha-Methylhistidine', 'C03298'): 0,
#  ('2,3-Dimethyl-5-phytylquinol', 'C15883'): 0,
#  ('Cyclopropanecarboxyl-CoA', 'C16268'): 0,
#  ('(+)-3-Carene', 'C11382'): 0,
#  ('2-Hexaprenyl-6-methoxyphenol', 'C05802'): 0,
#  ('Nickel-sirohydrochlorin', 'C21510'): 0,
#  ('Geranoyl-CoA', 'C01920'): 0,
#  ('2-Hydroxy-2,4-pentadienoate', 'C00596'): 0,
#  ("1-(5'-Phosphoribosyl)-5-amino-4-imidazolecarboxamide", 'C04677'): 0,
#  ('Novamethymycin', 'C20741'): 0,
#  ('Guanine', 'C00242'): 0,
#  ('L-Lyxose', 'C01508'): 0,
#  ('Glycerophosphoglycoglycerolipid', 'C06041'): 0,
#  ('6-Carboxyhex-2-enoyl-CoA', 'C06723'): 0,
#  ('(S)-1,2-Epoxypropane', 'C11507'): 0,
#  ('O-Sinapoylglucarate', 'C02866'): 0,
#  ('L-Anticapsin', 'C20941'): 0,
#  ('Laminaribiose', 'C02048'): 0,
#  ('Cobalt-precorrin 4', 'C11540'): 0,
#  ("N,N'-Diacetyllegionaminate", 'C20418'): 0,
#  ('dTDP-4-hydroxyamino-4,6-dideoxy-alpha-D-glucose', 'C21348'): 0,
#  ('beta-Nitropropanoate', 'C05669'): 0,
#  ('4-(2-Amino-5-hydroxyphenyl)-2,4-dioxobutanoate', 'C05652'): 0,
#  ('S,S-Dimethyl-beta-propiothetin', 'C04022'): 0,
#  ('Nitroxyl', 'C20937'): 0,
#  ('3,4-Dihydroxy-2-methy-4-[(2E,6E)-farnesyl]-3,4-dihydroquinoline 1-oxide',
#   'C21142'): 0,
#  ('Alanopine', 'C03210'): 0,
#  ('3-(Methylthio)propanoate', 'C08276'): 0,
#  ('2-Hydroxyisobutanoyl-CoA', 'C21287'): 0,
#  ('Triacylglycerol', 'C00422'): 0,
#  ('S-[(Z)-N-Hydroxy(phenyl)acetimidoyl]-L-glutathione', 'C21622'): 0,
#  ('8(R)-HPODE', 'C14831'): 0,
#  ('11-Oxocucurbitadienol', 'C21841'): 0,
#  ('4-Dimethylallyl-L-abrine', 'C20410'): 0,
#  ('Phenyl 5-phospho-alpha-D-ribofuranoside', 'C20726'): 0,
#  ('Hydroxyproline', 'C01157'): 0,
#  ('Xanthurenic acid', 'C02470'): 0,
#  ('N-Carbamyl-L-glutamate', 'C05829'): 0,
#  ('all-trans-zeta-Carotene', 'C05430'): 0,
#  ('6-Methylsalicylyl-CoA', 'C21312'): 0,
#  ('Quinate', 'C00296'): 0,
#  ('(3S)-Citramalyl-CoA', 'C01011'): 0,
#  ('5-Hydroxyconiferyl alcohol', 'C12205'): 0,
#  ('2-(Hydroxysulfanyl)hercynine', 'C21731'): 0,
#  ("N-(5'-Phospho-D-1'-ribulosylformimino)-5-amino-1-(5''-phospho-D-ribosyl)-4-imidazolecarboxamide",
#   'C04916'): 0,
#  ('(2E)-3-(4-Hydroxyphenyl)-2-isocyanoprop-2-enoate', 'C21891'): 0,
#  ("Adenosine 5'-phosphoramidate", 'C03851'): 0,
#  ('(8E,10R,12Z)-10-Hydroperoxy-8,12-octadecadienoate', 'C19937'): 0,
#  ('3-Oxo-5,6-dehydrosuberyl-CoA semialdehyde', 'C19946'): 0,
#  ('Indole-3-acetaldoxime N-oxide', 'C17204'): 0,
#  ("(R)-4'-Phosphopantothenoyl-L-cysteine", 'C04352'): 0,
#  ('5,7-Dihydroxy-2-methyl-4H-chromen-4-one', 'C20462'): 0,
#  ('N-Acetylisatin', 'C02172'): 0,
#  ('(2-Methylthio)acetaldehyde', 'C22279'): 0,
#  ("1,1'-Dihydroxylycopene", 'C19894'): 0,
#  ('2,4-Diacetamido-2,4,6-trideoxy-D-mannopyranose', 'C20424'): 0,
#  ('Roquefortine D', 'C22163'): 0,
#  ("6'-Oxokanamycin C", 'C21252'): 0,
#  ('Indole-3-ethanol', 'C00955'): 0,
#  ('2-Hydroxymuconate semialdehyde', 'C00682'): 0,
#  ('Pimeloyl-[acyl-carrier protein]', 'C19845'): 0,
#  ('Hesperetin 7-O-glucoside', 'C16422'): 0,
#  ('2-Acyl-sn-glycero-3-phosphoserine', 'C05974'): 0,
#  ...}

# %%
# compare ETU with LTU

# bokeh plot:
remove = ['C00001', 'C00080']  # remove H2O and H+
d1 = {k:v for k,v in cpd2ETUlineagesNum.items() if k not in remove}
d2 = {k:v for k,v in cpd2LTUlineagesNum.items() if k not in remove}

p = figure(width=800, height=800)

# Add annotations
valid_keys, data1, data2 = todata(d1, d2)

source = {'x': data1, 'y': data2, 'label': [f"{cpd2name.get(key, 'no name')}" for key in valid_keys]}
p.scatter('x', 'y', source=source, size=10, alpha=0.5)

# Add hover tool
hover = HoverTool()
hover.tooltips = [("cpd", "@label")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = '#ETU lineages'
p.yaxis.axis_label = '#LTU lineages'
# p.xaxis.ticker = [50, 100, 150, 200, 250, 300, 350]  # Convert range to list
p.xgrid.grid_line_color = None

# Show the plot
show(p)

# %%
cpd2ETUlineagesNum['C00007']/cpd2LTUlineagesNum['C00007']
# Out:
# 0.3870967741935484

# %%
# outlier
cpd2ETUlineagesNum['C02999'], cpd2LTUlineagesNum['C02999']
# Out:
# (3, 1)

# %%
# ratio instead
# more ETU -> more emergence than recruitment
# more LTU -> more recruitment than emergence

cpd2ratio = {}
for c, v in cpd2ETUlineagesNum.items():
    if v > 2 and c != 'C02999':  # only highly influential cpds
        if cpd2LTUlineagesNum[c] != 0:
            cpd2ratio[c] = cpd2ETUlineagesNum[c]/cpd2LTUlineagesNum[c]
        else:
            print(c, cpd2name[c])

scatter(cpd2foMean, cpd2ratio, x_axis='folditer', y_axis='ETU/LTU')

# %%
d1 = cpd2foMean
d2 = cpd2ratio

p = figure(width=800, height=800)

# Add annotations
valid_keys, data1, data2 = todata(d1, d2)

source = {'x': data1, 'y': data2, 'label': [f"{cpd2name.get(key, 'no name')}" for key in valid_keys]}
p.scatter('x', 'y', source=source, size=10, alpha=0.5)

# Add hover tool
hover = HoverTool()
hover.tooltips = [("cpd", "@label")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = 'iter'
p.yaxis.axis_label = 'ETU/LTU'
# p.xaxis.ticker = [50, 100, 150, 200, 250, 300, 350]  # Convert range to list
p.xgrid.grid_line_color = None

# Show the plot
show(p)

# %% [markdown]
# # 3. lineage reuse timing

# %% [markdown]
# ## x2usage (mean, std) across 1000 runs of ATP pre-expansion

# %%
# # this takes a while

# run2x2usage = {}
# for run in df_folds_folditer.columns:

#     rule2fo = {}
#     for key, value in df_rules_folditer[run].items():
#         if eval(key)[1] not in rule2fo.keys():
#             rule2fo[eval(key)[1]] = [value]
#         else:
#             rule2fo[eval(key)[1]].append(value)
    
#     folditer2rules = {}
#     for key, values in rule2fo.items():
#         for value in values:
#             if value not in folditer2rules.keys():
#                 folditer2rules[value] = [key]
#             else:
#                 folditer2rules[value].append(key)
            
#     x2usage = {x:set() for x in df_folds_folditer[run].keys()}  # empty dict
    
#     for i, rules in folditer2rules.items():
#         for rule in rules:
#             for x in rule:
#                 x2usage[x].add(i)  # don't record multiple usage within one fold_iter
#     x2usage.pop('fold_independent')
#     x2usage.pop('spontaneous')
    
#     run2x2usage[run] = x2usage

# with open('../data/assets/run2x2usage.pkl', 'wb') as file:
#     pickle.dump(run2x2usage, file)

# %%
run2x2usage = pd.read_pickle('../data/assets/run2x2usage.pkl')

# %%
x2foMean_od = dict(sorted(x2foMean.items(), key=lambda item: item[1]))
x2usageNum_1000 = {k:[] for k in x2foMean_od.keys()}  # enforce mean order

for x2usage in run2x2usage.values():
    for x, usage in x2usage.items():
        x2usageNum_1000[x].append(len(usage))

# %%
def scatter(dict1, dict2, x_axis = 'x-axis', y_axis = 'y-axis', savefig=False):
    fig, ax = plt.subplots()
    
    valid_keys, data1, data2 = todata(dict1, dict2)
    plt.scatter(data1, data2, marker='o', color='b', alpha = 0.1, label='Data Points', zorder=2)
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)

    if savefig:
        plt.savefig(f'scatter_{x_axis}_{y_axis}.png', dpi=300, bbox_inches='tight')
    
    plt.show()

# %%
x2usageNum_Mean = {k:np.mean(v) for k,v in x2usageNum_1000.items()}
x2usageNum_Std = {k:np.std(v) for k,v in x2usageNum_1000.items()}

scatter(x2usageNum_Mean, x2usageNum_Std, 'Mean lineage reuse count', 'SD lineage reuse count', savefig=False)

# %%
p = figure(width=400, height=300)

# define data
d1 = x2usageNum_Mean
d2 = x2usageNum_Std

valid_keys, data1, data2 = todata(d1, d2)
# data2 = np.log10(data2)
labels = [x2name.get(key, key) for key in valid_keys]
# colors = [class2color2[x2class[k]] for k in valid_keys]

# source
source = ColumnDataSource(data={
    'x': data1,
    'y': data2,
    'label': labels
})

p.scatter('x', 'y', source=source, size=10, alpha=0.5, line_color=None)
# p.scatter('x', 'y', source=source, size=10, alpha=1, line_color=None, fill_color='color')

# Add hover tool
hover = HoverTool()
hover.tooltips = [("X", "@label")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = 'Mean'
p.yaxis.axis_label = 'Std'
# p.xaxis.ticker = [0, 50, 100, 150, 200, 250, 300, 350]  # Convert range to list
p.xgrid.grid_line_color = None

# output_file("scatter.html")
show(p)

# %% [markdown]
# ### cpd2reuseNum

# %%
run2fo2reuseNum = {}
for run, x2usage in run2x2usage.items():
    fo2lineagesUsed = {}
    for x, usage in x2usage.items():
        for fo in usage:
            if fo not in fo2lineagesUsed:
                fo2lineagesUsed[fo] = set([x])
            else:
                fo2lineagesUsed[fo].add(x) 
    fo2lineagesUsedNum = {fo:len(lineagesUsed) for fo, lineagesUsed in fo2lineagesUsed.items()}
    
    fo2lineagesUsedNum_Full = {}
    for i in range(0, max(fo2lineagesUsedNum.keys())+1):
        if i not in fo2lineagesUsedNum.keys():
            fo2lineagesUsedNum_Full[i] = 0
        else:
            fo2lineagesUsedNum_Full[i] = fo2lineagesUsedNum[i]

    run2fo2reuseNum[run] = fo2lineagesUsedNum_Full

# %%
# FAD, SAM, chorismate, phylloquinone, oxygen
innovation2reuse = {'C00016': [], 'C00019': [], 'C00251': [], 'C02059': [], 'C00007': []}
for c in innovation2reuse.keys():
    for run, i in df_cpds_folditer.loc[c].items():
        innovation2reuse[c].append(run2fo2reuseNum[run][i])

# %%
innovation2reuse['C00007']
# Out:
# [99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  99,
#  99,
#  98,
#  98,
#  100,
#  100,
#  98,
#  98,
#  100,
#  100,
#  99,
#  98,
#  98,
#  100,
#  100,
#  98,
#  98,
#  98,
#  99,
#  98,
#  99,
#  100,
#  100,
#  100,
#  99,
#  99,
#  98,
#  98,
#  99,
#  98,
#  99,
#  100,
#  98,
#  98,
#  100,
#  99,
#  100,
#  98,
#  98,
#  98,
#  100,
#  100,
#  98,
#  98,
#  100,
#  98,
#  100,
#  99,
#  100,
#  98,
#  98,
#  98,
#  100,
#  99,
#  98,
#  99,
#  98,
#  98,
#  100,
#  99,
#  98,
#  100,
#  99,
#  98,
#  100,
#  100,
#  99,
#  98,
#  99,
#  98,
#  100,
#  100,
#  99,
#  100,
#  98,
#  100,
#  98,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  98,
#  98,
#  100,
#  99,
#  100,
#  98,
#  99,
#  98,
#  100,
#  99,
#  100,
#  99,
#  99,
#  98,
#  100,
#  100,
#  100,
#  98,
#  100,
#  98,
#  99,
#  100,
#  98,
#  98,
#  100,
#  98,
#  100,
#  99,
#  100,
#  100,
#  98,
#  98,
#  99,
#  99,
#  99,
#  99,
#  100,
#  99,
#  98,
#  100,
#  100,
#  98,
#  99,
#  100,
#  99,
#  98,
#  99,
#  100,
#  100,
#  100,
#  98,
#  99,
#  100,
#  100,
#  100,
#  98,
#  100,
#  98,
#  99,
#  100,
#  100,
#  99,
#  98,
#  100,
#  100,
#  100,
#  100,
#  98,
#  98,
#  99,
#  99,
#  98,
#  99,
#  98,
#  100,
#  100,
#  100,
#  100,
#  98,
#  98,
#  100,
#  99,
#  99,
#  99,
#  98,
#  100,
#  99,
#  100,
#  99,
#  99,
#  100,
#  98,
#  98,
#  98,
#  98,
#  99,
#  99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  99,
#  100,
#  98,
#  99,
#  98,
#  98,
#  99,
#  99,
#  100,
#  98,
#  98,
#  100,
#  99,
#  100,
#  99,
#  99,
#  98,
#  98,
#  100,
#  100,
#  99,
#  100,
#  98,
#  100,
#  99,
#  99,
#  99,
#  98,
#  98,
#  98,
#  100,
#  100,
#  99,
#  100,
#  99,
#  98,
#  99,
#  100,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  99,
#  99,
#  100,
#  100,
#  99,
#  98,
#  98,
#  98,
#  99,
#  98,
#  100,
#  99,
#  98,
#  98,
#  98,
#  98,
#  100,
#  100,
#  99,
#  98,
#  100,
#  100,
#  99,
#  99,
#  100,
#  98,
#  98,
#  99,
#  98,
#  98,
#  100,
#  99,
#  100,
#  98,
#  99,
#  99,
#  99,
#  98,
#  100,
#  98,
#  98,
#  99,
#  98,
#  99,
#  99,
#  99,
#  99,
#  98,
#  99,
#  99,
#  99,
#  98,
#  99,
#  99,
#  98,
#  100,
#  98,
#  99,
#  99,
#  100,
#  100,
#  98,
#  99,
#  98,
#  99,
#  99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  100,
#  98,
#  98,
#  100,
#  98,
#  100,
#  99,
#  99,
#  100,
#  99,
#  98,
#  98,
#  99,
#  99,
#  99,
#  99,
#  99,
#  98,
#  99,
#  100,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  98,
#  98,
#  98,
#  98,
#  99,
#  98,
#  98,
#  100,
#  99,
#  100,
#  100,
#  99,
#  98,
#  99,
#  99,
#  99,
#  100,
#  99,
#  99,
#  100,
#  99,
#  98,
#  100,
#  98,
#  98,
#  99,
#  100,
#  99,
#  99,
#  100,
#  98,
#  98,
#  100,
#  99,
#  98,
#  100,
#  98,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  100,
#  98,
#  98,
#  98,
#  100,
#  98,
#  98,
#  98,
#  99,
#  98,
#  100,
#  99,
#  100,
#  98,
#  99,
#  100,
#  98,
#  98,
#  98,
#  100,
#  99,
#  100,
#  98,
#  98,
#  99,
#  99,
#  99,
#  98,
#  98,
#  98,
#  99,
#  98,
#  99,
#  100,
#  99,
#  98,
#  100,
#  100,
#  100,
#  98,
#  99,
#  100,
#  100,
#  99,
#  99,
#  99,
#  98,
#  99,
#  100,
#  99,
#  98,
#  99,
#  98,
#  99,
#  98,
#  100,
#  100,
#  100,
#  99,
#  98,
#  100,
#  99,
#  100,
#  99,
#  99,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  100,
#  98,
#  98,
#  99,
#  100,
#  99,
#  100,
#  100,
#  100,
#  98,
#  98,
#  100,
#  98,
#  99,
#  100,
#  99,
#  100,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  98,
#  98,
#  100,
#  100,
#  100,
#  100,
#  100,
#  98,
#  98,
#  98,
#  99,
#  98,
#  98,
#  98,
#  100,
#  99,
#  100,
#  100,
#  99,
#  100,
#  99,
#  98,
#  99,
#  98,
#  100,
#  100,
#  99,
#  99,
#  100,
#  100,
#  100,
#  100,
#  98,
#  99,
#  98,
#  99,
#  100,
#  100,
#  100,
#  99,
#  100,
#  98,
#  100,
#  99,
#  98,
#  99,
#  99,
#  98,
#  100,
#  99,
#  98,
#  100,
#  100,
#  100,
#  99,
#  99,
#  100,
#  99,
#  100,
#  99,
#  98,
#  100,
#  99,
#  99,
#  100,
#  100,
#  100,
#  99,
#  98,
#  99,
#  99,
#  100,
#  100,
#  99,
#  98,
#  99,
#  98,
#  100,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  99,
#  98,
#  100,
#  98,
#  99,
#  99,
#  98,
#  100,
#  99,
#  99,
#  98,
#  99,
#  99,
#  98,
#  98,
#  98,
#  98,
#  99,
#  98,
#  99,
#  98,
#  99,
#  99,
#  100,
#  100,
#  98,
#  98,
#  98,
#  100,
#  100,
#  99,
#  99,
#  99,
#  98,
#  100,
#  100,
#  99,
#  100,
#  98,
#  99,
#  99,
#  100,
#  98,
#  99,
#  99,
#  100,
#  99,
#  99,
#  98,
#  99,
#  98,
#  99,
#  100,
#  100,
#  100,
#  98,
#  99,
#  99,
#  100,
#  98,
#  100,
#  99,
#  100,
#  100,
#  100,
#  98,
#  98,
#  98,
#  98,
#  99,
#  98,
#  98,
#  98,
#  98,
#  100,
#  100,
#  98,
#  98,
#  98,
#  98,
#  100,
#  100,
#  99,
#  99,
#  99,
#  100,
#  98,
#  99,
#  100,
#  99,
#  100,
#  100,
#  99,
#  99,
#  99,
#  99,
#  99,
#  99,
#  100,
#  98,
#  100,
#  100,
#  98,
#  100,
#  99,
#  100,
#  100,
#  98,
#  98,
#  98,
#  99,
#  100,
#  98,
#  98,
#  99,
#  100,
#  99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  99,
#  100,
#  100,
#  100,
#  98,
#  100,
#  100,
#  100,
#  98,
#  99,
#  98,
#  98,
#  99,
#  98,
#  99,
#  99,
#  98,
#  98,
#  98,
#  100,
#  99,
#  99,
#  98,
#  98,
#  100,
#  98,
#  99,
#  100,
#  100,
#  99,
#  99,
#  100,
#  99,
#  98,
#  98,
#  98,
#  98,
#  100,
#  98,
#  100,
#  100,
#  99,
#  99,
#  100,
#  100,
#  99,
#  99,
#  99,
#  98,
#  99,
#  99,
#  100,
#  98,
#  98,
#  99,
#  100,
#  99,
#  98,
#  99,
#  98,
#  100,
#  98,
#  100,
#  99,
#  99,
#  99,
#  100,
#  99,
#  98,
#  98,
#  99,
#  100,
#  99,
#  100,
#  100,
#  99,
#  99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  100,
#  100,
#  99,
#  99,
#  100,
#  99,
#  99,
#  100,
#  100,
#  99,
#  98,
#  99,
#  99,
#  99,
#  100,
#  100,
#  100,
#  99,
#  99,
#  98,
#  98,
#  99,
#  98,
#  99,
#  99,
#  100,
#  98,
#  98,
#  98,
#  99,
#  99,
#  100,
#  99,
#  99,
#  98,
#  98,
#  99,
#  100,
#  98,
#  100,
#  100,
#  100,
#  100,
#  99,
#  100,
#  98,
#  99,
#  98,
#  98,
#  100,
#  99,
#  99,
#  98,
#  99,
#  99,
#  98,
#  98,
#  100,
#  99,
#  99,
#  98,
#  98,
#  99,
#  98,
#  99,
#  100,
#  98,
#  100,
#  99,
#  98,
#  98,
#  98,
#  99,
#  100,
#  99,
#  99,
#  98,
#  99,
#  98,
#  99,
#  98,
#  100,
#  98,
#  100,
#  100,
#  99,
#  98,
#  98,
#  98,
#  98,
#  98,
#  99,
#  99,
#  98,
#  98,
#  99,
#  98,
#  99,
#  98,
#  100,
#  99,
#  100,
#  100,
#  100,
#  100,
#  100,
#  100,
#  99,
#  99,
#  98,
#  98,
#  98,
#  99,
#  98,
#  100,
#  100,
#  98,
#  98,
#  100,
#  98,
#  98,
#  100,
#  98,
#  100,
#  98,
#  98,
#  99,
#  99,
#  100,
#  99,
#  99,
#  99,
#  100,
#  99,
#  98,
#  98,
#  98,
#  100,
#  100,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  98,
#  99,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  100,
#  99,
#  98,
#  100,
#  98,
#  98,
#  98,
#  99,
#  99,
#  99,
#  99,
#  99,
#  100,
#  98,
#  99,
#  99,
#  100,
#  98,
#  98,
#  99,
#  100,
#  98,
#  98,
#  98,
#  99,
#  100,
#  99,
#  99,
#  98,
#  98,
#  98,
#  99,
#  100,
#  99,
#  98,
#  99,
#  99,
#  98,
#  100,
#  99,
#  98,
#  100,
#  99,
#  98,
#  100,
#  98,
#  98,
#  100,
#  98,
#  99,
#  99,
#  100,
#  99,
#  100,
#  100,
#  98,
#  99,
#  98,
#  99,
#  99,
#  98,
#  98,
#  100,
#  98,
#  99,
#  99,
#  100,
#  98,
#  100,
#  100,
#  100,
#  100,
#  98,
#  98,
#  99,
#  98,
#  99,
#  98,
#  100,
#  98,
#  98,
#  98,
#  100,
#  99,
#  98,
#  100,
#  98]

# %%
from collections import defaultdict

cpd2reuse = defaultdict(list)
for c in df_cpds_folditer.index:
    for run, i in df_cpds_folditer.loc[c].items():
        cpd2reuse[c].append(run2fo2reuseNum[run][i])

# %%
cpd2reuse_Mean = {k:np.mean(v) for k,v in cpd2reuse.items()}
cpd2reuse_Std = {k:np.std(v) for k,v in cpd2reuse.items()}

scatter(cpd2reuse_Mean, cpd2reuse_Std, 'Mean lineage recruitment count at compound discovery', 'SD lineage recruitment count at compound discovery', savefig=False)

# %%
p = figure(width=400, height=300)

# define data
d1 = cpd2reuse_Mean
d2 = cpd2reuse_Std

valid_keys, data1, data2 = todata(d1, d2)
# data2 = np.log10(data2)
labels = [cpd2name.get(key, key) for key in valid_keys]
# colors = ['red' if k in evo else 'blue' for k in valid_keys]

# source
source = ColumnDataSource(data={
    'x': data1,
    'y': data2,
    'label': labels
})

p.scatter('x', 'y', source=source, size=10, alpha=0.5, line_color=None)

# Add hover tool
hover = HoverTool()
hover.tooltips = [("cpd", "@label")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = 'Mean'
p.yaxis.axis_label = 'Std'
# p.xaxis.ticker = [0, 50, 100, 150, 200, 250, 300, 350]  # Convert range to list
p.xgrid.grid_line_color = None

# output_file("scatter.html")
show(p)

# %% [markdown]
# ## rn2ec

# %%
rn2ec = csv2dict('../data/assets/rn2ec.csv')

# %%
x2rn_ec1 = {}
x2rn_ec2 = {}
for x, rns in x2rn.items():
    ec_list1 = []
    ec_list2 = []
    for rn in rns:
        if rn2ec.get(rn[:6], 0) == 0:  # not in rn2ec
            ec_list1.append('0')
        else:
            ec_list1.append(rn2ec[rn[:6]].split('.')[0])
            ec_list2.append(rn2ec[rn[:6]].split('.')[0] + '.' + rn2ec[rn[:6]].split('.')[1])
    x2rn_ec1[x] = ec_list1
    x2rn_ec2[x] = ec_list2

# %% [markdown]
# ## x2usage from fastest run

# %%
# fastest run
result = pd.read_pickle(f'../data/fold_results/runs_fastest_slowest/2024-09-27_13-49-38_no_lookahead_preExpansion_C00002_37860.pkl.gz')

# %%
rule2fo = {}
for key, value in result.rules_folditer.items():
    if key[1] not in rule2fo.keys():
        rule2fo[key[1]] = [value]
    else:
        rule2fo[key[1]].append(value)

folditer2rules = {}
for key , values in rule2fo.items():
    for value in values:
        if value not in folditer2rules.keys():
            folditer2rules[value] = [key]
        else:
            folditer2rules[value].append(key)
        
x2usage = {x:set() for x in result.folds_folditer.keys()}  # empty dict
x2usage.pop('fold_independent')
x2usage.pop('spontaneous')

for i, rules in folditer2rules.items():
    for rule in rules:
        for x in rule:
            if x in x2usage: # ignore 'fold_independent' and 'spontaneous'
                x2usage[x].add(i)  # don't record multiple usage within one fold_iter
x2usage = {x:sorted(list(s)) for x,s in x2usage.items()}

# %%
folditer2reactionRules = {}
for key , fo in result.rules_folditer.items():
        if fo not in folditer2reactionRules.keys():
            folditer2reactionRules[fo] = [key]
        else:
            folditer2reactionRules[fo].append(key)
            
x2usage_ec1 = {x:[] for x in result.folds_folditer.keys()}  # empty dict
x2usage_ec1.pop('fold_independent')
x2usage_ec1.pop('spontaneous')
x2usage_ec2 = {x:[] for x in result.folds_folditer.keys()}  # empty dict
x2usage_ec2.pop('fold_independent')
x2usage_ec2.pop('spontaneous')

for i, rrs in folditer2reactionRules.items():
    for rr in rrs:
        for x in rr[1]:
            if x in x2usage_ec1: # ignore 'fold_independent' and 'spontaneous'
                x2usage_ec1[x].append([i, rn2ec.get(rr[0], '0.0')[0]])
                x2usage_ec2[x].append([i, rn2ec.get(rr[0], '0.0')[0:3]])

# %%
notinrn2ec = []
for rn in result.scope.rns:
    if rn[:6] not in rn2ec.keys():
        notinrn2ec.append(rn)
print(len(notinrn2ec), len(result.scope.rns), len(rn2ec.keys()))
# Out:
# 1345 7678 9491

# %% [markdown]
# ### detailed look at x2usage

# %%
x2usageNum_noSingle = {x:len(usage) for x, usage in x2usage.items() if len(usage) > 1}

# %%
for k,v in dict(sorted(x2usageNum_noSingle.items(), key=lambda item: item[1], reverse=True)).items():
    print(k, v, x2name.get(k,k))
# Out:
# 2003 112 Rossmann-like
# 2002 86 TIM beta/alpha-barrel
# 2007 66 Flavodoxin-like
# 304 58 Alpha-beta plaits
# 2004 35 P-loop domains-like
# 1 34 cradle loop barrel
# 10 33 jelly-roll
# 206 32 206
# 11 30 Immunoglobulin-like beta-sandwich
# 2006 27 HAD domain-like
# 246 27 Carbon-nitrogen hydrolase-like
# 221 27 beta-Grasp
# 7524 25 7524
# 7577 25 7577
# 3016 22 3016
# 2484 21 Ribonuclease H-like
# 236 21 GroES-like
# 7579 21 7579
# 205 21 205
# 244 20 FAD-linked reductases, C-terminal domain-like
# 12 18 Glycosyl hydrolase domain-like
# 109 18 Repetitive alpha hairpins
# 298 17 FwdE/GAPDH domain-like
# 101 17 HTH
# 2005 15 HUP domain-like
# 2487 15 The "swivelling" beta/beta/alpha domains
# 2486 15 2486
# 325 15 alpha/beta-Hammerhead/Barrel-sandwich hybrid
# 301 15 Bacillus chorismate mutase-like
# 323 15 323
# 129 14 129
# 7581 14 7581
# 222 14 Thioesterase/thiol ester dehydrase-isomerase-like
# 213 14 Nat/Ivy
# 7512 14 7512
# 2011 13 Phosphorylase/hydrolase-like
# 5 13 beta-propeller-like
# 327 13 Alpha-lytic protease prodomain-like
# 217 13 FAD-binding domain-like
# 2485 12 Thioredoxin-like
# 7514 12 7514
# 633 12 Bromodomain-like
# 212 11 212
# 7515 11 7515
# 7574 11 7574
# 7525 10 7525
# 4002 10 4002
# 210 10 Ntn/PP2C
# 141 10 141
# 7584 9 7584
# 7527 8 7527
# 218 8 Enolase-N/ribosomal protein
# 223 8 Profilin-like
# 103 8 RuvA-C
# 150 8 Ferritin/Heme oxygenase/4-helical cytokines
# 187 8 alpha-helical ferredoxin-like
# 231 8 231
# 4011 8 4011
# 1001 8 1001
# 7510 7 7510
# 131 7 PDEase-like
# 7516 7 7516
# 65 7 65
# 331 7 TBP-like
# 149 7 149
# 805 6 805
# 7542 6 7542
# 281 6 281
# 208 6 Single-stranded left-handed beta-helix
# 7552 6 7552
# 243 6 Cystatin-like
# 108 6 EF-hand
# 7561 6 7561
# 3740 6 3740
# 5100 6 5100
# 279 5 279
# 159 5 159
# 247 5 247
# 7522 5 7522
# 321 5 Glutamine synthetase-like
# 6094 5 6094
# 375 5 Rubredoxin-like
# 4 5 SH3
# 5069 5 5069
# 4335 5 4335
# 107 5 Cytochrome c-like
# 4025 5 4025
# 7531 4 7531
# 219 4 Cysteine proteinases-like
# 7523 4 7523
# 70 4 beta-clip
# 300 4 300
# 7571 4 7571
# 7564 4 7564
# 207 4 Single-stranded right-handed beta-helix
# 220 4 PH domain-like
# 7541 4 7541
# 4019 4 4019
# 296 4 296
# 7550 4 7550
# 1137 4 Tetrapyrrole methylase C-terminal domain-like
# 214 4 214
# 7604 4 7604
# 3687 4 3687
# 102 4 HhH/H2TH
# 302 4 Reverse ferredoxin
# 4033 4 4033
# 4052 4 4052
# 604 4 Spectrin repeat-like
# 7586 4 7586
# 3697 4 3697
# 4272 4 Nqo5-like
# 328 3 IF3-like
# 286 3 286
# 7573 3 7573
# 180 3 180
# 7543 3 7543
# 315 3 Tautomerase/MIF-like
# 868 3 868
# 276 3 276
# 2498 3 Zincin-like
# 7558 3 7558
# 211 3 211
# 209 3 209
# 601 3 Four-helical up-and-down bundle
# 230 3 T-fold
# 7501 3 7501
# 2492 3 2492
# 4995 3 4995
# 275 3 275
# 5038 3 Cytochrome c oxidase subunit I-like
# 830 3 830
# 136 3 136
# 880 3 880
# 4194 3 4194
# 4045 3 4045
# 7521 3 7521
# 316 3 Nucleotidyltransferase-like
# 1143 3 1143
# 278 3 278
# 602 3 L-aspartase middle domain-like
# 179 3 179
# 3858 3 3858
# 4044 3 4044
# 7556 3 7556
# 3281 3 3281
# 7518 2 7518
# 7572 2 7572
# 7504 2 7504
# 3692 2 3692
# 7528 2 7528
# 282 2 282
# 7517 2 7517
# 5104 2 5104
# 503 2 503
# 5084 2 Outer membrane meander beta-barrels
# 7588 2 7588
# 314 2 314
# 4126 2 beta-carbonic anhydrase-like
# 2 2 OB-fold
# 277 2 277
# 3264 2 3264
# 297 2 297
# 7567 2 7567
# 283 2 Creatinase/aminopeptidase-like
# 3688 2 3688
# 312 2 HIT-like
# 376 2 RING/U-box-like
# 4093 2 4093
# 371 2 371
# 4279 2 4279
# 810 2 810
# 177 2 177
# 330 2 dsRBD-like
# 232 2 232
# 147 2 147
# 7553 2 7553
# 6058 2 6058
# 3896 2 3896
# 189 2 189
# 7539 2 7539
# 106 2 106
# 4178 2 4178
# 708 2 708
# 813 2 813
# 4020 2 4020
# 3686 2 3686
# 3447 2 3447
# 268 2 Sterol carrier protein-like
# 623 2 623
# 258 2 258
# 4029 2 4029
# 876 2 876
# 3794 2 3794
# 4953 2 4953
# 3156 2 Cupredoxin-like
# 4952 2 4952
# 2500 2 2500
# 1074 2 1074
# 3005 2 3005
# 148 2 Histone-like
# 262 2 262
# 2012 2 2012
# 66 2 66
# 132 2 ACP-like
# 4017 2 4017
# 7595 2 7595
# 3207 2 3207
# 581 2 581
# 3321 2 3321
# 3323 2 3323
# 192 2 Long alpha-hairpin
# 7578 2 7578
# 4024 2 4024
# 3843 2 3843
# 3456 2 3456

# %%
def histogram(dict1, val_type = 'MEAN', bins = 10, x_axis = 'x-axis', y_axis ='counts', ylog=False, xlog=False):
    data1 = list(dict1.values())
    
    if type(data1[0]) == dict:
        data1 = [x[val_type] for x in data1]
    
    plt.figure(figsize=(4, 4))
    
    plt.hist(data1, bins=bins, edgecolor=None)  # orientation='horizontal'
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)

    if ylog:
        plt.yscale('log', nonpositive='clip')
    if xlog:
        plt.xscale('log', nonpositive='clip')
    
    # plt.savefig('5A_inset.svg', dpi=300, bbox_inches='tight')
    plt.show()

histogram(x2usageNum_noSingle, bins=50, x_axis='Number of re-use', y_axis='Lineage count')

# %% [markdown]
# ## duration (with new EC2 and new cofactor timing annotated)

# %%
x2usage_first_last = {key: [min(values), max(values)] for key, values in x2usage.items()}

# %%
# remove lineages with duration = 0
single_use_lineages = set()
x2usage_first_lastNoSingles = {}

for x , usage in x2usage_first_last.items():
    if usage[1]-usage[0] != 0:
        x2usage_first_lastNoSingles[x] = usage
    else:
        single_use_lineages.add(x)
print(len(single_use_lineages))
# Out:
# 180

# %%
single_use_lineages & set(group1)
# Out:
# {'184', '253', '3997', '7544', '875'}

# %% [markdown]
# ### lineages 'resurrected' by oxygen

# %%
# do not use oxygen at 296: 503, 5084, 219

# 211
# 281
# 209

# %%
lazarus = "211"
x2usage[lazarus], result.cpds_folditer['C00007']
# Out:
# ([99, 296, 309], 296)

# %%
for rn in x2rn[lazarus]:
    if result.rns_folditer.get(rn, 'N/A') != 'N/A':
        print(rn, result.rns_folditer.get(rn, 'N/A'), 'C00007' in rn2cpds[rn], rn2rules[rn])
# Out:
# R05416 309 True {frozenset({'211'})}
# R01507 296 True {frozenset({'211'})}
# R02521_v1 296 True {frozenset({'211'})}
# R08511_v1 88 False {frozenset({'3009'}), frozenset({'109', '2485'}), frozenset({'2485'}), frozenset({'211'})}
# R06632_v1 296 True {frozenset({'211'})}
# R01372_v1 296 True {frozenset({'211'})}
# R02530_v3 99 False {frozenset({'211'})}
# R00816_v1 296 True {frozenset({'211'})}
# R04089_v1 296 True {frozenset({'211'})}
# R05295_v1 296 True {frozenset({'211'})}
# R05246_v1 296 True {frozenset({'211'})}
# R02530_v1 99 False {frozenset({'211'})}
# R05404_v1 296 True {frozenset({'211'})}
# R02530_v2 99 False {frozenset({'211'})}
# R05778_v1 296 True {frozenset({'211'})}

# %% [markdown]
# ## dot per use

# %%
# remove single-use folds
x2usageNoSingles = {}
for x , usage in x2usage.items():
    if x in x2usage_first_lastNoSingles.keys():
        x2usageNoSingles[x] = usage
print(len(x2usage) - len(x2usageNoSingles))

x2usage_secondLast_last = {}
for key, values in x2usageNoSingles.items():
    x2usage_secondLast_last[key] = [sorted(values)[-2], sorted(values)[-1]]
# Out:
# 180

# %%
data = x2usageNoSingles
x2first_invention = {}
x2invention_iters = {}

# color by new ec invention
colors = []
for x in x2usageNoSingles.keys():
    # make fo2ec dict for lineage
    fo2ec = {}
    for fo_ec in x2usage_ec2[x]:
        if fo_ec[0] not in fo2ec:
            fo2ec[fo_ec[0]] = set(fo_ec[1])
        else:
            fo2ec[fo_ec[0]].add(fo_ec[1])

    # track when inventions are made
    invention_fo = {}
    current_ecs = set()
    for fo, ecs in fo2ec.items():
        # if ecs - current_ecs != set():  # first is red
        if (ecs - current_ecs != set()) and (fo != result.folds_folditer[x]):  # first is black
            invention_fo[fo] = set(ecs - current_ecs)
        current_ecs = current_ecs | ecs
    # record first invention
    x2first_invention[x] = min(invention_fo.keys(), default=None)  # if no invention, return None
    # record invention iters
    x2invention_iters[x] = invention_fo

    # populate colors list
    for fo in fo2ec.keys():
        if fo in invention_fo.keys():
            colors.append('red')
        else:
            colors.append('black')


keys = list(data.keys())
values = [value for sublist in data.values() for value in sublist]
y_positions = [key for key, sublist in data.items() for _ in sublist]

# Plotting
plt.figure(figsize=(10, 20))
plt.figure(figsize=(10, 30))
plt.scatter(values, y_positions, marker='o', alpha=0.5, color=colors)
plt.gca().invert_yaxis()

# custom y labels
y_positions_list = []
for x in y_positions:
    if x not in y_positions_list:
        y_positions_list.append(x)
name_labels = [x2name.get(x, x) for x in keys]

# Adding labels
plt.xlabel('Lineage order at lineage usage', fontsize=18)
plt.ylabel('Lineages (first to last)', fontsize=18)
plt.yticks(ticks=y_positions_list, labels=name_labels, fontsize=8)
# plt.yticks([])
plt.ylim([220, -3])
plt.xticks(fontsize=18)

# plt.savefig('dot_per_use_2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### time until first invention

# %%
x2time_until_invension = {}
no_invention_lineages = []
for x, first_invention in x2first_invention.items():
    if first_invention != None:
        x2time_until_invension[x] = first_invention - result.folds_folditer[x]
    else:
        no_invention_lineages.append(x)
len(x2first_invention), len(x2time_until_invension), len(no_invention_lineages)
# Out:
# (216, 152, 64)

# %%
histogram(x2time_until_invension, bins=30, x_axis='Iteration until first neofunctionalization')
scatter(result.folds_folditer, x2time_until_invension, 'lineage addition', 'time until first invention')

# %%
len({k:v for k,v in x2time_until_invension.items() if v <= 30})
# Out:
# 90

# %%
np.mean(list(x2time_until_invension.values()))
# Out:
# 48.25657894736842

# %%
# bokeh plot:
d1 = result.folds_folditer
d2 = x2time_until_invension

p = figure(width=800, height=800)

# Add annotations
valid_keys, data1, data2 = todata(d1, d2)

source = {'x': data1, 'y': data2, 'label': [f"X{key} " + x2name.get(key, 'no X name') for key in valid_keys],}
p.scatter('x', 'y', source=source, size=10, alpha=0.5)

# Add hover tool
hover = HoverTool()
hover.tooltips = [("X", "@label")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = 'lineage addition'
p.yaxis.axis_label = 'time until first invention'
# p.xaxis.ticker = [50, 100, 150, 200, 250, 300, 350]  # Convert range to list
p.xgrid.grid_line_color = None

# Show the plot
show(p)

# %% [markdown]
# ### O2 neofunctionalization (catalyzing a novel 2-digit E.C.)

# %%
iter2inventionNum = {}
for x, invention_iters in x2invention_iters.items():
    for i in invention_iters:
        if i in iter2inventionNum:
            iter2inventionNum[i] += 1
        else:
            iter2inventionNum[i] = 1

# %%
plt.bar(iter2inventionNum.keys(), iter2inventionNum.values())
plt.xlabel('Lineage addition')
plt.ylabel('Number of lineages with neofunctionalization')
plt.xlim([0, max(iter2inventionNum.keys())+1])
# plt.savefig(f'iter2neofunc.svg', dpi=300, bbox_inches='tight')
plt.show()

# %%
result.cpds_folditer['C00007']
# Out:
# 296

# %% [markdown]
# ## diversity

# %%
fo2lineagesUsed = {}
for x, usage in x2usage.items():
    for fo in usage:
        if fo not in fo2lineagesUsed:
            fo2lineagesUsed[fo] = set([x])
        else:
            fo2lineagesUsed[fo].add(x) 
fo2lineagesUsedNum = {fo:len(lineagesUsed) for fo, lineagesUsed in fo2lineagesUsed.items()}

fo2lineagesUsedNum_Full = {}
for i in range(0, max(fo2lineagesUsedNum.keys())+1):
    if i not in fo2lineagesUsedNum.keys():
        fo2lineagesUsedNum_Full[i] = 0
    else:
        fo2lineagesUsedNum_Full[i] = fo2lineagesUsedNum[i]
print(len(fo2lineagesUsedNum_Full))
# Out:
# 372

# %%
folditer2cpd = {}
for c, order in result.cpds_folditer.items():
    if order not in folditer2cpd.keys():
        folditer2cpd[order] = [c]
    else:
        folditer2cpd[order].append(c)
print(len(folditer2cpd))

folditer2cpdNum = {}
for fo in folditer2cpd.keys():
    folditer2cpdNum[fo] = len(folditer2cpd[fo])

folditer2cpdNumFull = {}
for i in range(0, max(folditer2cpd.keys())):
    if i not in folditer2cpdNum.keys():
        folditer2cpdNumFull[i] = 0
    else:
        folditer2cpdNumFull[i] = folditer2cpdNum[i]
print(len(folditer2cpdNumFull))

# only 164 lineage addition steps lead to new cpd discovery
# new rules are constantly discovered after each lineage addition, but new cpd discovery is harder
# Out:
# 164
# 361

# %%
folditer2lineages = {}
for x, folditer in result.folds_folditer.items():
    if folditer not in folditer2lineages.keys():
        folditer2lineages[folditer] = [x]
    else:
        folditer2lineages[folditer].append(x)
print(len(folditer2lineages), len(folditer2cpdNumFull))
        
double_addition = []
triple_addition = []
for i, lineages in folditer2lineages.items():
    if len(lineages) == 2:
        double_addition.append(i)
    if len(lineages) == 3:
        triple_addition.append(i)

# extend end until all additions complete
for i in range(len(folditer2lineages) - len(folditer2cpdNumFull)):
    folditer2cpdNumFull[i+len(folditer2cpdNumFull)] = 0
print(len(folditer2lineages), len(folditer2cpdNumFull))
# Out:
# 372 361
# 372 372

# %%
folditer2cpdNumFull
# Out:
# {0: 484,
#  1: 12,
#  2: 5,
#  3: 0,
#  4: 9,
#  5: 0,
#  6: 4,
#  7: 0,
#  8: 2,
#  9: 2,
#  10: 0,
#  11: 0,
#  12: 0,
#  13: 0,
#  14: 0,
#  15: 0,
#  16: 4,
#  17: 4,
#  18: 6,
#  19: 232,
#  20: 40,
#  21: 49,
#  22: 4,
#  23: 2,
#  24: 22,
#  25: 8,
#  26: 4,
#  27: 0,
#  28: 5,
#  29: 2,
#  30: 3,
#  31: 4,
#  32: 0,
#  33: 2,
#  34: 1,
#  35: 4,
#  36: 0,
#  37: 3,
#  38: 10,
#  39: 1,
#  40: 0,
#  41: 1,
#  42: 1,
#  43: 16,
#  44: 90,
#  45: 0,
#  46: 5,
#  47: 6,
#  48: 0,
#  49: 4,
#  50: 0,
#  51: 6,
#  52: 60,
#  53: 3,
#  54: 2,
#  55: 117,
#  56: 11,
#  57: 2,
#  58: 1,
#  59: 1,
#  60: 4,
#  61: 11,
#  62: 3,
#  63: 3,
#  64: 0,
#  65: 0,
#  66: 0,
#  67: 0,
#  68: 0,
#  69: 0,
#  70: 0,
#  71: 4,
#  72: 1,
#  73: 1,
#  74: 0,
#  75: 5,
#  76: 131,
#  77: 11,
#  78: 15,
#  79: 0,
#  80: 0,
#  81: 1,
#  82: 8,
#  83: 1,
#  84: 5,
#  85: 0,
#  86: 12,
#  87: 3,
#  88: 5,
#  89: 1,
#  90: 0,
#  91: 12,
#  92: 1,
#  93: 31,
#  94: 2,
#  95: 0,
#  96: 0,
#  97: 0,
#  98: 11,
#  99: 0,
#  100: 0,
#  101: 0,
#  102: 0,
#  103: 0,
#  104: 0,
#  105: 0,
#  106: 0,
#  107: 0,
#  108: 290,
#  109: 12,
#  110: 0,
#  111: 0,
#  112: 0,
#  113: 2,
#  114: 0,
#  115: 8,
#  116: 0,
#  117: 0,
#  118: 4,
#  119: 34,
#  120: 82,
#  121: 287,
#  122: 0,
#  123: 15,
#  124: 68,
#  125: 1,
#  126: 4,
#  127: 1,
#  128: 19,
#  129: 0,
#  130: 0,
#  131: 0,
#  132: 5,
#  133: 1,
#  134: 7,
#  135: 6,
#  136: 3,
#  137: 1,
#  138: 1,
#  139: 0,
#  140: 0,
#  141: 0,
#  142: 0,
#  143: 0,
#  144: 0,
#  145: 0,
#  146: 0,
#  147: 0,
#  148: 3,
#  149: 0,
#  150: 0,
#  151: 1,
#  152: 51,
#  153: 60,
#  154: 0,
#  155: 0,
#  156: 0,
#  157: 1,
#  158: 3,
#  159: 0,
#  160: 0,
#  161: 2,
#  162: 0,
#  163: 0,
#  164: 0,
#  165: 0,
#  166: 3,
#  167: 3,
#  168: 0,
#  169: 2,
#  170: 0,
#  171: 0,
#  172: 5,
#  173: 3,
#  174: 0,
#  175: 0,
#  176: 0,
#  177: 0,
#  178: 0,
#  179: 0,
#  180: 2,
#  181: 3,
#  182: 32,
#  183: 0,
#  184: 1,
#  185: 0,
#  186: 0,
#  187: 0,
#  188: 0,
#  189: 0,
#  190: 0,
#  191: 0,
#  192: 0,
#  193: 0,
#  194: 0,
#  195: 0,
#  196: 186,
#  197: 2,
#  198: 0,
#  199: 11,
#  200: 0,
#  201: 2,
#  202: 0,
#  203: 0,
#  204: 10,
#  205: 0,
#  206: 0,
#  207: 0,
#  208: 3,
#  209: 1,
#  210: 0,
#  211: 4,
#  212: 0,
#  213: 1,
#  214: 0,
#  215: 0,
#  216: 0,
#  217: 1,
#  218: 0,
#  219: 0,
#  220: 1,
#  221: 0,
#  222: 0,
#  223: 0,
#  224: 0,
#  225: 1,
#  226: 0,
#  227: 0,
#  228: 0,
#  229: 1,
#  230: 0,
#  231: 0,
#  232: 0,
#  233: 0,
#  234: 0,
#  235: 8,
#  236: 0,
#  237: 2,
#  238: 0,
#  239: 1,
#  240: 48,
#  241: 0,
#  242: 0,
#  243: 0,
#  244: 1,
#  245: 0,
#  246: 0,
#  247: 0,
#  248: 1,
#  249: 3,
#  250: 0,
#  251: 0,
#  252: 2,
#  253: 0,
#  254: 0,
#  255: 0,
#  256: 0,
#  257: 0,
#  258: 0,
#  259: 0,
#  260: 0,
#  261: 7,
#  262: 0,
#  263: 0,
#  264: 0,
#  265: 0,
#  266: 21,
#  267: 71,
#  268: 0,
#  269: 0,
#  270: 1,
#  271: 49,
#  272: 0,
#  273: 0,
#  274: 2,
#  275: 261,
#  276: 3,
#  277: 0,
#  278: 4,
#  279: 2,
#  280: 0,
#  281: 0,
#  282: 0,
#  283: 0,
#  284: 0,
#  285: 0,
#  286: 0,
#  287: 0,
#  288: 0,
#  289: 3,
#  290: 0,
#  291: 0,
#  292: 4,
#  293: 2,
#  294: 0,
#  295: 0,
#  296: 850,
#  297: 17,
#  298: 0,
#  299: 5,
#  300: 0,
#  301: 14,
#  302: 13,
#  303: 0,
#  304: 0,
#  305: 7,
#  306: 0,
#  307: 20,
#  308: 0,
#  309: 10,
#  310: 16,
#  311: 1,
#  312: 5,
#  313: 27,
#  314: 0,
#  315: 1,
#  316: 0,
#  317: 1,
#  318: 1,
#  319: 1,
#  320: 1,
#  321: 0,
#  322: 1,
#  323: 0,
#  324: 1,
#  325: 0,
#  326: 0,
#  327: 0,
#  328: 0,
#  329: 0,
#  330: 0,
#  331: 0,
#  332: 0,
#  333: 0,
#  334: 0,
#  335: 0,
#  336: 0,
#  337: 0,
#  338: 1,
#  339: 0,
#  340: 0,
#  341: 0,
#  342: 0,
#  343: 0,
#  344: 0,
#  345: 0,
#  346: 7,
#  347: 0,
#  348: 0,
#  349: 0,
#  350: 0,
#  351: 0,
#  352: 0,
#  353: 0,
#  354: 8,
#  355: 0,
#  356: 2,
#  357: 0,
#  358: 0,
#  359: 0,
#  360: 1,
#  361: 0,
#  363: 0,
#  365: 0,
#  367: 0,
#  369: 0,
#  371: 0,
#  373: 0,
#  375: 0,
#  377: 0,
#  379: 0,
#  381: 0}

# %%
plt.figure(figsize=(5, 1.25))

values = list(fo2lineagesUsedNum_Full.values())
x = range(len(values))
plt.bar(x, values, color='gray', alpha=1, width=1.0)

plt.xlim([0, len(folditer2cpdNumFull.values())])
plt.xticks([])
plt.ylim([0, 120])
plt.ylabel('Num lineages used', fontsize=6)

# plt.savefig('folditer_lineage-usage.svg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### overlay cpd discovery & lineage diversity

# %%
cpd2iter = {}
for cpd in ['C00006', 'C00154', 'C00077', 'C00047', 'C00135', 'C00073', 'C00448', 'C11901', 'C00341', 'C00353', 'C00923', 'C00463', 'C00229', 'C05819', 'C03313', 'C00027', 'C00032', 'C00059', 'C00094', 'C05773', 'C00251', 'C00082', 'C00079', 'C00078', 'C02059', 'C00828', 'C01063', 'C00120', 'C00018', 'C00302', 'C00334', 'C11440', 'C00002', 'C00003', 'C00010', 'C00024', 'C00129', 'C00068', 'C00019', 'C00101', 'C00016', 'C00061', 'C00363', 'C00194', 'C00062', 'C00007']:
    for folditer in folditer2cpd.keys():
        for c in folditer2cpd[folditer]:
            if c == cpd:
                cpd2iter[c] = folditer

fig, ax1 = plt.subplots(figsize=(15, 5))

# First plot (line plot)
ax1.plot(folditer2cpdNumFull.values(), color='b', label='Line plot')
ax1.set_ylabel('Number of compounds discovered', fontsize=16)
ax1.set_ylim([-100, 1000])
ax1.set_xlim([0, len(folditer2cpdNumFull)])
ax1.set_xlabel('Lineage order', fontsize=16)

# Second y-axis for the bar plot
ax2 = ax1.twinx()
values = list(fo2lineagesUsedNum_Full.values())
x = range(len(values))
ax2.bar(x, values, color='gray', alpha=0.6, label='Bar plot')
ax2.set_ylabel('Number of lineages used (lineage diversity)', fontsize=16)
ax2.set_ylim([-10, 120])

# Add cpd annotations
for key, value in cpd2iter.items():
    position = random.randint(100, 800)
    ax1.text(value, position, cpd2name[key], ha='center', va='bottom', color='b')
    ax1.scatter(value, position - 5, color='b')

# Add rugplots to ax1 (primary axis)
sns.rugplot(double_addition, height=0.04, color='k', ax=ax1)  # Double lineage addition
sns.rugplot(triple_addition, height=0.08, color='k', ax=ax1)  # Triple lineage addition

# Custom legend labels
# custom_labels = ['Compounds', 'lineage diversity']
# handles = lines + bars
# ax1.legend(handles, custom_labels, loc='upper left')

plt.tight_layout()
# plt.savefig('folditer_cpds_lineage_diversity.svg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## folditer vs. new E.C. invention

# %%
# include the single usage

notches1 = {}
for x in x2usage.keys():
    fo2ec = {}
    for fo_ec in x2usage_ec1[x]:
        if fo_ec[0] not in fo2ec:
            fo2ec[fo_ec[0]] = set(fo_ec[1])
        else:
            fo2ec[fo_ec[0]].add(fo_ec[1])

    current_ecs = set()
    for fo, ecs in fo2ec.items():
#         if ecs - current_ecs != set() and current_ecs != set():
        if ecs - current_ecs != set():
            if x not in notches1:
                notches1[x] = [fo]
            else:
                notches1[x].append(fo)
        current_ecs = current_ecs | ecs

notches2 = {}
for x in x2usage.keys():
    fo2ec = {}
    for fo_ec in x2usage_ec2[x]:
        if fo_ec[0] not in fo2ec:
            fo2ec[fo_ec[0]] = set(fo_ec[1])
        else:
            fo2ec[fo_ec[0]].add(fo_ec[1])

    current_ecs = set()
    for fo, ecs in fo2ec.items():
#         if ecs - current_ecs != set() and current_ecs != set():
        if ecs - current_ecs != set():
            if x not in notches2:
                notches2[x] = [fo]
            else:
                notches2[x].append(fo)
        current_ecs = current_ecs | ecs

# %%
fo2inventions1 = {}
for x, fos in notches1.items():
    for fo in fos:
        if fo not in fo2inventions1: 
            fo2inventions1[fo] = 1
        else:
            fo2inventions1[fo] += 1

fo2inventions1_Full = {}
for i in range(0, max(fo2inventions1.keys())+1):
    if i not in fo2inventions1.keys():
        fo2inventions1_Full[i] = 0
    else:
        fo2inventions1_Full[i] = fo2inventions1[i]
print(len(fo2inventions1_Full))

fo2inventions2 = {}
for x, fos in notches2.items():
    for fo in fos:
        if fo not in fo2inventions2: 
            fo2inventions2[fo] = 1
        else:
            fo2inventions2[fo] += 1

fo2inventions2_Full = {}
for i in range(0, max(fo2inventions2.keys())+1):
    if i not in fo2inventions2.keys():
        fo2inventions2_Full[i] = 0
    else:
        fo2inventions2_Full[i] = fo2inventions2[i]
print(len(fo2inventions2_Full))
# Out:
# 372
# 372

# %%
plt.figure(figsize=(30, 5))
plt.plot(fo2inventions1_Full.values(), color='k')

# Create a rugplot
sns.rugplot(double_addition, height=0.04, color='blue')  # double lineage addition
sns.rugplot(triple_addition, height=0.08, color='blue')  # triple lineage addition

plt.xlim([0, len(folditer2cpdNumFull)])
plt.ylim([-3,40])
plt.ylabel('# lineages with new trick (EC 1 dig.)', fontsize=16)
# plt.savefig('folditer_lineage_diversity.svg', dpi=300, bbox_inches='tight')
plt.show()



plt.figure(figsize=(30, 5))
plt.plot(fo2inventions2_Full.values(), color='k')

# Create a rugplot
sns.rugplot(double_addition, height=0.04, color='blue')  # double lineage addition
sns.rugplot(triple_addition, height=0.08, color='blue')  # triple lineage addition

plt.xlim([0, len(folditer2cpdNumFull)])
plt.ylim([-3,40])
plt.ylabel('# lineages with new trick (EC 2 dig.)', fontsize=16)
# plt.savefig('folditer_lineage_diversity.svg', dpi=300, bbox_inches='tight')
plt.show()



# compare with cpd discovery
cpd2iter = {}
for cpd in ['C00006', 'C00154', 'C00077', 'C00047', 'C00135', 'C00073', 'C00448', 'C11901', 'C00341', 'C00353', 'C00923', 'C00463', 'C00229', 'C05819', 'C03313', 'C00027', 'C00032', 'C00059', 'C00094', 'C05773', 'C00251', 'C00082', 'C00079', 'C00078', 'C02059', 'C00828', 'C01063', 'C00120', 'C00018', 'C00302', 'C00334', 'C11440', 'C00002', 'C00003', 'C00010', 'C00024', 'C00129', 'C00068', 'C00019', 'C00101', 'C00016', 'C00061', 'C00363', 'C00194', 'C00062', 'C00007']:
    for folditer in folditer2cpd.keys():
        for c in folditer2cpd[folditer]:
            if c == cpd:
                cpd2iter[c] = folditer
                
plt.figure(figsize=(30, 5))
plt.plot(folditer2cpdNumFull.values(), color='k')

# Add annotations
for key, value in cpd2iter.items():
    position = random.randint(100, 800)
    plt.text(value, position, cpd2name[key], ha='center', va='bottom', color='blue')
    plt.scatter(value, position-5, color='b')

# Create a rugplot
sns.rugplot(double_addition, height=0.04, color='blue')  # double lineage addition
sns.rugplot(triple_addition, height=0.08, color='blue')  # triple lineage addition
    
plt.xlim([0, len(folditer2cpdNumFull)])
plt.ylim([-100, 1000])
plt.xlabel('lineage_order', fontsize=16)
plt.ylabel('# cpds discovered', fontsize=16)
# plt.savefig('folditer_cpds_annotated_2.svg', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## #usage vs. #rules - scatter

# %%
x2rulesNum_scope = csv2dict('../data/assets/xgroup2/xgroup2rulesNum_scope.csv')

# %%
# some lineages with many rules are used in one folditer!

x2usageNum = {x:len(usage) for x, usage in x2usage.items()}
loglog(x2usageNum, x2rulesNum_scope, 'log(#usage)', 'log(#rules)')
ylog(x2usageNum, x2rulesNum_scope, '#usage', 'log(#rules)')

# %%
d1 = x2usageNum
d2 = x2rulesNum_scope

# output_file("mean_folditer_vs_escore_RUN.html")
p = figure(width=800, height=800)

# Add annotations
valid_keys, data1, data2 = todata(d1, d2)
data1 = np.log10(data1)
data2 = np.log10(data2)

# Use a red colormap
colormap = plt.cm.Blues
scalar_mappable = ScalarMappable(cmap=colormap)
colors = scalar_mappable.to_rgba([x2ds[x] for x in valid_keys if x in x2ds])
colors = ['#ff7f0e' if key in group1 else '#1f77b4' for key in valid_keys]

source = {'x': data1, 'y': data2, 'label': [f"X{key} " + x2name.get(key, 'no X name') for key in valid_keys], 'ds': [x2ds[key] for key in valid_keys], 
          'color': colors, 'num_rules': [str(x2rulesNum_scope[key]) for key in valid_keys]}
p.scatter('x', 'y', source=source, size=10, color='color', alpha=0.5)

# Add hover tool
hover = HoverTool()
hover.tooltips = [("X", "@label"), ("#rules", "@num_rules"), ("ds", "@ds")]
p.add_tools(hover)

# Customize plot
p.xaxis.axis_label = '#usage'
p.yaxis.axis_label = '#rules_scope'
p.xgrid.grid_line_color = None

# Show the plot
show(p)

# %%
single_use = [x for x in x2usageNum.keys() if x2usageNum[x] == 1]
len(single_use)
# Out:
# 180

# %%
print(single_use)
# Out:
# ['4004', '4021', '3699', '4081', '7589', '7529', '239', '7560', '3691', '62', '7534', '7500', '7580', '3883', '266', '133', '7509', '2493', '3754', '7554', '172', '3257', '3847', '629', '873', '270', '7549', '7520', '307', '387', '3599', '6113', '3654', '3651', '3292', '4262', '7536', '3086', '355', '377', '611', '812', '3117', '3009', '284', '875', '164', '582', '7513', '4237', '650', '3001', '305', '64', '197', '3685', '4022', '7562', '2496', '237', '235', '1114', '154', '4111', '253', '6096', '4295', '842', '1055', '7551', '285', '6075', '1077', '3076', '632', '7540', '814', '1144', '5067', '525', '4049', '319', '5103', '309', '185', '920', '378', '4018', '7587', '2008', '1119', '184', '7544', '4114', '2010', '590', '3052', '7568', '3371', '139', '73', '69', '313', '374', '6051', '199', '303', '3997', '146', '867', '914', '257', '7', '3249', '6166', '557', '158', '4294', '9', '640', '3978', '4983', '4110', '6174', '608', '620', '4159', '6', '4161', '3752', '3294', '196', '911', '241', '3960', '3115', '869', '4229', '881', '528', '3892', '3777', '4160', '5039', '324', '4076', '3322', '4971', '4223', '7546', '7507', '806', '169', '228', '603', '306', '75', '865', '3018', '3269', '872', '3500', '3304', '3623', '7563', '4048', '4028', '3993', '3994', '7601', '7602', '4046', '3579', '702', '3339', '3374', '144', '4036', '4054', '4035']

# %%
set(group1) & set(single_use)
# Out:
# {'184', '253', '3997', '7544', '875'}

# %%
for x in set(group1) & set(single_use):
    print(x, x2rulesNum_scope[x])
# Out:
# 253 1
# 3997 1
# 184 11
# 875 1
# 7544 11

# %%
scatter(x2foMean, x2usageNum)
ylog(x2foMean, x2usageNum, 'mean lineage order', '#lineage usage')

# %% [markdown]
# # Do first-reactions always have the lineage that was injected at that cumiter?

# %%
# The answer is - YES

# for run in df_cpds_folditer.columns:
#     cumiter2rules = {}
#     for rule, i in df_rules_cumiter[run].items():
#         if i not in cumiter2rules:
#             cumiter2rules[i] = [eval(rule)]  # convert string into tuple with 'eval'
#         else:
#             cumiter2rules[i].append(eval(rule))
    
#     cumiter2lineages = {}
#     for x, cumiter in df_folds_cumiter[run].items():
#         if cumiter not in cumiter2lineages:
#             cumiter2lineages[cumiter] = [x]
#         else:
#             cumiter2lineages[cumiter].append(x)
    
#     for i, rnRules in cumiter2rules.items():
#         if i in cumiter2lineages.keys():  # check cumiters with lineage addition
#             lineages = cumiter2lineages[i]
#             for rnRule in rnRules:
#                 for x in lineages:  # check all lineages (multi-addition possible)
#                     if x not in rnRule[1]:
#                         print(f'{x} not in rule: {rnRule[1]}')

# %% [markdown]
# # Only use rules with one lineage (solo domain vs. multi-domain enzymes)

# %%
rn2rules_solo = {}
for rn, rules in rn2rules.items():
    new_rules = set()
    for rule in rules:
        if len(rule) == 1:
            new_rules.add(rule)
    rn2rules_solo[rn] = new_rules

# remove reactions with no solo rules
rn2rules_solo = {k:v for k,v in rn2rules_solo.items() if len(v) > 0}

# %%
len(rns_scope)
# Out:
# 7678

# %%
len(rn2rules), len(set(rn2rules.keys()) & set(rns_scope))
# Out:
# (12872, 5730)

# %%
len(rn2rules_solo), len(set(rn2rules_solo.keys()) & set(rns_scope))
# Out:
# (8715, 3819)

# %%
rn2rules_solo
# Out:
# {'R01015': {frozenset({'2002'})},
#  'R01070': {frozenset({'2002'}), frozenset({'304'})},
#  'R01786': {frozenset({'2484'})},
#  'R02740': {frozenset({'10'}), frozenset({'2002'}), frozenset({'2007'})},
#  'R09084': {frozenset({'2003'})},
#  'R02189': {frozenset({'2484'})},
#  'R09085': {frozenset({'2003'})},
#  'R01518': {frozenset({'7525'})},
#  'R00431': {frozenset({'2004'})},
#  'R00726': {frozenset({'2004'})},
#  'R00341': {frozenset({'2004'})},
#  'R04780': {frozenset({'246'}), frozenset({'304'})},
#  'R01827': {frozenset({'2002'})},
#  'R02739': {frozenset({'10'}), frozenset({'2002'}), frozenset({'2007'})},
#  'R10907': {frozenset({'2003'})},
#  'R01056': {frozenset({'7560'})},
#  'R01529': {frozenset({'2002'})},
#  'R02035': {frozenset({'2003'}), frozenset({'5'})},
#  'R01049': {frozenset({'7573'})},
#  'R05605': {frozenset({'2002'})},
#  'R00709': {frozenset({'7510'})},
#  'R00268': {frozenset({'7510'})},
#  'R00267': {frozenset({'7510'})},
#  'R00351': {frozenset({'2002'}), frozenset({'172'})},
#  'R01899': {frozenset({'7510'})},
#  'R00472': {frozenset({'2002'})},
#  'R10612': {frozenset({'2002'})},
#  'R00473': {frozenset({'2002'})},
#  'R00479': {frozenset({'2002'})},
#  'R00705': {frozenset({'7524'})},
#  'R03045': {frozenset({'2486'})},
#  'R03158': {frozenset({'2486'})},
#  'R00706': {frozenset({'7524'})},
#  'R01383': {frozenset({'7512'})},
#  'R02640': {frozenset({'2003'})},
#  'R01639': {frozenset({'2484'})},
#  'R01478': {frozenset({'2002'})},
#  'R01904': {frozenset({'2003'})},
#  'R01381': {frozenset({'7516'})},
#  'R03313': {frozenset({'7524'})},
#  'R10147': {frozenset({'2002'})},
#  'R02735': {frozenset({'286'})},
#  'R04405': {frozenset({'2002'})},
#  'R00946': {frozenset({'2002'})},
#  'R01777': {frozenset({'2007'}), frozenset({'7579'})},
#  'R01466': {frozenset({'2003'})},
#  'R01771': {frozenset({'206'}), frozenset({'2006'}), frozenset({'212'})},
#  'R04173': {frozenset({'3016'})},
#  'R00582': {frozenset({'7525'}), frozenset({'2006'})},
#  'R00586': {frozenset({'2007'}), frozenset({'7579'})},
#  'R00897': {frozenset({'2003'})},
#  'R02412': {frozenset({'2004'})},
#  'R03460': {frozenset({'328'})},
#  'R03084': {frozenset({'2002'}), frozenset({'2007'})},
#  'R01826': {frozenset({'2002'})},
#  'R01714': {frozenset({'875'})},
#  'R01373': {frozenset({'7523'})},
#  'R01715': {frozenset({'164'}), frozenset({'304'}), frozenset({'301'})},
#  'R01728': {frozenset({'164'})},
#  'R01730': {frozenset({'2003'})},
#  'R00714': {frozenset({'7524'})},
#  'R00713': {frozenset({'7524'})},
#  'R02649': {frozenset({'7531'})},
#  'R00259': {frozenset({'213'})},
#  'R00669': {frozenset({'304'})},
#  'R01398': {frozenset({'2003'})},
#  'R00551': {frozenset({'2006'})},
#  'R01934': {frozenset({'7510'})},
#  'R09776': {frozenset({'7531'})},
#  'R06979': {frozenset({'10'})},
#  'R06978': {frozenset({'213'})},
#  'R00178': {frozenset({'331'})},
#  'R01402': {frozenset({'2011'})},
#  'R07364': {frozenset({'10'})},
#  'R00177': {frozenset({'327'})},
#  'R01401': {frozenset({'2011'})},
#  'R07394': {frozenset({'2006'})},
#  'R07392': {frozenset({'281'})},
#  'R04143': {frozenset({'206'})},
#  'R07395': {frozenset({'2006'})},
#  'R01290': {frozenset({'2003'})},
#  'R00192': {frozenset({'2003'})},
#  'R04858': {frozenset({'2003'})},
#  'R02911': {frozenset({'213'})},
#  'R03130': {frozenset({'101'})},
#  'R00678': {frozenset({'4229'}), frozenset({'4983'})},
#  'R01959': {frozenset({'2487'}), frozenset({'7579'})},
#  'R01960': {frozenset({'244'})},
#  'R02665': {frozenset({'10'})},
#  'R03889': {frozenset({'7524'})},
#  'R04323': {frozenset({'2002'})},
#  'R06582': {frozenset({'149'})},
#  'R02416': {frozenset({'323'})},
#  'R02193': {frozenset({'2003'})},
#  'R06576': {frozenset({'101'})},
#  'R06572': {frozenset({'149'})},
#  'R01942': {frozenset({'2003'})},
#  'R02253': {frozenset({'149'})},
#  'R01615': {frozenset({'2003'})},
#  'R07433': {frozenset({'323'})},
#  'R00733': {frozenset({'2003'})},
#  'R02533': {frozenset({'2003'})},
#  'R00731': {frozenset({'146'})},
#  'R02521': {frozenset({'211'})},
#  'R02519': {frozenset({'10'})},
#  'R02287': {frozenset({'304'})},
#  'R00525': {frozenset({'2011'})},
#  'R02285': {frozenset({'2006'})},
#  'R01883': {frozenset({'2003'})},
#  'R00333': {frozenset({'375'})},
#  'R00127': {frozenset({'2004'})},
#  'R00124': {frozenset({'304'})},
#  'R01135': {frozenset({'2004'})},
#  'R00332': {frozenset({'2004'})},
#  'R00330': {frozenset({'304'})},
#  'R01130': {frozenset({'2002'})},
#  'R00158': {frozenset({'2004'}), frozenset({'7531'})},
#  'R00156': {frozenset({'304'})},
#  'R00570': {frozenset({'304'})},
#  'R05908': {frozenset({'7516'})},
#  'R05927': {frozenset({'216'})},
#  'R05926': {frozenset({'7516'})},
#  'R05928': {frozenset({'7516'})},
#  'R05932': {frozenset({'7516'})},
#  'R05929': {frozenset({'7516'})},
#  'R05931': {frozenset({'7516'})},
#  'R05930': {frozenset({'7516'})},
#  'R05935': {frozenset({'7516'})},
#  'R05936': {frozenset({'7516'})},
#  'R04549': {frozenset({'246'})},
#  'R05074': {frozenset({'7512'})},
#  'R04657': {frozenset({'2004'})},
#  'R05146': {frozenset({'7558'})},
#  'R04567': {frozenset({'208'})},
#  'R04658': {frozenset({'7512'})},
#  'R04587': {frozenset({'212'})},
#  'R05075': {frozenset({'7558'})},
#  'R01482': {frozenset({'2002'})},
#  'R01541': {frozenset({'2002'})},
#  'R05606': {frozenset({'2002'})},
#  'R03254': {frozenset({'2002'})},
#  'R03351': {frozenset({'7516'})},
#  'R03350': {frozenset({'2006'})},
#  'R05645': {frozenset({'2007'})},
#  'R05644': {frozenset({'2005'})},
#  'R05176': {frozenset({'2003'})},
#  'R05647': {frozenset({'2006'})},
#  'R05646': {frozenset({'2005'})},
#  'R01497': {frozenset({'7516'})},
#  'R03354': {frozenset({'7516'})},
#  'R01500': {frozenset({'7512'})},
#  'R10805': {frozenset({'2004'})},
#  'R10804': {frozenset({'7512'})},
#  'R04017': {frozenset({'2004'})},
#  'R05947': {frozenset({'7555'})},
#  'R05940': {frozenset({'7555'})},
#  'R05937': {frozenset({'7555'})},
#  'R06006': {frozenset({'7516'})},
#  'R05977': {frozenset({'7516'})},
#  'R12479': {frozenset({'109'})},
#  'R06722': {frozenset({'109'})},
#  'R05986': {frozenset({'10'})},
#  'R05985': {frozenset({'7516'})},
#  'R05989': {frozenset({'7516'})},
#  'R05990': {frozenset({'7555'})},
#  'R05988': {frozenset({'7512'})},
#  'R07823': {frozenset({'7515'})},
#  'R07824': {frozenset({'2002'})},
#  'R07821': {frozenset({'7515'})},
#  'R07811': {frozenset({'2002'})},
#  'R07812': {frozenset({'7515'})},
#  'R07814': {frozenset({'7515'})},
#  'R07819': {frozenset({'7515'})},
#  'R07815': {frozenset({'109'})},
#  'R07807': {frozenset({'10'})},
#  'R07808': {frozenset({'7515'})},
#  'R07806': {frozenset({'7515'})},
#  'R07413': {frozenset({'207'})},
#  'R02360': {frozenset({'207'})},
#  'R04965': {frozenset({'222'})},
#  'R04958': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04952': {frozenset({'7581'})},
#  'R04955': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04568': {frozenset({'222'})},
#  'R04725': {frozenset({'2003'})},
#  'R04962': {frozenset({'2003'})},
#  'R04956': {frozenset({'2003'})},
#  'R04430': {frozenset({'2003'})},
#  'R04970': {frozenset({'2003'})},
#  'R04536': {frozenset({'2003'})},
#  'R04534': {frozenset({'2003'})},
#  'R04428': {frozenset({'222'})},
#  'R04961': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04533': {frozenset({'2003'})},
#  'R04954': {frozenset({'222'})},
#  'R04544': {frozenset({'222'})},
#  'R04355': {frozenset({'7581'})},
#  'R04543': {frozenset({'2003'})},
#  'R04966': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04566': {frozenset({'2003'})},
#  'R04964': {frozenset({'2003'})},
#  'R04963': {frozenset({'7581'})},
#  'R04969': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04968': {frozenset({'7581'})},
#  'R04537': {frozenset({'222'})},
#  'R04960': {frozenset({'7581'})},
#  'R04724': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04429': {frozenset({'2003'}), frozenset({'2002'})},
#  'R04953': {frozenset({'2003'})},
#  'R04535': {frozenset({'222'})},
#  'R04957': {frozenset({'7581'})},
#  'R04967': {frozenset({'2003'})},
#  'R04726': {frozenset({'7581'})},
#  'R04959': {frozenset({'2003'})},
#  'R04738': {frozenset({'2486'})},
#  'R03991': {frozenset({'7581'})},
#  'R04749': {frozenset({'2486'})},
#  'R03778': {frozenset({'7581'})},
#  'R04747': {frozenset({'7581'})},
#  'R04170': {frozenset({'2486'})},
#  'R04740': {frozenset({'2486'})},
#  'R04746': {frozenset({'2486'})},
#  'R03858': {frozenset({'7581'})},
#  'R02685': {frozenset({'2486'})},
#  'R00391': {frozenset({'7581'})},
#  'R01177': {frozenset({'7581'})},
#  'R04744': {frozenset({'2486'})},
#  'R04742': {frozenset({'7581'})},
#  'R03026': {frozenset({'2486'})},
#  'R00238': {frozenset({'7581'})},
#  'R01360': {frozenset({'2002'})},
#  'R01366': {frozenset({'4295'})},
#  'R01978': {frozenset({'7581'})},
#  'R01361': {frozenset({'2003'})},
#  'R02251': {frozenset({'5038'}), frozenset({'601'})},
#  'R02241': {frozenset({'7558'}), frozenset({'2007'})},
#  'R00851': {frozenset({'2006'}), frozenset({'7558'})},
#  'R02239': {frozenset({'180'}), frozenset({'304'})},
#  'R01890': {frozenset({'2005'})},
#  'R01321': {frozenset({'3883'})},
#  'R01021': {frozenset({'206'})},
#  'R01320': {frozenset({'2003'})},
#  'R03424': {frozenset({'2003'})},
#  'R02056': {frozenset({'2003'}), frozenset({'109'})},
#  'R02057': {frozenset({'3883'})},
#  'R01468': {frozenset({'206'})},
#  'R02038': {frozenset({'2005'})},
#  'R01799': {frozenset({'3896'})},
#  'R01800': {frozenset({'3883'}), frozenset({'300'})},
#  'R02978': {frozenset({'2003'})},
#  'R03245': {frozenset({'2004'})},
#  'R01123': {frozenset({'221'})},
#  'R05634': {frozenset({'212'})},
#  'R05637': {frozenset({'301'})},
#  'R05633': {frozenset({'7516'})},
#  'R05884': {frozenset({'7588'})},
#  'R09654': {frozenset({'2003'})},
#  'R04218': {frozenset({'141'})},
#  'R02065': {frozenset({'141'})},
#  'R09653': {frozenset({'2003'})},
#  'R09656': {frozenset({'2003'})},
#  'R09658': {frozenset({'2003'})},
#  'R02687': {frozenset({'2007'}), frozenset({'7579'})},
#  'R01351': {frozenset({'7579'})},
#  'R02250': {frozenset({'2007'}), frozenset({'7579'})},
#  'R01494': {frozenset({'210'})},
#  'R05640': {frozenset({'149'})},
#  'R03199': {frozenset({'109'})},
#  'R07498': {frozenset({'217'})},
#  'R07494': {frozenset({'2003'})},
#  'R12404': {frozenset({'2003'})},
#  'R12405': {frozenset({'2003'})},
#  'R07495': {frozenset({'2003'})},
#  'R07497': {frozenset({'10'})},
#  'R07506': {frozenset({'149'})},
#  'R04427': {frozenset({'2003'})},
#  'R03611': {frozenset({'149'})},
#  'R04826': {frozenset({'149'})},
#  'R03974': {frozenset({'222'})},
#  'R08739': {frozenset({'7527'})},
#  'R01463': {frozenset({'149'})},
#  'R08734': {frozenset({'7527'})},
#  'R08758': {frozenset({'149'})},
#  'R07296': {frozenset({'222'})},
#  'R04823': {frozenset({'2002'})},
#  'R04806': {frozenset({'149'})},
#  'R04817': {frozenset({'2002'})},
#  'R04263': {frozenset({'2003'})},
#  'R04819': {frozenset({'2002'})},
#  'R04825': {frozenset({'2002'})},
#  'R04818': {frozenset({'2002'})},
#  'R08761': {frozenset({'149'})},
#  'R08759': {frozenset({'149'})},
#  'R04807': {frozenset({'149'})},
#  'R04824': {frozenset({'2002'})},
#  'R08760': {frozenset({'149'})},
#  'R04854': {frozenset({'149'})},
#  'R03933': {frozenset({'149'})},
#  'R02723': {frozenset({'149'})},
#  'R02216': {frozenset({'2003'})},
#  'R01454': {frozenset({'149'})},
#  'R04855': {frozenset({'149'})},
#  'R03851': {frozenset({'149'})},
#  'R02213': {frozenset({'149'})},
#  'R03262': {frozenset({'149'})},
#  'R03263': {frozenset({'149'})},
#  'R02843': {frozenset({'149'})},
#  'R03326': {frozenset({'149'})},
#  'R02836': {frozenset({'2003'})},
#  'R02834': {frozenset({'2003'})},
#  'R02211': {frozenset({'149'})},
#  'R01837': {frozenset({'2003'})},
#  'R08517': {frozenset({'149'})},
#  'R04759': {frozenset({'149'})},
#  'R03783': {frozenset({'149'})},
#  'R02351': {frozenset({'149'})},
#  'R01840': {frozenset({'149'})},
#  'R07500': {frozenset({'141'})},
#  'R07504': {frozenset({'2003'})},
#  'R10708': {frozenset({'141'})},
#  'R07501': {frozenset({'2003'})},
#  'R10710': {frozenset({'2003'})},
#  'R10491': {frozenset({'2003'})},
#  'R07236': {frozenset({'2003'})},
#  'R10492': {frozenset({'2003'})},
#  'R07895': {frozenset({'7581'})},
#  'R07891': {frozenset({'7581'})},
#  'R07899': {frozenset({'7581'})},
#  'R03402': {frozenset({'9'})},
#  'R03401': {frozenset({'2002'})},
#  'R07863': {frozenset({'149'})},
#  'R00640': {frozenset({'217'})},
#  'R07675': {frozenset({'2002'})},
#  'R00889': {frozenset({'2003'})},
#  'R01818': {frozenset({'185'})},
#  'R00189': {frozenset({'2005'})},
#  'R04292': {frozenset({'7588'})},
#  'R03005': {frozenset({'2005'})},
#  'R10757': {frozenset({'141'})},
#  'R07263': {frozenset({'2486'})},
#  'R07262': {frozenset({'222'})},
#  'R08166': {frozenset({'7579'})},
#  'R01717': {frozenset({'880'})},
#  'R08165': {frozenset({'7574'})},
#  'R09736': {frozenset({'2003'})},
#  'R01226': {frozenset({'2002'})},
#  'R00489': {frozenset({'1'})},
#  'R03269': {frozenset({'7564'})},
#  'R04231': {frozenset({'2003'})},
#  'R00130': {frozenset({'2004'})},
#  'R04230': {frozenset({'2003'})},
#  'R03018': {frozenset({'2484'}), frozenset({'2004'})},
#  'R03035': {frozenset({'2005'}), frozenset({'2004'})},
#  'R03220': {frozenset({'867'})},
#  'R00036': {frozenset({'2002'})},
#  'R03197': {frozenset({'2002'})},
#  'R00310': {frozenset({'2007'})},
#  'R03165': {frozenset({'2007'})},
#  'R05578': {frozenset({'101'})},
#  'R06529': {frozenset({'7577'})},
#  'R05225': {frozenset({'2004'})},
#  'R05221': {frozenset({'2004'})},
#  'R12184': {frozenset({'150'}), frozenset({'2004'})},
#  'R06558': {frozenset({'2004'})},
#  'R07302': {frozenset({'7577'})},
#  'R04594': {frozenset({'7525'})},
#  'R05223': {frozenset({'2004'})},
#  'R04148': {frozenset({'7553'})},
#  'R05222': {frozenset({'2004'})},
#  'R03182': {frozenset({'2004'})},
#  'R01078': {frozenset({'2002'})},
#  'R05681': {frozenset({'7510'})},
#  'R05085': {frozenset({'3016'})},
#  'R07406': {frozenset({'spontaneous'}), frozenset({'7510'})},
#  'R05838': {frozenset({'2002'})},
#  'R00278': {frozenset({'1'})},
#  'R03459': {frozenset({'2492'})},
#  'R00549': {frozenset({'1'})},
#  'R00161': {frozenset({'2005'})},
#  'R00425': {frozenset({'7580'})},
#  'R04457': {frozenset({'2007'})},
#  'R03458': {frozenset({'7501'})},
#  'R00066': {frozenset({'1'})},
#  'R07281': {frozenset({'297'})},
#  'R07280': {frozenset({'2006'}), frozenset({'208'})},
#  'R04638': {frozenset({'221'})},
#  'R00428': {frozenset({'230'}), frozenset({'7509'})},
#  'R02237': {frozenset({'2004'}), frozenset({'4093'})},
#  'R04620': {frozenset({'7515'})},
#  'R05046': {frozenset({'230'}), frozenset({'7509'})},
#  'R03504': {frozenset({'230'})},
#  'R03503': {frozenset({'304'})},
#  'R03066': {frozenset({'2002'})},
#  'R00939': {frozenset({'7501'})},
#  'R00936': {frozenset({'7501'})},
#  'R05048': {frozenset({'230'}),
#   frozenset({'7509'}),
#   frozenset({'spontaneous'})},
#  'R04639': {frozenset({'230'}),
#   frozenset({'7509'}),
#   frozenset({'spontaneous'})},
#  'R03067': {frozenset({'2002'})},
#  'R08770': {frozenset({'244'})},
#  'R12067': {frozenset({'244'})},
#  'R09737': {frozenset({'2003'})},
#  'R05000': {frozenset({'141'})},
#  'R08771': {frozenset({'2003'})},
#  'R12657': {frozenset({'2003'})},
#  'R10053': {frozenset({'217'})},
#  'R00289': {frozenset({'7516'})},
#  'R03184': {frozenset({'217'})},
#  'R02933': {frozenset({'5'})},
#  'R03469': {frozenset({'206'})},
#  'R03433': {frozenset({'206'})},
#  'R03361': {frozenset({'206'})},
#  'R03430': {frozenset({'246'})},
#  'R04372': {frozenset({'220'})},
#  'R03478': {frozenset({'206'})},
#  'R05202': {frozenset({'206'})},
#  'R01157': {frozenset({'2006'})},
#  'R00566': {frozenset({'303'})},
#  'R01154': {frozenset({'213'})},
#  'R05050': {frozenset({'7524'})},
#  'R07419': {frozenset({'2007'})},
#  'R07417': {frozenset({'7524'})},
#  'R07418': {frozenset({'7524'})},
#  'R07414': {frozenset({'321'})},
#  'R07415': {frozenset({'2003'})},
#  'R01613': {frozenset({'7581'})},
#  'R02446': {frozenset({'813'})},
#  'R02444': {frozenset({'10'})},
#  'R04276': {frozenset({'10'})},
#  'R03123': {frozenset({'2003'})},
#  'R01220': {frozenset({'2007'})},
#  'R00943': {frozenset({'2004'})},
#  'R01655': {frozenset({'133'})},
#  'R00024': {frozenset({'302'})},
#  'R01829': {frozenset({'2002'})},
#  'R01068': {frozenset({'2002'})},
#  'R01523': {frozenset({'2004'})},
#  'R00345': {frozenset({'2002'})},
#  'R00214': {frozenset({'2007'})},
#  'R10860': {frozenset({'7524'})},
#  'R01058': {frozenset({'7524'})},
#  'R05338': {frozenset({'2002'})},
#  'R05339': {frozenset({'2007'})},
#  'R09780': {frozenset({'2007'})},
#  'R02003': {frozenset({'141'})},
#  'R02061': {frozenset({'141'})},
#  'R01658': {frozenset({'141'})},
#  'R07214': {frozenset({'10'})},
#  'R05728': {frozenset({'149'})},
#  'R04460': {frozenset({'149'})},
#  'R00730': {frozenset({'149'})},
#  'R07190': {frozenset({'149'})},
#  'R04296': {frozenset({'7512'})},
#  'R08160': {frozenset({'149'})},
#  'R08168': {frozenset({'149'})},
#  'R08167': {frozenset({'2004'})},
#  'R08164': {frozenset({'7512'})},
#  'R07450': {frozenset({'149'})},
#  'R07451': {frozenset({'149'})},
#  'R07791': {frozenset({'149'})},
#  'R07445': {frozenset({'149'})},
#  'R07474': {frozenset({'149'})},
#  'R07446': {frozenset({'149'})},
#  'R06952': {frozenset({'5'})},
#  'R07559': {frozenset({'149'})},
#  'R07558': {frozenset({'149'})},
#  'R06953': {frozenset({'5'})},
#  'R06954': {frozenset({'2003'})},
#  'R02733': {frozenset({'2011'})},
#  'R00798': {frozenset({'2003'})},
#  'R03303': {frozenset({'2012'})},
#  'R04418': {frozenset({'7524'})},
#  'R04379': {frozenset({'315'})},
#  'R04134': {frozenset({'11'})},
#  'R04380': {frozenset({'11'})},
#  'R05582': {frozenset({'2003'})},
#  'R05600': {frozenset({'2486'})},
#  'R05592': {frozenset({'2486'})},
#  'R00959': {frozenset({'7528'})},
#  'R03387': {frozenset({'2484'})},
#  'R01064': {frozenset({'2002'})},
#  'R00955': {frozenset({'312'})},
#  'R08211': {frozenset({'2003'})},
#  'R01022': {frozenset({'2003'})},
#  'R02565': {frozenset({'7524'})},
#  'R02566': {frozenset({'7524'})},
#  'R02421': {frozenset({'7512'})},
#  'R00948': {frozenset({'7516'})},
#  'R01824': {frozenset({'2002'})},
#  'R11256': {frozenset({'2002'})},
#  'R00817': {frozenset({'11'})},
#  'R02991': {frozenset({'7579'})},
#  'R06990': {frozenset({'304'})},
#  'R00816': {frozenset({'211'})},
#  'R03966': {frozenset({'315'})},
#  'R00228': {frozenset({'7524'})},
#  'R05865': {frozenset({'7579'})},
#  'R02604': {frozenset({'7579'})},
#  'R05389': {frozenset({'315'})},
#  'R02602': {frozenset({'11'})},
#  'R02762': {frozenset({'7524'})},
#  'R05353': {frozenset({'7524'})},
#  'R05864': {frozenset({'11'})},
#  'R02601': {frozenset({'11'})},
#  'R05374': {frozenset({'11'})},
#  'R05295': {frozenset({'211'})},
#  'R09543': {frozenset({'2003'})},
#  'R09725': {frozenset({'7579'})},
#  'R10121': {frozenset({'222'})},
#  'R10119': {frozenset({'7581'})},
#  'R10120': {frozenset({'2003'})},
#  'R10115': {frozenset({'7581'})},
#  'R10118': {frozenset({'2003'})},
#  'R10122': {frozenset({'2003'})},
#  'R10116': {frozenset({'2003'})},
#  'R10117': {frozenset({'222'})},
#  'R10123': {frozenset({'149'})},
#  'R03209': {frozenset({'1119'})},
#  'R00315': {frozenset({'2484'})},
#  'R00230': {frozenset({'1'}), frozenset({'7510'})},
#  'R00194': {frozenset({'2011'})},
#  'R10404': {frozenset({'2003'})},
#  'R10305': {frozenset({'2003'})},
#  'R01291': {frozenset({'309'})},
#  'R10563': {frozenset({'2002'})},
#  'R10550': {frozenset({'2002'})},
#  'R07676': {frozenset({'2002'})},
#  'R10619': {frozenset({'12'})},
#  'R00291': {frozenset({'2003'})},
#  'R10349': {frozenset({'141'})},
#  'R04872': {frozenset({'10'})},
#  'R06361': {frozenset({'210'})},
#  'R05229': {frozenset({'10'})},
#  'R05301': {frozenset({'10'})},
#  'R04147': {frozenset({'7577'})},
#  'R05230': {frozenset({'297'})},
#  'R05303': {frozenset({'2003'})},
#  'R05467': {frozenset({'2005'})},
#  'R05357': {frozenset({'2006'})},
#  'R05469': {frozenset({'10'})},
#  'R05468': {frozenset({'10'})},
#  'R05466': {frozenset({'10'})},
#  'R10485': {frozenset({'2486'})},
#  'R10415': {frozenset({'10'})},
#  'R07662': {frozenset({'2002'})},
#  'R07661': {frozenset({'7516'})},
#  'R10930': {frozenset({'7531'})},
#  'R05459': {frozenset({'1'})},
#  'R09198': {frozenset({'2485'})},
#  'R09190': {frozenset({'2485'})},
#  'R05462': {frozenset({'2485'})},
#  'R09192': {frozenset({'1'})},
#  'R04060': {frozenset({'2485'})},
#  'R06675': {frozenset({'2003'})},
#  'R09328': {frozenset({'243'})},
#  'R06680': {frozenset({'2003'})},
#  'R06681': {frozenset({'243'})},
#  'R06679': {frozenset({'304'})},
#  'R06682': {frozenset({'2003'})},
#  'R09327': {frozenset({'304'})},
#  'R09329': {frozenset({'2003'})},
#  'R09354': {frozenset({'2002'})},
#  'R09351': {frozenset({'7512'})},
#  'R09352': {frozenset({'7512'})},
#  'R09353': {frozenset({'2485'})},
#  'R06699': {frozenset({'304'})},
#  'R06700': {frozenset({'304'})},
#  'R10954': {frozenset({'2485'})},
#  'R06704': {frozenset({'2485'})},
#  'R10956': {frozenset({'2003'})},
#  'R10957': {frozenset({'2003'})},
#  'R10959': {frozenset({'2003'})},
#  'R10958': {frozenset({'2003'})},
#  'R10461': {frozenset({'2003'})},
#  'R10488': {frozenset({'286'})},
#  'R10466': {frozenset({'2006'})},
#  'R10416': {frozenset({'149'})},
#  'R10445': {frozenset({'10'})},
#  'R10457': {frozenset({'4194'})},
#  'R10414': {frozenset({'149'})},
#  'R10340': {frozenset({'4194'})},
#  'R10588': {frozenset({'2003'})},
#  'R10321': {frozenset({'149'})},
#  'R10341': {frozenset({'4194'})},
#  'R11067': {frozenset({'2003'})},
#  'R11065': {frozenset({'10'})},
#  'R10917': {frozenset({'2003'})},
#  'R09684': {frozenset({'141'})},
#  'R11105': {frozenset({'4229'})},
#  'R11106': {frozenset({'244'})},
#  'R02328': {frozenset({'7516'})},
#  'R06514': {frozenset({'10'})},
#  'R02777': {frozenset({'2003'})},
#  'R06513': {frozenset({'2003'})},
#  'R10573': {frozenset({'2003'})},
#  'R06437': {frozenset({'10'})},
#  'R06438': {frozenset({'2003'})},
#  'R10459': {frozenset({'2003'})},
#  'R11020': {frozenset({'2003'})},
#  'R06439': {frozenset({'2003'})},
#  'R06424': {frozenset({'10'})},
#  'R06427': {frozenset({'2003'})},
#  'R05518': {frozenset({'221'})},
#  'R11051': {frozenset({'2002'})},
#  'R08934': {frozenset({'10'})},
#  'R08933': {frozenset({'2003'})},
#  'R06436': {frozenset({'2003'})},
#  'R11041': {frozenset({'2003'})},
#  'R06433': {frozenset({'10'})},
#  'R11042': {frozenset({'2003'})},
#  'R11046': {frozenset({'10'})},
#  'R11045': {frozenset({'2003'})},
#  'R11047': {frozenset({'2003'})},
#  'R06434': {frozenset({'2003'})},
#  'R08597': {frozenset({'10'})},
#  'R08932': {frozenset({'2003'})},
#  'R08930': {frozenset({'3016'})},
#  'R08931': {frozenset({'3016'})},
#  'R08927': {frozenset({'2003'})},
#  'R08929': {frozenset({'2003'})},
#  'R10105': {frozenset({'7524'})},
#  'R11175': {frozenset({'2003'}), frozenset({'304'})},
#  'R11178': {frozenset({'304'})},
#  'R10103': {frozenset({'2003'})},
#  'R11245': {frozenset({'206'})},
#  'R11185': {frozenset({'2484'})},
#  'R11244': {frozenset({'2003'})},
#  'R11243': {frozenset({'236'})},
#  'R11081': {frozenset({'2002'})},
#  'R11247': {frozenset({'7512'})},
#  'R11246': {frozenset({'7516'})},
#  'R11233': {frozenset({'2003'})},
#  'R11079': {frozenset({'211'})},
#  'R11234': {frozenset({'2484'})},
#  'R11240': {frozenset({'2006'})},
#  'R11241': {frozenset({'7516'})},
#  'R11497': {frozenset({'7512'})},
#  'R10157': {frozenset({'10'})},
#  'R10154': {frozenset({'2003'})},
#  'R02305': {frozenset({'141'})},
#  'R10162': {frozenset({'149'})},
#  'R10156': {frozenset({'2003'})},
#  'R09814': {frozenset({'149'})},
#  'R10145': {frozenset({'10'})},
#  'R11368': {frozenset({'244'}), frozenset({'1'})},
#  'R10796': {frozenset({'149'})},
#  'R11389': {frozenset({'2002'})},
#  'R11387': {frozenset({'149'})},
#  'R11393': {frozenset({'244'}), frozenset({'1'})},
#  'R11421': {frozenset({'7512'})},
#  'R11417': {frozenset({'7512'})},
#  'R11420': {frozenset({'7512'})},
#  'R11422': {frozenset({'7512'})},
#  'R11415': {frozenset({'149'})},
#  'R11418': {frozenset({'7512'})},
#  'R11419': {frozenset({'7581'})},
#  'R11423': {frozenset({'7512'})},
#  'R11491': {frozenset({'1'})},
#  'R11463': {frozenset({'7561'})},
#  'R11568': {frozenset({'243'})},
#  'R09707': {frozenset({'286'})},
#  'R11569': {frozenset({'243'})},
#  'R08956': {frozenset({'2007'})},
#  'R11072': {frozenset({'2002'})},
#  'R11719': {frozenset({'230'})},
#  'R08208': {frozenset({'2003'})},
#  'R04286': {frozenset({'230'})},
#  'R09990': {frozenset({'2003'})},
#  'R07245': {frozenset({'2003'})},
#  'R12002': {frozenset({'2002'})},
#  'R12001': {frozenset({'2002'})},
#  'R11522': {frozenset({'304'})},
#  'R10781': {frozenset({'212'})},
#  'R10093': {frozenset({'7531'})},
#  'R02111': {frozenset({'7512'})},
#  'R07953': {frozenset({'7581'})},
#  'R07937': {frozenset({'7581'})},
#  'R12297': {frozenset({'7516'})},
#  'R12298': {frozenset({'7516'})},
#  'R07620': {frozenset({'6'})},
#  'R12293': {frozenset({'206'})},
#  'R12312': {frozenset({'206'})},
#  'R11705': {frozenset({'2003'})},
#  'R12344': {frozenset({'876'})},
#  'R12354': {frozenset({'206'})},
#  'R00672': {frozenset({'2002'})},
#  'R10547': {frozenset({'2006'})},
#  'R05049': {frozenset({'7524'})},
#  'R00832': {frozenset({'213'})},
#  'R04189': {frozenset({'232'})},
#  'R11372': {frozenset({'304'})},
#  'R09394': {frozenset({'2002'})},
#  'R09726': {frozenset({'7541'})},
#  'R09395': {frozenset({'325'})},
#  'R12424': {frozenset({'2002'})},
#  'R12427': {frozenset({'314'})},
#  'R12423': {frozenset({'2002'})},
#  'R12428': {frozenset({'314'})},
#  'R12432': {frozenset({'314'})},
#  'R12431': {frozenset({'314'})},
#  'R05668': {frozenset({'298'})},
#  'R05672': {frozenset({'213'})},
#  'R05673': {frozenset({'2003'})},
#  'R05670': {frozenset({'7577'})},
#  'R05674': {frozenset({'2003'})},
#  'R05676': {frozenset({'101'})},
#  'R05669': {frozenset({'221'})},
#  'R11963': {frozenset({'2007'})},
#  'R11961': {frozenset({'2007'})},
#  'R11962': {frozenset({'2007'})},
#  'R12414': {frozenset({'2003'})},
#  'R02058': {frozenset({'213'})},
#  'R00768': {frozenset({'2007'})},
#  'R00416': {frozenset({'7516'})},
#  'R10791': {frozenset({'149'})},
#  'R10794': {frozenset({'149'})},
#  'R10792': {frozenset({'149'}), frozenset({'spontaneous'})},
#  'R10171': {frozenset({'7581'})},
#  'R10278': {frozenset({'304'})},
#  'R04509': {frozenset({'2003'}),
#   frozenset({'281'}),
#   frozenset({'150'}),
#   frozenset({'2002'})},
#  'R10712': {frozenset({'281'}), frozenset({'2002'})},
#  'R03472': {frozenset({'2002'})},
#  'R02135': {frozenset({'150'})},
#  'R10686': {frozenset({'7523'})},
#  'R04448': {frozenset({'2003'})},
#  'R03471': {frozenset({'2003'}), frozenset({'281'}), frozenset({'2002'})},
#  'R03223': {frozenset({'281'}), frozenset({'2002'})},
#  'R10988': {frozenset({'7512'})},
#  'R09759': {frozenset({'7512'})},
#  'R09758': {frozenset({'7512'})},
#  'R10990': {frozenset({'7512'})},
#  'R10989': {frozenset({'7512'})},
#  'R09757': {frozenset({'7512'})},
#  'R11222': {frozenset({'149'})},
#  'R10226': {frozenset({'2003'})},
#  'R10225': {frozenset({'2003'})},
#  'R11545': {frozenset({'101'})},
#  'R10129': {frozenset({'2003'})},
#  'R11210': {frozenset({'10'})},
#  'R11211': {frozenset({'149'})},
#  'R08861': {frozenset({'2007'})},
#  'R12499': {frozenset({'4237'})},
#  'R04053': {frozenset({'7574'})},
#  'R12497': {frozenset({'2002'})},
#  'R10720': {frozenset({'146'})},
#  'R10673': {frozenset({'2002'})},
#  'R12408': {frozenset({'150'})},
#  'R09376': {frozenset({'7501'})},
#  'R09375': {frozenset({'7501'})},
#  'R00904': {frozenset({'7524'})},
#  'R09076': {frozenset({'2003'})},
#  'R09378': {frozenset({'212'})},
#  'R09379': {frozenset({'2003'})},
#  'R12608': {frozenset({'304'})},
#  'R12375': {frozenset({'2003'})},
#  'R07493': {frozenset({'217'})},
#  'R07481': {frozenset({'2003'})},
#  'R12376': {frozenset({'2003'})},
#  'R05731': {frozenset({'149'})},
#  'R07488': {frozenset({'217'})},
#  'R03200': {frozenset({'109'})},
#  'R12371': {frozenset({'2003'})},
#  'R05776': {frozenset({'2003'})},
#  'R03168': {frozenset({'213'})},
#  'R00448': {frozenset({'2003'})},
#  'R09805': {frozenset({'7524'})},
#  'R09800': {frozenset({'283'})},
#  'R12178': {frozenset({'149'})},
#  'R12177': {frozenset({'149'})},
#  'R00414': {frozenset({'7512'})},
#  'R12553': {frozenset({'2003'})},
#  'R12552': {frozenset({'2003'})},
#  'R10676': {frozenset({'7512'})},
#  'R09697': {frozenset({'2003'})},
#  'R05812': {frozenset({'2003'})},
#  'R07775': {frozenset({'2003'}), frozenset({'7550'})},
#  'R07773': {frozenset({'212'})},
#  'R05808': {frozenset({'7550'})},
#  'R05807': {frozenset({'2007'})},
#  'R03194': {frozenset({'2007'})},
#  'R05814': {frozenset({'2007'})},
#  'R07774': {frozenset({'2003'})},
#  'R11329': {frozenset({'2007'})},
#  'R06291': {frozenset({'149'})},
#  'R02068': {frozenset({'109'})},
#  'R06297': {frozenset({'149'})},
#  'R06294': {frozenset({'149'})},
#  'R06292': {frozenset({'149'})},
#  'R05092': {frozenset({'109'})},
#  'R06295': {frozenset({'149'})},
#  'R06293': {frozenset({'149'})},
#  'R03807': {frozenset({'10'})},
#  'R03009': {frozenset({'10'})},
#  'R03806': {frozenset({'10'})},
#  'R05097': {frozenset({'10'})},
#  'R06326': {frozenset({'10'})},
#  'R06336': {frozenset({'10'})},
#  'R06322': {frozenset({'10'})},
#  'R06323': {frozenset({'10'})},
#  'R06339': {frozenset({'149'})},
#  'R06341': {frozenset({'149'})},
#  'R06327': {frozenset({'149'})},
#  'R06324': {frozenset({'149'})},
#  'R06325': {frozenset({'149'})},
#  'R08588': {frozenset({'2002'})},
#  'R10667': {frozenset({'2002'})},
#  'R08587': {frozenset({'2011'})},
#  'R10666': {frozenset({'7523'})},
#  'R08589': {frozenset({'7523'})},
#  'R10695': {frozenset({'2002'})},
#  'R10668': {frozenset({'2011'})},
#  'R11061': {frozenset({'2003'})},
#  'R04994': {frozenset({'2003'})},
#  'R12255': {frozenset({'141'})},
#  'R10709': {frozenset({'2003'})},
#  'R08782': {frozenset({'141'})},
#  'R11040': {frozenset({'2484'})},
#  'R10935': {frozenset({'2002'})},
#  'R11039': {frozenset({'7531'})},
#  'R12659': {frozenset({'149'})},
#  'R00813': {frozenset({'2003'})},
#  'R05663': {frozenset({'7524'})},
#  'R06259': {frozenset({'223'})},
#  'R05532': {frozenset({'2003'})},
#  'R06497': {frozenset({'7512'})},
#  'R10615': {frozenset({'7524'})},
#  'R05177': {frozenset({'2007'})},
#  'R06260': {frozenset({'319'})},
#  'R10904': {frozenset({'7527'})},
#  'R09125': {frozenset({'4160'})},
#  'R06642': {frozenset({'2003'})},
#  'R05973': {frozenset({'7512'})},
#  'R05289': {frozenset({'7524'})},
#  'R06490': {frozenset({'7512'})},
#  'R05149': {frozenset({'2003'})},
#  'R01633': {frozenset({'7510'})},
#  'R06463': {frozenset({'149'})},
#  'R09397': {frozenset({'7516'})},
#  'R06498': {frozenset({'7512'})},
#  'R06261': {frozenset({'223'})},
#  'R11668': {frozenset({'304'})},
#  'R08214': {frozenset({'7510'})},
#  'R11122': {frozenset({'7512'})},
#  'R10247': {frozenset({'2002'})},
#  'R01419': {frozenset({'7524'})},
#  'R11363': {frozenset({'149'})},
#  'R02606': {frozenset({'7579'})},
#  'R05969': {frozenset({'3754'})},
#  'R06788': {frozenset({'2012'})},
#  'R06479': {frozenset({'2003'})},
#  'R01635': {frozenset({'7523'})},
#  'R06789': {frozenset({'7579'})},
#  'R09266': {frozenset({'243'})},
#  'R09979': {frozenset({'211'})},
#  'R05664': {frozenset({'7524'})},
#  'R09569': {frozenset({'2003'})},
#  'R04117': {frozenset({'211'})},
#  'R06455': {frozenset({'7512'})},
#  'R10101': {frozenset({'2003'})},
#  'R07125': {frozenset({'2002'})},
#  'R11123': {frozenset({'149'})},
#  'R03102': {frozenset({'7524'})},
#  'R05520': {frozenset({'2003'})},
#  'R06475': {frozenset({'2003'})},
#  'R03103': {frozenset({'7524'})},
#  'R01867': {frozenset({'2002'})},
#  'R11661': {frozenset({'2003'})},
#  'R07515': {frozenset({'7579'})},
#  'R05972': {frozenset({'7512'})},
#  'R01005': {frozenset({'7516'})},
#  'R07677': {frozenset({'247'})},
#  'R06488': {frozenset({'7512'})},
#  'R05850': {frozenset({'281'})},
#  'R03462': {frozenset({'211'})},
#  'R05917': {frozenset({'7567'})},
#  'R06238': {frozenset({'7512'})},
#  'R05248': {frozenset({'211'})},
#  'R02289': {frozenset({'2002'})},
#  'R09823': {frozenset({'2003'})},
#  'R11048': {frozenset({'2003'})},
#  'R11663': {frozenset({'2003'})},
#  'R04441': {frozenset({'12'})},
#  'R06464': {frozenset({'149'})},
#  'R07476': {frozenset({'2002'})},
#  'R10874': {frozenset({'7512'})},
#  'R09325': {frozenset({'2487'})},
#  'R02858': {frozenset({'2003'})},
#  'R09188': {frozenset({'2487'})},
#  'R03464': {frozenset({'869'})},
#  'R05270': {frozenset({'149'})},
#  'R10877': {frozenset({'149'})},
#  'R09228': {frozenset({'2003'})},
#  'R06496': {frozenset({'7512'})},
#  'R06696': {frozenset({'304'})},
#  'R03027': {frozenset({'222'})},
#  'R05594': {frozenset({'2486'})},
#  'R12658': {frozenset({'244'})},
#  'R08768': {frozenset({'244'})},
#  'R05309': {frozenset({'2003'})},
#  'R03073': {frozenset({'2003'})},
#  'R11129': {frozenset({'2003'})},
#  'R00588': {frozenset({'7577'})},
#  'R09307': {frozenset({'2003'})},
#  'R10246': {frozenset({'2002'})},
#  'R03244': {frozenset({'2002'})},
#  'R00994': {frozenset({'7510'})},
#  'R06452': {frozenset({'7512'})},
#  'R00812': {frozenset({'2003'})},
#  'R06467': {frozenset({'149'})},
#  'R03390': {frozenset({'304'})},
#  'R03072': {frozenset({'2003'})},
#  'R09126': {frozenset({'7579'})},
#  'R04088': {frozenset({'2003'})},
#  'R06454': {frozenset({'149'})},
#  'R05757': {frozenset({'2003'})},
#  'R06477': {frozenset({'2003'})},
#  'R06499': {frozenset({'7512'})},
#  'R05599': {frozenset({'2486'})},
#  'R07463': {frozenset({'2003'})},
#  'R12350': {frozenset({'4126'})},
#  'R08769': {frozenset({'2003'})},
#  'R09350': {frozenset({'2487'})},
#  'R11478': {frozenset({'244'})},
#  'R09262': {frozenset({'2003'})},
#  'R05137': {frozenset({'2485'})},
#  'R06457': {frozenset({'7512'})},
#  'R05070': {frozenset({'12'})},
#  'R06470': {frozenset({'149'})},
#  'R06787': {frozenset({'2485'})},
#  'R05232': {frozenset({'2003'})},
#  'R06128': {frozenset({'7512'})},
#  'R10881': {frozenset({'2003'})},
#  'R10883': {frozenset({'2003'})},
#  'R12351': {frozenset({'7515'})},
#  'R08215': {frozenset({'7510'})},
#  'R05922': {frozenset({'2002'})},
#  'R11669': {frozenset({'304'})},
#  'R01868': {frozenset({'2002'})},
#  'R05359': {frozenset({'7579'})},
#  'R04456': {frozenset({'2007'})},
#  'R09263': {frozenset({'2003'})},
#  'R09282': {frozenset({'222'})},
#  'R10656': {frozenset({'149'})},
#  'R05240': {frozenset({'2003'})},
#  'R12054': {frozenset({'243'})},
#  'R05076': {frozenset({'222'})},
#  'R12204': {frozenset({'5084'})},
#  'R05377': {frozenset({'281'})},
#  'R05239': {frozenset({'2003'})},
#  'R01634': {frozenset({'281'})},
#  'R09977': {frozenset({'2002'})},
#  'R05150': {frozenset({'2003'})},
#  'R10882': {frozenset({'149'})},
#  'R09837': {frozenset({'2486'})},
#  'R01514': {frozenset({'2004'})},
#  'R11665': {frozenset({'7581'})},
#  'R06489': {frozenset({'7512'})},
#  'R11149': {frozenset({'2003'})},
#  'R05314': {frozenset({'2003'})},
#  'R05245': {frozenset({'211'})},
#  'R05522': {frozenset({'149'})},
#  'R09559': {frozenset({'2007'})},
#  'R10343': {frozenset({'2003'})},
#  'R11666': {frozenset({'2003'})},
#  'R10878': {frozenset({'149'})},
#  'R02422': {frozenset({'10'})},
#  'R05789': {frozenset({'7551'})},
#  'R10876': {frozenset({'7512'})},
#  'R11626': {frozenset({'2007'})},
#  'R05235': {frozenset({'7524'})},
#  'R06785': {frozenset({'2003'})},
#  'R05598': {frozenset({'374'})},
#  'R05364': {frozenset({'7579'})},
#  'R06127': {frozenset({'7512'})},
#  'R07405': {frozenset({'2007'})},
#  'R09306': {frozenset({'2003'})},
#  'R01869': {frozenset({'2002'})},
#  'R09398': {frozenset({'7513'})},
#  'R02021': {frozenset({'2005'})},
#  'R05136': {frozenset({'2002'})},
#  'R04115': {frozenset({'2003'})},
#  'R01983': {frozenset({'2002'})},
#  'R05597': {frozenset({'2486'})},
#  'R02765': {frozenset({'211'})},
#  'R06473': {frozenset({'2003'})},
#  'R09560': {frozenset({'2003'})},
#  'R02941': {frozenset({'7524'})},
#  'R06449': {frozenset({'149'})},
#  'R06262': {frozenset({'528'})},
#  'R04464': {frozenset({'2002'})},
#  'R06451': {frozenset({'7512'})},
#  'R09305': {frozenset({'247'})},
#  'R05292': {frozenset({'2003'})},
#  'R01977': {frozenset({'2003'})},
#  'R10164': {frozenset({'139'})},
#  'R09283': {frozenset({'7527'})},
#  'R03540': {frozenset({'7561'})},
#  'R06263': {frozenset({'2484'})},
#  'R11629': {frozenset({'2004'})},
#  'R11134': {frozenset({'244'})},
#  'R11050': {frozenset({'217'})},
#  ...}

# %%
# dict2csv(rn2rules_solo, 'rn2rules_solo.csv')

# %%
def getCpdUsingLineages(cpd, direct_cpd_rn_set):
    
    # get all reactions that use given cpd
    if cpd.startswith('C'):
        # just use one run to get using/producing reactions
        run = '87452'
        using, both, producing = getUsingProducingRns(run, cpd, direct_cpd_rn_set)
    
        my_rns = (set(using) | set(both.keys())) & set(rn2rules_solo.keys())  # use + both in solo

    else:
        my_rns = direct_cpd_rn_set & set(rn2rules_solo.keys())
    
    
    cpd_using_lineages = set() 
    for rn in my_rns:
        for x in rn2rules_solo[rn]:  # for each lineage
            cpd_using_lineages.update(x)  # Add elements from the lineage
    
    if 'spontaneous' in cpd_using_lineages:
        cpd_using_lineages.remove('spontaneous')
    
    return cpd_using_lineages



cpd = 'Z00009'
direct_cpd_rn_set = getDirectRns(cpd) & set(result.scope.rns)
cuf = getCpdUsingLineages(cpd, direct_cpd_rn_set)
len(cuf)
# Out:
# 2

# %%
rn2direction.pop('\ufeffC00404_syn')
rn2direction['C00404_syn'] = 'forward'

# %%
cpd2lineagesSolo = {}
for cpd in result.scope.cpds:
    direct_cpd_rn_set = getDirectRns(cpd) & set(result.scope.rns)
    cpd2lineagesSolo[cpd] = getCpdUsingLineages(cpd, direct_cpd_rn_set)

# %%
cpd2lineagesSolo
# Out:
# {'C20805': set(),
#  'C03912': {'2002', '221', '2486', '7524'},
#  'C19719': set(),
#  'C18239': {'304', '325'},
#  'C00101': {'1',
#   '2002',
#   '2003',
#   '2004',
#   '266',
#   '304',
#   '4093',
#   '7501',
#   '7571',
#   '842'},
#  'C00416': {'180', '2007', '304', '3086', '3896', '7558', '7579'},
#  'C12124': {'2003'},
#  'C01279': {'150', '2002', '2003', '281'},
#  'C00100': {'1', '172', '2002', '2003', '2486', '7510', '7524', '7581'},
#  'C01213': set(),
#  'C04006': {'220', '7512', '7516'},
#  'C19818': set(),
#  'C21645': {'2003'},
#  'C20404': {'10'},
#  'C06473': {'2003'},
#  'C05439': {'217'},
#  'C22109': {'141'},
#  'C05276': {'2486'},
#  'C20158': set(),
#  'C18797': {'7579'},
#  'C22360': set(),
#  'C00482': {'101', '2002', '7512', '7524'},
#  'C00820': set(),
#  'C01214': {'206', '7577'},
#  'C21677': {'141'},
#  'C08734': {'2002'},
#  'C00027': {'136', '2485'},
#  'C09723': set(),
#  'C21560': {'149'},
#  'C21021': set(),
#  'C11388': set(),
#  'C05608': {'2003'},
#  'C17588': {'2003', '7567'},
#  'C09664': set(),
#  'C03401': set(),
#  'C21007': {'2003'},
#  'C03134': {'10'},
#  'C20377': {'2003', '222'},
#  'C16422': {'7512'},
#  'C20181': set(),
#  'C15523': set(),
#  'C09306': set(),
#  'C17751': {'7512'},
#  'C15489': set(),
#  'C02642': {'246', '304'},
#  'C16353': {'2003'},
#  'C12449': set(),
#  'C17500': set(),
#  'C06257': set(),
#  'C02004': set(),
#  'C02172': set(),
#  'C19972': set(),
#  'C02153': set(),
#  'C21612': {'2002', '7589'},
#  'C22033': {'2007', '7516'},
#  'C19673': {'7581'},
#  'C03738': set(),
#  'C22029': set(),
#  'C21758': set(),
#  'C19891': set(),
#  'C05984': set(),
#  'C17558': {'3086'},
#  'C11557': {'206'},
#  'C22102': {'206'},
#  'C22299': {'7513'},
#  'C21192': set(),
#  'C16562': set(),
#  'C11527': set(),
#  'C20803': {'149'},
#  'C00362': {'131', '2004', '2006', '7527'},
#  'C00346': {'2003', '2005', '2006', '206'},
#  'C21071': {'2003'},
#  'C04322': set(),
#  'C08591': {'149'},
#  'C17234': set(),
#  'C05433': {'149'},
#  'C20232': {'7561'},
#  'C19879': {'2006'},
#  'C04294': {'150', '2003'},
#  'C01582': set(),
#  'C22339': set(),
#  'C01099': {'2484', '281'},
#  'C00337': {'2002'},
#  'C00550': {'10', '246'},
#  'C17218': set(),
#  'C02912': set(),
#  'C06195': set(),
#  'C06086': set(),
#  'C00643': {'4983'},
#  'C03548': set(),
#  'C00016': {'1', '2002', '2003', '2005', '2007', '221'},
#  'C03993': set(),
#  'C01010': set(),
#  'C21874': {'243'},
#  'C01286': {'2002', '2484'},
#  'C05571': set(),
#  'C00931': set(),
#  'C03526': set(),
#  'C17349': set(),
#  'C00273': set(),
#  'C20250': {'7561'},
#  'C15999': {'304'},
#  'C05998': {'2486'},
#  'C12838': {'7579'},
#  'C01304': {'2002', '2492', '7501'},
#  'C07330': set(),
#  'C11038': {'2004', '304'},
#  'C02207': set(),
#  'C05711': {'210'},
#  'C16362': set(),
#  'C16145': set(),
#  'C20697': set(),
#  'C01131': {'2484', '281'},
#  'C22187': {'7579'},
#  'C22238': set(),
#  'C19702': {'7567'},
#  'C18022': {'867'},
#  'C01885': {'2007', '7579'},
#  'C04673': set(),
#  'C05918': set(),
#  'C00697': {'139', '2007'},
#  'C20940': {'2003'},
#  'C04281': {'7524'},
#  'C21717': set(),
#  'C03160': {'2486'},
#  'C20802': set(),
#  'C21170': {'323'},
#  'C02593': {'7581'},
#  'C03210': set(),
#  'C22188': {'7579'},
#  'C01893': set(),
#  'C21332': set(),
#  'C19737': set(),
#  'C20528': set(),
#  'C04807': {'2002', '247', '304'},
#  'C00305': set(),
#  'C03220': set(),
#  'C01118': {'2007', '7579'},
#  'C21667': {'2007'},
#  'Z00059': set(),
#  'C01043': {'7561'},
#  'C00808': set(),
#  'C14154': {'2003'},
#  'C20258': set(),
#  'C06183': set(),
#  'C21727': {'141'},
#  'C21256': set(),
#  'C05748': {'2002', '2003'},
#  'C20224': set(),
#  'C01068': {'236'},
#  'C18902': {'2003'},
#  'C01020': set(),
#  'C06376': {'2002'},
#  'C04797': set(),
#  'C21707': {'141'},
#  'C00770': {'2003'},
#  'C10020': {'323'},
#  'C06593': set(),
#  'C05412': set(),
#  'C04900': set(),
#  'C05652': set(),
#  'C00596': {'11', '7579'},
#  'C20532': set(),
#  'Z00041': {'2002'},
#  'C16163': set(),
#  'C20374': {'2003'},
#  'C03546': set(),
#  'C15867': {'141'},
#  'C16827': set(),
#  'C20626': {'7516'},
#  'C17226': set(),
#  'C00774': {'331', '7512', '7581'},
#  'C05231': {'222'},
#  'C06099': {'2002', '2003'},
#  'C05427': {'141'},
#  'C05913': {'867'},
#  'C06007': {'12'},
#  'C02949': {'222'},
#  'C00058': {'10', '2002', '2003', '7527', '7579'},
#  'C21890': set(),
#  'C03493': set(),
#  'C00387': {'10', '2006', '2011', '7517', '7527'},
#  'C06732': set(),
#  'C00864': {'2004', '2484'},
#  'C00116': {'12', '2002', '2003', '2006', '2484', '7579'},
#  'C09812': {'2003'},
#  'C17328': {'2003'},
#  'C01250': {'213'},
#  'C04637': {'206', '246'},
#  'C15699': {'2003', '321'},
#  'C05938': {'7524'},
#  'C05516': set(),
#  'C00637': {'7524'},
#  'C05755': {'2002', '2003', '7581'},
#  'C06020': {'2002'},
#  'C01380': {'7579'},
#  'C03195': set(),
#  'C00169': {'2003', '7531', '7552'},
#  'C05584': {'2003', '7524'},
#  'C02993': set(),
#  'C20275': set(),
#  'C03666': set(),
#  'C21180': set(),
#  'C03428': {'141'},
#  'C00150': set(),
#  'Z00005': {'2486', '325'},
#  'C05784': set(),
#  'C21762': {'206'},
#  'C04290': {'2003'},
#  'C19806': set(),
#  'Z00027': set(),
#  'C01592': set(),
#  'C05660': set(),
#  'C02305': set(),
#  'C21647': set(),
#  'C00431': {'2003', '246', '7524'},
#  'C16355': set(),
#  'C19763': {'7512'},
#  'C15563': {'7539'},
#  'C20351': {'7577'},
#  'C09839': set(),
#  'C00693': {'2002', '2003'},
#  'C21716': set(),
#  'C19801': set(),
#  'C05979': set(),
#  'C05786': {'867'},
#  'C21312': set(),
#  'C06555': {'7561'},
#  'C22166': {'149'},
#  'C00750': {'2003'},
#  'C15886': set(),
#  'C11999': set(),
#  'C21561': set(),
#  'C01850': {'323'},
#  'C11910': {'2003'},
#  'C02045': {'2002'},
#  'C18802': {'2007', '206'},
#  'C11838': {'2484', '309'},
#  'C10945': {'101', '2003'},
#  'C07756': {'210'},
#  'C05270': {'7581'},
#  'C01623': {'2003'},
#  'C04047': {'2486'},
#  'C03263': {'867'},
#  'C03898': set(),
#  'C00466': set(),
#  'C01013': {'2003', '2486', '304'},
#  'C00089': {'10', '2002', '2006'},
#  'C21473': {'243'},
#  'C20889': {'2002', '2003'},
#  'C22185': {'7579'},
#  'Z00025': {'107',
#   '136',
#   '139',
#   '149',
#   '150',
#   '2003',
#   '241',
#   '243',
#   '244',
#   '2485',
#   '262',
#   '304',
#   '3156',
#   '3249',
#   '3978',
#   '4229',
#   '4983',
#   '5039',
#   '5069',
#   '868',
#   '9'},
#  'C03740': {'810'},
#  'C07103': {'2007'},
#  'C21858': {'246'},
#  'C18035': {'10', '2003'},
#  'C00296': {'323'},
#  'C00498': {'221', '7512', '7516'},
#  'C00203': {'2003', '7512', '7516'},
#  'C21026': set(),
#  'C01528': {'2003', '7577'},
#  'C19819': set(),
#  'C11174': {'206'},
#  'C15857': {'2003'},
#  'C03889': {'219'},
#  'C22073': set(),
#  'C20371': {'2002'},
#  'C21611': {'281', '7589'},
#  'C02576': {'7524'},
#  'C21283': set(),
#  'C06136': {'10'},
#  'C22337': {'2484', '281'},
#  'Z00037': {'304'},
#  'C02930': {'2007'},
#  'C09614': {'10'},
#  'C21493': {'7512'},
#  'C09789': {'7512'},
#  'C22112': {'2003'},
#  'C18232': {'7579'},
#  'C00229': {'206', '221', '304', '314', '7558', '7579', '7581'},
#  'C09750': set(),
#  'C03058': {'2003'},
#  'C00254': {'164', '2003', '7523'},
#  'C19947': {'2003'},
#  'C02804': set(),
#  'C21288': set(),
#  'C21507': set(),
#  'C00360': {'131', '2004', '2006', '7527'},
#  'C14155': {'2003'},
#  'C04092': {'276'},
#  'C22164': {'149', '4194'},
#  'C01217': {'2007', '206', '212', '304', '7501', '7564'},
#  'C00187': {'2003', '2004', '217', '331', '7515'},
#  'C19793': set(),
#  'C04462': set(),
#  'C22328': {'101'},
#  'C00294': {'10', '2002', '2006', '2011', '7517', '7527'},
#  'C07130': set(),
#  'C05324': {'2003'},
#  'C18083': set(),
#  'C12323': set(),
#  'C00087': {'107', '304', '5'},
#  'C20565': {'4279'},
#  'C11514': {'2003'},
#  'C16222': {'323'},
#  'C21497': set(),
#  'C05824': {'2003'},
#  'C20712': set(),
#  'C17753': set(),
#  'C00405': {'2003', '213', '244', '246'},
#  'C04421': set(),
#  'C20937': set(),
#  'C12318': {'10', '2003'},
#  'C12137': {'2002', '323', '7512'},
#  'C02119': {'11'},
#  'C03145': set(),
#  'C17947': {'2002'},
#  'C21614': {'230'},
#  'C00437': {'2003', '304'},
#  'C09871': set(),
#  'C06307': set(),
#  'C16700': set(),
#  'C22370': set(),
#  'C16191': {'323'},
#  'C16818': set(),
#  'C19971': {'213'},
#  'C21287': set(),
#  'C22162': {'149', '4194'},
#  'C20376': {'2003', '7581'},
#  'C12630': {'7512'},
#  'C20885': set(),
#  'C03230': set(),
#  'C21660': {'141'},
#  'C22009': {'149'},
#  'C01173': {'2003'},
#  'C21829': {'149'},
#  'C05527': set(),
#  'C03537': set(),
#  'C22369': set(),
#  'C16153': set(),
#  'C22314': set(),
#  'C00633': {'7524'},
#  'C03848': set(),
#  'C02353': {'246'},
#  'C15972': {'314'},
#  'C02630': {'2003'},
#  'C00244': {'9'},
#  'C13051': {'2007'},
#  'Z00053': set(),
#  'C22171': {'149', '2003'},
#  'C05822': {'246'},
#  'C01126': {'2003'},
#  'C03598': {'2003'},
#  'C06074': {'109'},
#  'C12442': {'2003'},
#  'C00412': {'221', '222', '323', '3978'},
#  'C11516': {'2006', '7516'},
#  'C03004': set(),
#  'C00165': {'2007', '7579'},
#  'C19833': set(),
#  'C01352': {'1', '2002', '2003', '2007', '221', '4052'},
#  'C00628': {'10'},
#  'C16372': {'323'},
#  'C00106': {'10', '2002', '2011', '7517', '7549', '7573'},
#  'C00556': {'323'},
#  'C16356': set(),
#  'C01746': set(),
#  'C00065': {'2003',
#   '2006',
#   '2007',
#   '205',
#   '300',
#   '3883',
#   '7525',
#   '7577',
#   '7579',
#   '876'},
#  'C22108': {'141'},
#  'C05235': {'2002', '2005'},
#  'C22070': set(),
#  'C21674': set(),
#  'C12317': set(),
#  'C03506': {'141', '2002'},
#  'C05775': {'7525'},
#  'C20639': {'286'},
#  'C02115': set(),
#  'C05985': {'10', '7524'},
#  'C01212': {'2004'},
#  'C09718': set(),
#  'C00007': {'1',
#   '10',
#   '11',
#   '131',
#   '136',
#   '146',
#   '149',
#   '150',
#   '158',
#   '2002',
#   '2003',
#   '2004',
#   '2007',
#   '2012',
#   '211',
#   '217',
#   '230',
#   '241',
#   '243',
#   '244',
#   '247',
#   '2485',
#   '2486',
#   '257',
#   '262',
#   '281',
#   '304',
#   '3156',
#   '3207',
#   '3249',
#   '331',
#   '3978',
#   '4052',
#   '4160',
#   '4229',
#   '4983',
#   '5',
#   '5069',
#   '867'},
#  'C21272': set(),
#  'C05752': {'2002', '2003', '222', '314', '7581'},
#  'C12211': {'3016', '7512'},
#  'Z00012': set(),
#  'C15998': {'223'},
#  'C14899': {'2002', '247', '2484'},
#  'C15887': set(),
#  'C01111': set(),
#  'C11351': set(),
#  'C15978': set(),
#  'C15892': set(),
#  'C20422': {'2002'},
#  'C01877': set(),
#  'C21446': set(),
#  'C06661': {'2003'},
#  'C22119': {'2003'},
#  'C17439': set(),
#  'C05807': {'244'},
#  'C00061': {'1',
#   '180',
#   '2005',
#   '2006',
#   '2007',
#   '208',
#   '221',
#   '246',
#   '304',
#   '7525'},
#  'C04507': set(),
#  'C01029': set(),
#  'C22059': {'141'},
#  'C20941': {'2003'},
#  'C02067': {'2006', '7549'},
#  'C03232': {'3016'},
#  'C04938': set(),
#  'C05548': set(),
#  'C00472': {'2007'},
#  'C01724': {'149', '217'},
#  'C15485': {'10', '2002'},
#  'C01769': {'2003'},
#  'C00441': {'2002', '282', '304', '7524'},
#  'C00180': {'2003', '2011', '246', '7524', '7552', '7579'},
#  'C20861': {'109'},
#  'C04373': {'2002', '7512'},
#  'C17954': set(),
#  'C17211': {'7510'},
#  'C01134': {'159', '2004', '2005', '2006', '2484', '7564'},
#  'C06125': {'2004', '7515'},
#  'C01682': set(),
#  'C01372': {'7579'},
#  'C00935': {'2003', '7516'},
#  'C03283': {'213'},
#  'C20955': {'2486'},
#  'C01234': {'10', '2003'},
#  'C17263': set(),
#  'C11879': set(),
#  'C14179': {'7524'},
#  'C20896': {'2002'},
#  'C00044': {'159',
#   '2002',
#   '2004',
#   '2007',
#   '230',
#   '2484',
#   '304',
#   '316',
#   '7504',
#   '7509',
#   '7516',
#   '7580',
#   '868'},
#  'C00099': {'1', '2003', '206', '246', '7524'},
#  'C00071': {'2003', '582', '7524', '7579'},
#  'C01499': {'7524'},
#  'C01455': {'374'},
#  'C00449': set(),
#  'C09844': set(),
#  'C21281': set(),
#  'C00488': set(),
#  'C00999': {'243', '3978'},
#  'C04045': {'2003'},
#  'C20242': set(),
#  'C22160': {'2002', '314'},
#  'C04573': {'2003'},
#  'C05834': set(),
#  'C03033': {'2002'},
#  'C01417': {'5'},
#  'C05616': {'2012'},
#  'C02704': set(),
#  'C05772': {'7550'},
#  'C00005': {'141',
#   '149',
#   '2002',
#   '2003',
#   '2004',
#   '2007',
#   '217',
#   '221',
#   '230',
#   '236',
#   '244',
#   '246',
#   '2485',
#   '276',
#   '3016',
#   '304',
#   '3249',
#   '331',
#   '7501',
#   '7510',
#   '7524',
#   '7581',
#   '842'},
#  'C20962': set(),
#  'C20625': {'7516'},
#  'C17355': {'2003'},
#  'C20634': {'2003', '323'},
#  'C12287': set(),
#  'C00344': {'2002', '7515'},
#  'C16333': set(),
#  'C05831': {'2003'},
#  'C00849': {'7579'},
#  'C06308': set(),
#  'C10208': {'7512'},
#  'C22258': {'2003'},
#  'C00483': {'146', '213'},
#  'C03871': set(),
#  'C21064': set(),
#  'C04579': {'7525'},
#  'C19712': set(),
#  'C22158': {'314'},
#  'Z00003': {'2003', '222', '2486'},
#  'C03135': set(),
#  'C21630': set(),
#  'C20617': {'7516'},
#  'C16311': {'149'},
#  'C00680': {'286'},
#  'C04409': {'2002'},
#  'C21284': {'2002', '2007'},
#  'C13508': set(),
#  'C16588': {'7510'},
#  'C04884': {'10', '2002', '5'},
#  'C20682': set(),
#  'C16470': {'7581'},
#  'C01460': set(),
#  'C12624': {'7579'},
#  'C04225': {'286'},
#  'C20993': set(),
#  'C16930': set(),
#  'C00568': {'2002', '212'},
#  'C06000': {'2486'},
#  'C20542': {'149'},
#  'C16849': {'2002'},
#  'C00223': {'10', '2002', '2003', '2007', '213', '323', '7527', '7581'},
#  'C00877': {'2003', '222', '2486', '325'},
#  'C00439': {'2006', '304'},
#  'C17749': {'7512'},
#  'C20905': {'301'},
#  'C00170': {'2003', '2011', '213'},
#  'C00977': set(),
#  'C00641': {'10',
#   '2002',
#   '2003',
#   '2007',
#   '3086',
#   '323',
#   '3883',
#   '5038',
#   '601',
#   '7512',
#   '7515',
#   '7516',
#   '7579'},
#  'C06027': {'2002', '222'},
#  'C15930': {'2002'},
#  'C18094': set(),
#  'C11061': {'7512'},
#  'C00356': {'2002', '2486', '7527', '7581'},
#  'Z00008': set(),
#  'C15681': {'2003'},
#  'C04540': {'210'},
#  'Z00029': {'1',
#   '10',
#   '109',
#   '11',
#   '1119',
#   '131',
#   '141',
#   '150',
#   '159',
#   '164',
#   '172',
#   '180',
#   '185',
#   '2',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2011',
#   '206',
#   '208',
#   '210',
#   '212',
#   '220',
#   '221',
#   '230',
#   '246',
#   '247',
#   '2484',
#   '2486',
#   '2487',
#   '281',
#   '297',
#   '301',
#   '302',
#   '304',
#   '3086',
#   '312',
#   '315',
#   '321',
#   '327',
#   '3371',
#   '3754',
#   '3883',
#   '3896',
#   '4093',
#   '4279',
#   '5',
#   '5104',
#   '528',
#   '70',
#   '73',
#   '7504',
#   '7510',
#   '7512',
#   '7513',
#   '7515',
#   '7516',
#   '7525',
#   '7527',
#   '7528',
#   '7531',
#   '7534',
#   '7541',
#   '7551',
#   '7573',
#   '7574',
#   '868',
#   '880'},
#  'C06735': {'2003'},
#  'C06533': set(),
#  'C03986': set(),
#  'C04170': {'323'},
#  'C19834': set(),
#  'C02161': set(),
#  'C21694': set(),
#  'C05334': set(),
#  'C00565': {'2002', '2003'},
#  'C02335': set(),
#  'C00243': {'10', '2002', '235', '7516'},
#  'C09320': {'2003'},
#  'C05266': {'2486'},
#  'C00535': {'2002', '2003', '2004', '7512'},
#  'C01261': {'221'},
#  'C21450': {'7579'},
#  'C22276': {'3016'},
#  'C06057': set(),
#  'C17584': {'2003'},
#  'C17435': set(),
#  'C09818': {'2486'},
#  'C16340': {'2003'},
#  'C02427': set(),
#  'Z00030': {'1',
#   '10',
#   '101',
#   '11',
#   '131',
#   '141',
#   '146',
#   '149',
#   '150',
#   '158',
#   '159',
#   '172',
#   '180',
#   '2',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2011',
#   '206',
#   '207',
#   '210',
#   '211',
#   '212',
#   '221',
#   '232',
#   '246',
#   '247',
#   '2484',
#   '2485',
#   '281',
#   '297',
#   '3009',
#   '301',
#   '304',
#   '3156',
#   '316',
#   '321',
#   '3371',
#   '3754',
#   '3883',
#   '4279',
#   '5',
#   '5104',
#   '601',
#   '70',
#   '73',
#   '7504',
#   '7510',
#   '7512',
#   '7515',
#   '7516',
#   '7524',
#   '7525',
#   '7527',
#   '7528',
#   '7531',
#   '7534',
#   '7541',
#   '7549',
#   '7564',
#   '7573',
#   '7574',
#   '7579',
#   '810',
#   '867',
#   '868'},
#  'C20410': {'2003'},
#  'C03393': {'7510', '7589'},
#  'C03794': {'2004'},
#  'C21825': set(),
#  'C04146': {'141'},
#  'C15992': set(),
#  'C04832': set(),
#  'C00989': {'2003'},
#  'C00512': {'323', '7581'},
#  'C21295': set(),
#  'C04702': {'3754'},
#  'C00748': set(),
#  'C11455': set(),
#  'C20664': set(),
#  'C03827': {'2003'},
#  'C00740': {'2003', '2006', '210', '7525'},
#  'C00887': {'107', '5039'},
#  'C20485': {'2002'},
#  'C20245': {'2004'},
#  'C02718': set(),
#  'C15786': {'149'},
#  'C20695': {'5'},
#  'C00074': {'2002', '2004', '246', '328', '7516'},
#  'C01401': set(),
#  'C02486': set(),
#  'C05848': {'244'},
#  'C05841': {'2004', '2006', '2011', '7517', '7527'},
#  'C01924': set(),
#  'C03741': set(),
#  'C20163': set(),
#  'C03660': set(),
#  'C20581': set(),
#  'C20313': set(),
#  'C05923': {'230', '7509'},
#  'C00012': set(),
#  'C00365': {'131', '2004', '2006', '2492', '266', '7527', '842'},
#  'C01514': {'149'},
#  'C03190': set(),
#  'C16540': {'2003'},
#  'C04187': set(),
#  'C00791': {'2002', '2492', '7539'},
#  'C03290': set(),
#  'C15885': set(),
#  'C03440': {'2003', '286'},
#  'C20636': set(),
#  'C00257': {'2003', '5'},
#  'C04257': {'2002', '2484'},
#  'C21706': set(),
#  'C06393': {'2003'},
#  'C17327': {'2003'},
#  'C20375': {'2003', '7581'},
#  'C03189': {'2006'},
#  'C17212': {'7510'},
#  'C20844': {'2003'},
#  'C21116': {'141', '2003'},
#  'C03267': set(),
#  'C03851': set(),
#  'C03486': set(),
#  'C22253': {'7512'},
#  'C15565': {'276'},
#  'C15682': {'7512'},
#  'C00214': {'10', '131', '2006', '7527'},
#  'C09099': {'7512'},
#  'Z00050': set(),
#  'C04181': set(),
#  'C21175': set(),
#  'C16330': {'7581'},
#  'C22110': {'141'},
#  'C01542': set(),
#  'C02926': set(),
#  'C00546': {'2002', '2003', '211', '5', '7524'},
#  'C14180': {'708'},
#  'C22181': {'7512', '7579'},
#  'C20784': set(),
#  'C00788': {'2003'},
#  'C21348': set(),
#  'C01412': {'7524'},
#  'C03979': {'2002', '2003'},
#  'C16518': set(),
#  'C04244': {'2002', '2003'},
#  'C17401': {'7550'},
#  'C05689': set(),
#  'C01673': set(),
#  'C02400': {'7512'},
#  'C07480': {'2003'},
#  'C11498': {'2002'},
#  'C05133': set(),
#  'C15603': {'2002', '2003', '2007'},
#  'C20631': set(),
#  'C01996': {'323', '7579'},
#  'C16284': set(),
#  'C20465': {'2003', '323'},
#  'C15816': {'2003'},
#  'C20576': set(),
#  'C06149': set(),
#  'C04438': set(),
#  'C03997': {'2004', '266'},
#  'C00024': {'1',
#   '172',
#   '2002',
#   '2003',
#   '2007',
#   '208',
#   '213',
#   '219',
#   '2486',
#   '3016',
#   '304',
#   '323',
#   '7510',
#   '7524',
#   '7527',
#   '7579',
#   '7581'},
#  'C05515': set(),
#  'C06111': set(),
#  'C00581': {'2003'},
#  'C00903': {'2003'},
#  'C20322': set(),
#  'C20870': set(),
#  'C20622': {'7516'},
#  'C19772': set(),
#  'C11472': {'2005', '2006'},
#  'Z00063': {'109',
#   '141',
#   '2002',
#   '2003',
#   '205',
#   '2487',
#   '301',
#   '3740',
#   '7564',
#   '7586',
#   '7588'},
#  'C18331': {'2003'},
#  'C07447': {'149', '219'},
#  'C03955': {'213'},
#  'C02700': {'2487', '7579'},
#  'C05306': {'141', '3740', '7579'},
#  'C12205': {'101', '136', '2485'},
#  'C04924': set(),
#  'C00440': {'2002', '2003'},
#  'C04063': {'220'},
#  'C01024': {'2007'},
#  'C06123': set(),
#  'C01720': {'2002'},
#  'C19674': set(),
#  'C01620': set(),
#  'C03395': set(),
#  'C16321': {'149'},
#  'C20555': {'4194'},
#  'C00423': set(),
#  'C02919': set(),
#  'C08312': {'206'},
#  'C02514': {'11', '620'},
#  'C00091': {'2003', '2007', '213', '7524', '7527', '7579', '7581'},
#  'C20894': {'5'},
#  'C12623': {'2003', '2012'},
#  'C05589': {'2003'},
#  'C05357': {'107'},
#  'C07481': {'2003'},
#  'C21336': {'5'},
#  'C12092': {'7581'},
#  'C21074': {'10'},
#  'C11901': {'109', '141'},
#  'C16674': set(),
#  'C00502': {'5'},
#  'C02744': set(),
#  'C00137': {'101', '131', '2002', '3883', '7516'},
#  'C22329': {'101'},
#  'C02091': {'10', '2003', '304', '7577'},
#  'C11994': {'149'},
#  'C04783': set(),
#  'C00253': {'2007', '2011', '7517', '7553', '7561'},
#  'C00388': {'2003'},
#  'C01694': set(),
#  'C05117': {'7577'},
#  'C02814': {'11', '2007'},
#  'C00164': {'2002', '2003', '4295'},
#  'C20185': set(),
#  'C16142': set(),
#  'C20435': {'2003'},
#  'C00345': {'2003', '5'},
#  'C19725': {'208', '7512'},
#  'C02753': {'5'},
#  'C00330': {'131', '2004', '2006', '2011', '7527'},
#  'C21633': set(),
#  'C08299': {'2003'},
#  'C21289': {'2003'},
#  'C20562': {'247'},
#  'C17966': set(),
#  'C20839': set(),
#  'C18911': {'2003', '212'},
#  'C00489': {'10', '210', '7524'},
#  'C22113': set(),
#  'C05945': set(),
#  'C21169': {'323'},
#  'C02779': set(),
#  'C02059': {'2003', '2007'},
#  'C06156': set(),
#  'C04180': {'222', '2486'},
#  'C01468': {'2002', '2485', '374'},
#  'C03618': {'2002'},
#  'C00469': {'10', '107', '582', '7579'},
#  'C01300': {'2002', '230', '304'},
#  'C21805': {'2007'},
#  'C12641': {'323'},
#  'C05167': {'2003', '244'},
#  'C20243': set(),
#  'C11890': set(),
#  'C00545': {'5'},
#  'C11499': {'2003'},
#  'Z00006': {'10',
#   '101',
#   '11',
#   '131',
#   '141',
#   '150',
#   '159',
#   '2',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '206',
#   '208',
#   '210',
#   '221',
#   '246',
#   '281',
#   '304',
#   '327',
#   '3371',
#   '4126',
#   '4279',
#   '5',
#   '62',
#   '73',
#   '7510',
#   '7516',
#   '7525',
#   '7527',
#   '7549',
#   '830'},
#  'C16217': {'2003', '319'},
#  'C21009': {'2003'},
#  'C18233': {'582'},
#  'C09873': set(),
#  'C16409': set(),
#  'C04695': set(),
#  'C05631': {'10', '2003'},
#  'C01144': {'2486'},
#  'C11930': set(),
#  'C21607': {'7512', '7558'},
#  'C15926': set(),
#  'C16075': {'149', '304'},
#  'C06021': {'2002'},
#  'C00386': {'2003', '206'},
#  'C07354': set(),
#  'C05135': set(),
#  'C11062': {'2003'},
#  'C02133': {'304', '650'},
#  'C10784': set(),
#  'C20776': {'206'},
#  'C00033': {'1',
#   '2002',
#   '2003',
#   '2007',
#   '2011',
#   '2484',
#   '304',
#   '5',
#   '7524',
#   '7527',
#   '7529',
#   '7552',
#   '7567',
#   '7579'},
#  'C18002': {'7525'},
#  'C01132': {'2002', '206'},
#  'C12354': {'7581'},
#  'C00543': {'10', '232'},
#  'C02569': {'7534'},
#  'C02226': set(),
#  'C01674': {'2002', '7567'},
#  'C17754': set(),
#  'C19753': set(),
#  'C04712': set(),
#  'C22342': {'208'},
#  'Z00032': {'1',
#   '10',
#   '141',
#   '149',
#   '164',
#   '2002',
#   '2003',
#   '2007',
#   '206',
#   '207',
#   '208',
#   '223',
#   '243',
#   '244',
#   '2486',
#   '262',
#   '301',
#   '304',
#   '3978',
#   '7510',
#   '867'},
#  'C21801': {'1'},
#  'C12325': set(),
#  'C21393': set(),
#  'C06144': set(),
#  'C00861': {'2002', '2484'},
#  'C20415': {'213'},
#  'C00370': {'7512', '7579'},
#  'C02341': {'2003', '286', '7523'},
#  'C06634': set(),
#  'C03771': set(),
#  'C00378': {'150', '206'},
#  'C19757': {'323'},
#  'C06714': set(),
#  'C15501': set(),
#  'C12324': {'2486'},
#  'C18009': set(),
#  'C16850': {'2002'},
#  'C00207': {'141', '2003', '4295', '7524'},
#  'C18472': set(),
#  'C03082': set(),
#  'C00094': {'2003', '2005', '2007'},
#  'C15781': {'217'},
#  'C05785': set(),
#  'C10193': {'101'},
#  'C16488': {'2002'},
#  'C06567': set(),
#  'C21285': {'2002'},
#  'C04419': {'2486'},
#  'C10454': {'101'},
#  'C00282': set(),
#  'C21294': {'2484'},
#  'C00519': {'7577'},
#  'C01533': {'7512'},
#  'C03063': {'11'},
#  'C05596': set(),
#  'Z00007': set(),
#  'C17222': set(),
#  'C04556': {'150', '2002', '2003', '281'},
#  'C06017': {'2003'},
#  'C16336': set(),
#  'C04148': set(),
#  'C17017': {'2002', '7523'},
#  'C04236': {'7510'},
#  'C21777': set(),
#  'C20402': set(),
#  'C22246': {'2005'},
#  'C01817': set(),
#  'C05932': {'7524'},
#  'C08813': set(),
#  'C21843': set(),
#  'C20922': set(),
#  'C15877': set(),
#  'C21107': set(),
#  'C08576': set(),
#  'C00009': {'1',
#   '10',
#   '12',
#   '131',
#   '159',
#   '180',
#   '2',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2011',
#   '206',
#   '208',
#   '210',
#   '220',
#   '221',
#   '246',
#   '2484',
#   '2486',
#   '304',
#   '312',
#   '321',
#   '327',
#   '328',
#   '4093',
#   '5',
#   '5104',
#   '7510',
#   '7512',
#   '7515',
#   '7524',
#   '7525',
#   '7527',
#   '7551',
#   '7552',
#   '7577',
#   '7584',
#   '7588'},
#  'C16141': set(),
#  'C20423': set(),
#  'C02320': set(),
#  'C06210': set(),
#  'C20476': set(),
#  'C00726': {'211', '246', '2485', '3009'},
#  'C15925': {'2003'},
#  'C04559': set(),
#  'C09541': set(),
#  'C00375': set(),
#  'C04016': set(),
#  'C03406': set(),
#  'C08511': set(),
#  'C03166': set(),
#  'C01142': {'2002', '213'},
#  'C07351': set(),
#  'C06076': set(),
#  'C05335': {'327'},
#  'C06062': set(),
#  'C00779': {'2003', '243'},
#  'C20640': set(),
#  'C21731': {'7577'},
#  'C02513': set(),
#  'C06441': {'2484', '281'},
#  'C00397': {'7512'},
#  'C03341': {'2003'},
#  'C20062': {'2486'},
#  'C19741': set(),
#  'C05634': {'7524'},
#  'C11822': {'2003'},
#  'C02835': {'7524'},
#  'C06028': {'222', '7527'},
#  'C21923': set(),
#  'C01755': {'2007', '5'},
#  'C06052': set(),
#  'C00942': {'131', '304', '868'},
#  'C21068': {'7531'},
#  'C18311': set(),
#  'C07635': {'2003'},
#  'C01143': {'2004'},
#  'C20398': {'10'},
#  'C11811': {'7588'},
#  'C00097': {'10', '149', '2003', '2011', '205', '321', '7577', '810'},
#  'C21687': set(),
#  'C00052': {'2003', '235', '312', '7512', '7516'},
#  'C06213': {'2003'},
#  'C02291': {'2003'},
#  'C22277': {'7513'},
#  'C01042': {'206', '213'},
#  'C03659': set(),
#  'C15486': {'2002'},
#  'C05713': {'2002'},
#  'C20248': {'2005'},
#  'C15900': set(),
#  'C16271': set(),
#  'C05642': set(),
#  'C00353': {'109', '141', '2002', '7534'},
#  'C20594': set(),
#  'C14151': {'2003'},
#  'C02780': {'2002', '2003'},
#  'C22116': {'2003'},
#  'C21979': set(),
#  'C15651': {'2006'},
#  'C19865': {'7512'},
#  'C05922': {'230', '7509'},
#  'C18325': {'323'},
#  'C17010': {'2002', '2011'},
#  'C18237': {'7516'},
#  'C05669': set(),
#  'C00084': {'10', '107', '2002', '281', '315', '582', '7524'},
#  'C22024': {'2003'},
#  'C00163': {'2002', '2003', '2484'},
#  'C00181': {'2002', '2003'},
#  'C12348': {'7581'},
#  'C21714': set(),
#  'C06218': set(),
#  'C12368': set(),
#  'C17440': set(),
#  'C03939': {'2486', '7581'},
#  'C20186': set(),
#  'C17204': set(),
#  'C03087': set(),
#  'C22180': {'7512', '7579'},
#  'C03460': {'2486'},
#  'C20366': {'10', '7579'},
#  'C16829': set(),
#  'C05598': set(),
#  'C06040': {'7512', '7515', '7516'},
#  'C03680': set(),
#  'C00025': {'2002',
#   '2003',
#   '2004',
#   '2005',
#   '2007',
#   '206',
#   '210',
#   '213',
#   '3016',
#   '304',
#   '321',
#   '4093',
#   '7524',
#   '7577'},
#  'C11962': {'2003'},
#  'C09704': {'149'},
#  'C20773': {'2002', '2011'},
#  'C16502': {'2003', '7524'},
#  'C18473': set(),
#  'C02670': {'7524'},
#  'C14153': {'2003'},
#  'C05418': set(),
#  'C05359': {'2002', '2007'},
#  'C19848': {'7541'},
#  'C17210': set(),
#  'C20694': set(),
#  'C18225': {'149'},
#  'C05640': set(),
#  'Z00033': {'10', '2002', '213', '2486', '325'},
#  'C20772': {'2002'},
#  'C00332': {'2003', '7577', '7581'},
#  'C00844': {'2002', '7512'},
#  'C03354': set(),
#  'Z00062': set(),
#  'C05766': {'2002'},
#  'C04002': set(),
#  'C05744': {'2003', '7581'},
#  'C15524': {'205'},
#  'C05127': {'2003'},
#  'C18033': {'2003', '3016'},
#  'C20144': set(),
#  'C21784': {'7534'},
#  'C09820': {'2003', '7581'},
#  'C20418': set(),
#  'C10722': set(),
#  'C12203': {'2003'},
#  'C00075': {'159', '2004', '2484', '304', '375', '70', '7516'},
#  'C05769': set(),
#  'C12270': {'206'},
#  'C04767': set(),
#  'C16338': {'7581'},
#  'C21608': {'7512', '7558'},
#  'C11507': {'2002'},
#  'C07024': {'221', '298'},
#  'C21661': set(),
#  'C04690': set(),
#  'C05139': {'2003'},
#  'C03154': {'213'},
#  'Z00043': set(),
#  'C01408': set(),
#  'C17467': set(),
#  'C16337': set(),
#  'C16317': set(),
#  'C00975': set(),
#  'C20692': {'5'},
#  'C14463': set(),
#  'C15979': set(),
#  'C05125': set(),
#  'C02170': {'301', '7524'},
#  'C18845': set(),
#  'C08579': {'9'},
#  'C16509': {'149'},
#  'C06224': {'7564'},
#  'C19845': set(),
#  'C11513': set(),
#  'C06368': {'2002'},
#  'C20188': set(),
#  'C21675': set(),
#  'C05794': set(),
#  'C03981': set(),
#  'C09736': {'2003'},
#  'C16359': set(),
#  'C18050': {'2006', '7512'},
#  'C00417': {'286', '4021', '7523'},
#  'C00460': {'2004', '304', '70', '7504'},
#  'C00599': {'149', '2002', '2003', '2004'},
#  'C19794': {'7516'},
#  'C15547': {'222'},
#  'C16334': {'7581'},
#  'C17266': set(),
#  'C03117': {'2003'},
#  'C16276': set(),
#  'C06394': set(),
#  'C00846': {'2003', '7579'},
#  'C05572': set(),
#  'C17230': set(),
#  'C03067': {'7524'},
#  'C19750': set(),
#  'C20654': {'7510', '7542'},
#  'C05691': {'327'},
#  'C11996': set(),
#  'C22038': {'2003', '323'},
#  'C01748': set(),
#  'C01219': {'3016'},
#  'Z00065': set(),
#  'C07044': {'2003', '2006'},
#  'C04640': set(),
#  'C21705': set(),
#  'C00251': {'164', '2007', '301', '304', '7523', '880'},
#  'C00836': {'2003'},
#  'C01028': {'213'},
#  'C21562': set(),
#  'C06357': set(),
#  'C12144': set(),
#  'C00313': {'7527'},
#  'C11915': {'10', '2003'},
#  'C21620': {'2007'},
#  ...}

# %%
# dict2csv(cpd2lineagesSolo, '../data/assets/cpd2lineagesSolo.csv')

# %% [markdown]
# # TableS_oxygen_category

# %%
len(ETU_O2), len(LTU_O2), len(NU_O2), len(IU_O2)
# Out:
# (24, 62, 242, 68)

# %%
FU_O2 = ETU_O2_using_loose - ETU_O2
len(FU_O2)
# Out:
# 7

# %%
len(ETU_O2) + len(FU_O2) + len(LTU_O2) + len(NU_O2) + len(IU_O2)
# must remove FUs from LTUs
# Out:
# 403

# %%
LTU_O2 = LTU_O2 - FU_O2
len(LTU_O2)
# Out:
# 55

# %%
len(ETU_O2) + len(FU_O2) + len(LTU_O2) + len(NU_O2) + len(IU_O2)
# Out:
# 396

# %%
print(IU_O2)
# Out:
# {'236', '141', '213', '3447', '7561', '3264', '4025', '3960', '4272', '5038', '7579', '2011', '103', '7552', '7512', '210', '7584', '4335', '316', '222', '219', '602', '4', '228', '2006', '196', '5084', '3456', '3281', '3994', '503', '107', '218', '7542', '2005', '279', '7524', '7525', '4046', '7581', '206', '5100', '7578', '3697', '608', '7567', '7515', '4019', '4194', '298', '7510', '315', '323', '9', '2487', '4952', '301', '3843', '371', '6166', '3740', '3579', '601', '268', '4024', '129', '4011', '1001'}

# %%
x2oxygen_category = {}
for x in x2foMean:
    if x in ETU_O2:
        x2oxygen_category[x] = 'ETU'
    elif x in FU_O2:
        x2oxygen_category[x] = 'FU'
    elif x in LTU_O2:
        x2oxygen_category[x] = 'LTU'
    elif x in IU_O2:
        x2oxygen_category[x] = 'IU'
    elif x in NU_O2:
        x2oxygen_category[x] = 'NU'
    else:
        print('this should not run')

# %%
x2oxygen_category_od = dict(sorted(x2oxygen_category.items(), key=lambda item: int(item[0])))

data = []
for x in x2oxygen_category_od.keys():
    data.append({
        'Lineage': x,
        'Name': x2name.get(x, 'NO XNAME'),
        'Category': x2oxygen_category_od[x]
    })

df = pd.DataFrame(data)  # Convert list of dicts to DataFrame
df.head()
# Out:
#   Lineage                 Name Category
# 0       1   cradle loop barrel      LTU
# 1       2              OB-fold       NU
# 2       4                  SH3       IU
# 3       5  beta-propeller-like      LTU
# 4       6             NO XNAME      ETU

# %%
# df.to_csv('TableS_oxygen_category.csv', index=False)

# %% [markdown]
# # TableS_representative_run_cpds

# %%
cpd2name = csv2dict('../data/assets/cpd2name.csv')

# %%
data = []
for c in result.cpds_folditer.keys():
    data.append({
        'Iteration': result.cpds_folditer[c],
        'Compound ID': c,
        'Compound name': cpd2name.get(c, c)
    })

df = pd.DataFrame(data)  # Convert list of dicts to DataFrame
df.head()
# Out:
#    Iteration Compound ID                                      Compound name
# 0          0      C20485  (4S)-4-Hydroxy-2-oxoglutarate; (S)-2-Hydroxy-4...
# 1          0      C07836         D-glycero-beta-D-manno-Heptose 7-phosphate
# 2          0      C01419                        Cys-Gly; L-Cysteinylglycine
# 3          0      C00217  D-Glutamate; D-Glutamic acid; D-Glutaminic aci...
# 4          0      C00257  D-Gluconic acid; D-Gluconate; D-gluco-Hexonic ...

# %%
# df.to_csv('TableS_rep_run_cpds.csv', index=False)

# %% [markdown]
# # TableS_representative_run_lineages

# %%
data = []
for x in result.folds_folditer.keys():
    data.append({
        'Iteration': result.folds_folditer[x] - 1,  # ignore correct for 'fold_independent' and 'spontaneous'
        'Lineage': x,
        'Name': x2name.get(x, 'NO XNAME')
    })

df = pd.DataFrame(data)  # Convert list of dicts to DataFrame
df.head()
# Out:
#    Iteration           Lineage                   Name
# 0         -1  fold_independent               NO XNAME
# 1          0       spontaneous               NO XNAME
# 2          1              2002  TIM beta/alpha-barrel
# 3          2              2006        HAD domain-like
# 4          3              2484    Ribonuclease H-like

# %%
# df.to_csv('TableS_rep_run_lineages.csv', index=False)

# %% [markdown]
# # ETU vs. LTU #reactions

# %%
len(using)
# Out:
# 826

# %%
len(ETU_O2), len(FU_O2), len(LTU_O2), len(IU_O2), len(NU_O2)
# Out:
# (24, 7, 55, 68, 242)

# %%
len(ETU_O2) + len(FU_O2) + len(LTU_O2) + len(IU_O2) + len(NU_O2)
# Out:
# 396

# %%
x2rn_scope_ETU_O2 = {k:len(v) for k,v in x2rn_scope.items() if k in ETU_O2}

x2rn_scope_ETU_O2_ox = {}
for k,v in x2rn_scope.items():
    if k in ETU_O2:
        v_ox = [r for r in v if r in using] 
        x2rn_scope_ETU_O2_ox[k] = len(v_ox)
for x, l in x2rn_scope_ETU_O2.items():
    print(x, l, x2rn_scope_ETU_O2_ox[x], x2rn_scope_ETU_O2_ox[x]/l)
# Out:
# 3115 1 1 1.0
# 146 22 22 1.0
# 158 5 5 1.0
# 241 1 1 1.0
# 4983 4 4 1.0
# 6174 2 2 1.0
# 3752 1 1 1.0
# 6 2 2 1.0
# 262 15 15 1.0
# 7 6 6 1.0
# 4160 1 1 1.0
# 3978 4 4 1.0
# 603 2 2 1.0
# 3207 3 3 1.0
# 2012 10 10 1.0
# 557 5 5 1.0
# 3777 1 1 1.0
# 257 7 7 1.0
# 640 4 4 1.0
# 4110 2 2 1.0
# 3249 6 6 1.0
# 4159 2 2 1.0
# 881 1 1 1.0
# 4229 1 1 1.0

# %%
x2rn_scope_FU_O2 = {k:len(v) for k,v in x2rn_scope.items() if k in FU_O2}

x2rn_scope_FU_O2_ox = {}
for k,v in x2rn_scope.items():
    if k in FU_O2:
        v_ox = [r for r in v if r in using] 
        x2rn_scope_FU_O2_ox[k] = len(v_ox)
for x, l in x2rn_scope_FU_O2.items():
    print(x, l, x2rn_scope_FU_O2_ox[x], x2rn_scope_FU_O2_ox[x]/l)
# Out:
# 620 2 1 0.5
# 914 9 8 0.8888888888888888
# 66 27 24 0.8888888888888888
# 4028 2 1 0.5
# 4294 22 20 0.9090909090909091
# 4048 2 1 0.5
# 867 12 2 0.16666666666666666

# %%
x2rn_scope_LTU_O2 = {k:len(v) for k,v in x2rn_scope.items() if k in LTU_O2}

LTU2oxRatio = {}
x2rn_scope_LTU_O2_ox = {}
for k,v in x2rn_scope.items():
    if k in LTU_O2:
        v_ox = [r for r in v if r in using] 
        x2rn_scope_LTU_O2_ox[k] = len(v_ox)
for x, l in x2rn_scope_LTU_O2.items():
    print(x, l, x2rn_scope_LTU_O2_ox[x], x2rn_scope_LTU_O2_ox[x]/l)
    LTU2oxRatio[x] = x2rn_scope_LTU_O2_ox[x]/l
# Out:
# 4052 42 7 0.16666666666666666
# 205 56 1 0.017857142857142856
# 247 17 5 0.29411764705882354
# 244 217 111 0.511520737327189
# 3156 18 9 0.5
# 7514 73 37 0.5068493150684932
# 278 12 3 0.25
# 187 21 1 0.047619047619047616
# 633 50 5 0.1
# 2485 38 7 0.18421052631578946
# 150 37 15 0.40540540540540543
# 211 15 11 0.7333333333333333
# 149 153 118 0.7712418300653595
# 325 98 26 0.2653061224489796
# 5 74 26 0.35135135135135137
# 11 159 15 0.09433962264150944
# 604 12 3 0.25
# 243 90 74 0.8222222222222222
# 131 37 1 0.02702702702702703
# 101 118 3 0.025423728813559324
# 375 8 1 0.125
# 223 23 1 0.043478260869565216
# 302 4 1 0.25
# 3687 10 6 0.6
# 6058 5 1 0.2
# 12 156 52 0.3333333333333333
# 179 46 26 0.5652173913043478
# 10 211 87 0.41232227488151657
# 2484 122 1 0.00819672131147541
# 331 37 21 0.5675675675675675
# 230 20 3 0.15
# 221 131 28 0.21374045801526717
# 327 82 1 0.012195121951219513
# 192 6 2 0.3333333333333333
# 108 26 2 0.07692307692307693
# 217 90 41 0.45555555555555555
# 281 26 2 0.07692307692307693
# 7574 74 1 0.013513513513513514
# 209 6 2 0.3333333333333333
# 4002 56 1 0.017857142857142856
# 109 253 1 0.003952569169960474
# 304 354 31 0.08757062146892655
# 3016 178 4 0.02247191011235955
# 2004 165 3 0.01818181818181818
# 2007 413 9 0.021791767554479417
# 2486 82 1 0.012195121951219513
# 4033 39 4 0.10256410256410256
# 106 4 2 0.5
# 2002 789 21 0.026615969581749048
# 5069 11 1 0.09090909090909091
# 7577 186 4 0.021505376344086023
# 2003 1380 114 0.08260869565217391
# 231 55 26 0.4727272727272727
# 1 230 43 0.18695652173913044
# 136 14 6 0.42857142857142855

# %%
def histogram(dict1, val_type = 'MEAN', bins = 10, x_axis = 'x-axis', y_axis ='counts', ylog=False, xlog=False):
    data1 = list(dict1.values())
    
    if type(data1[0]) == dict:
        data1 = [x[val_type] for x in data1]
    
    plt.figure(figsize=(4, 4))
    
    plt.hist(data1, bins=bins, edgecolor=None)  # orientation='horizontal'
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)

    if ylog:
        plt.yscale('log', nonpositive='clip')
    if xlog:
        plt.xscale('log', nonpositive='clip')
    
    # plt.savefig(f'{x_axis}_{y_axis}.svg', dpi=300, bbox_inches='tight')
    plt.show()


histogram(LTU2oxRatio, x_axis='Fraction of O2-using rns', y_axis='LTU lineage count')

# %% [markdown]
# ## are most generalists part-time O2 users?

# %%
x2rn_scopeNum = {k:len(v) for k,v in x2rn_scope.items()}
x2rn_scopeNum['2003']
# Out:
# 1380

# %%
histogram(x2rn_scopeNum, bins=100)

# %%
generalists = [k for k,v in x2rn_scopeNum.items() if v >= 100]
len(generalists)
# Out:
# 26

# %%
count = 0
for x in generalists:
    print(x in LTU_O2, x, x2rn_scopeNum[x], LTU2oxRatio.get(x,'not LTU'))
    if x in LTU_O2:
        count += 1
print(count/len(generalists))
# Out:
# False 236 135 not LTU
# True 244 217 0.511520737327189
# True 149 153 0.7712418300653595
# False 141 277 not LTU
# True 11 159 0.09433962264150944
# False 2006 169 not LTU
# True 101 118 0.025423728813559324
# True 12 156 0.3333333333333333
# False 7581 139 not LTU
# True 10 211 0.41232227488151657
# True 2484 122 0.00819672131147541
# False 206 157 not LTU
# True 221 131 0.21374045801526717
# False 246 139 not LTU
# False 7524 116 not LTU
# False 222 102 not LTU
# True 109 253 0.003952569169960474
# True 304 354 0.08757062146892655
# True 3016 178 0.02247191011235955
# True 2004 165 0.01818181818181818
# True 2007 413 0.021791767554479417
# True 2002 789 0.026615969581749048
# False 7512 125 not LTU
# True 7577 186 0.021505376344086023
# True 2003 1380 0.08260869565217391
# True 1 230 0.18695652173913044
# 0.6538461538461539

# %%
LTU2oxRatio_gen = {k:v for k,v in LTU2oxRatio.items() if k in generalists}
histogram(LTU2oxRatio_gen, x_axis='Fraction of O2-using rns', y_axis='Generalist LTU lineage count')

# %% [markdown]
# # IU fractions

# %%
x2rn_scope_IU_O2 = {k:len(v) for k,v in x2rn_scope.items() if k in IU_O2}

IU2oxRatio = {}
x2rn_scope_IU_O2_ox = {}
for k,v in x2rn_scope.items():
    if k in IU_O2:
        v_ox = [r for r in v if r in indirectO2 or r in producing]  # indirect or O2 producing
        x2rn_scope_IU_O2_ox[k] = len(v_ox)
for x, l in x2rn_scope_IU_O2.items():
    print(x, l, x2rn_scope_IU_O2_ox[x], x2rn_scope_IU_O2_ox[x]/l)
    IU2oxRatio[x] = x2rn_scope_IU_O2_ox[x]/l
# Out:
# 7561 15 8 0.5333333333333333
# 601 10 4 0.4
# 3697 6 2 0.3333333333333333
# 236 135 8 0.05925925925925926
# 323 68 17 0.25
# 7510 42 1 0.023809523809523808
# 371 5 2 0.4
# 608 2 1 0.5
# 3281 4 4 1.0
# 4194 16 8 0.5
# 4025 6 4 0.6666666666666666
# 141 277 9 0.032490974729241874
# 3843 3 3 1.0
# 316 6 1 0.16666666666666666
# 7515 55 2 0.03636363636363636
# 196 1 1 1.0
# 2006 169 2 0.011834319526627219
# 2487 82 4 0.04878048780487805
# 279 50 3 0.06
# 2011 49 1 0.02040816326530612
# 2005 63 1 0.015873015873015872
# 213 34 3 0.08823529411764706
# 268 4 3 0.75
# 3740 8 2 0.25
# 7525 48 1 0.020833333333333332
# 5084 10 3 0.3
# 4024 2 1 0.5
# 9 5 4 0.8
# 3264 7 2 0.2857142857142857
# 7581 139 3 0.02158273381294964
# 298 84 4 0.047619047619047616
# 4046 1 1 1.0
# 7578 3 1 0.3333333333333333
# 206 157 8 0.050955414012738856
# 7579 93 22 0.23655913978494625
# 301 57 2 0.03508771929824561
# 219 25 5 0.2
# 7542 41 1 0.024390243902439025
# 218 32 3 0.09375
# 228 4 4 1.0
# 103 45 1 0.022222222222222223
# 4011 67 3 0.04477611940298507
# 4335 7 2 0.2857142857142857
# 7524 116 13 0.11206896551724138
# 107 22 3 0.13636363636363635
# 3579 2 2 1.0
# 503 7 1 0.14285714285714285
# 210 37 7 0.1891891891891892
# 222 102 5 0.049019607843137254
# 3994 1 1 1.0
# 315 8 1 0.125
# 4019 7 1 0.14285714285714285
# 4952 6 1 0.16666666666666666
# 5100 8 2 0.25
# 3960 1 1 1.0
# 602 8 1 0.125
# 4272 5 4 0.8
# 129 88 6 0.06818181818181818
# 4 19 2 0.10526315789473684
# 7584 69 4 0.057971014492753624
# 1001 24 10 0.4166666666666667
# 3456 3 3 1.0
# 7567 7 1 0.14285714285714285
# 7512 125 40 0.32
# 6166 5 5 1.0
# 3447 6 5 0.8333333333333334
# 7552 13 1 0.07692307692307693
# 5038 6 3 0.5

# %%
histogram(IU2oxRatio, x_axis='Fraction of O2-dependent rns', y_axis='IU lineage count')

# %%
IU2oxRatio_gen = {k:v for k,v in IU2oxRatio.items() if k in generalists}
histogram(IU2oxRatio_gen, x_axis='Fraction of O2-dep rns', y_axis='Gen IU lineage count')
